# %% [markdown]
# # nn-fac: Nonnegative Factorization techniques toolbox

# %% [markdown]
# #### Notes:
# As of now, algorithms do not work with numpy versions higher than 1.24.
#
# Consequently, numpy 1.23.5 is only set to work with python <= 3.11.
#
# Recommendation: Using python 3.10.4. Using numpy 1.23.5.

# %%
import numpy as np
import tensorly as tl

# %%
import nn_fac.nmf as nmf # Nonnegative Matrix Factorization
import nn_fac.ntf as ntf # Nonnegative PARAFAC Decomposition
import nn_fac.ntd as ntd # Nonnegative Tucker Decomposition
import nn_fac.parafac2 as parafac2 # Nonnegative Tensor Factorization admitting variability over a factor

# %% [markdown]
# # NMF: Nonnegative Matrix Factorization
#
# ### HALS

# %%
rank = 2
U_lines = 500
V_col = 250

# Normalize columnwise ? easier to recompute probably
U_0 = np.random.rand(U_lines, rank)
V_0 = np.random.rand(rank, V_col)
M = U_0@V_0 + 1e-2 * np.random.rand(U_lines, V_col)
U, V, errors, toc = nmf.nmf(M, rank, init = "random", n_iter_max = 1000, tol = 1e-8,update_rule = "hals",
           sparsity_coefficients = [None, None], fixed_modes = [], normalize = [False, False],
           verbose=True, return_costs = True)
# Out:
# Normalized cost function value=853.0797215817331
# Normalized cost function value=138.42787637220587, variation=714.6518452095272.
# Normalized cost function value=58.71987425485922, variation=79.70800211734665.
# Normalized cost function value=31.80646917109251, variation=26.913405083766712.
# Normalized cost function value=19.99763648355698, variation=11.808832687535528.
# Normalized cost function value=12.137956966446474, variation=7.859679517110507.
# Normalized cost function value=8.085741715226334, variation=4.05221525122014.
# Normalized cost function value=7.406179723628243, variation=0.6795619915980904.
# Normalized cost function value=5.3280347297006285, variation=2.078144993927615.
# Normalized cost function value=4.043083789805184, variation=1.2849509398954444.
# Normalized cost function value=3.218166324074136, variation=0.8249174657310481.
# Normalized cost function value=2.8443068367195345, variation=0.3738594873546015.
# Normalized cost function value=2.5022262548290475, variation=0.34208058189048707.
# Normalized cost function value=2.153994432946728, variation=0.34823182188231927.
# Normalized cost function value=1.9076063965066643, variation=0.2463880364400639.
# Normalized cost function value=1.7275964419873482, variation=0.18000995451931612.
# Normalized cost function value=1.6790681673633827, variation=0.04852827462396547.
# Normalized cost function value=1.5805763688261782, variation=0.09849179853720447.
# Normalized cost function value=1.5093445710103366, variation=0.07123179781584166.
# Normalized cost function value=1.4280760595890314, variation=0.0812685114213052.
# Normalized cost function value=1.3650900182812984, variation=0.062986041307733.
# Normalized cost function value=1.3469792090498776, variation=0.018110809231420832.
# Normalized cost function value=1.301070180880052, variation=0.04590902816982556.
# Normalized cost function value=1.2671414663036993, variation=0.033928714576352714.
# Normalized cost function value=1.2406027537752178, variation=0.0265387125284815.
# Normalized cost function value=1.2325430522103562, variation=0.008059701564861577.
# Normalized cost function value=1.2123398621142614, variation=0.020203190096094836.
# Normalized cost function value=1.206381850165271, variation=0.0059580119489903716.
# Normalized cost function value=1.1923142739362287, variation=0.014067576229042311.
# Normalized cost function value=1.182768797229473, variation=0.009545476706755762.
# Normalized cost function value=1.177760007156686, variation=0.005008790072786873.
# Normalized cost function value=1.1707706035156586, variation=0.006989403641027403.
# Normalized cost function value=1.1621604647011539, variation=0.008610138814504786.
# Normalized cost function value=1.1549033022614745, variation=0.007257162439679332.
# Normalized cost function value=1.1487639874649866, variation=0.0061393147964878825.
# Normalized cost function value=1.1435092842447794, variation=0.0052547032202072685.
# Normalized cost function value=1.1389378149044784, variation=0.004571469340300949.
# Normalized cost function value=1.1349247848671773, variation=0.004013030037301135.
# Normalized cost function value=1.1314010996878354, variation=0.0035236851793418733.
# Normalized cost function value=1.1283084556237029, variation=0.003092644064132566.
# Normalized cost function value=1.1255952451209732, variation=0.002713210502729657.
# Normalized cost function value=1.1232158300706585, variation=0.0023794150503146927.
# Normalized cost function value=1.1224089837644784, variation=0.000806846306180109.
# Normalized cost function value=1.120332049512745, variation=0.0020769342517334977.
# Normalized cost function value=1.1196388007670912, variation=0.0006932487456536851.
# Normalized cost function value=1.1178591749366007, variation=0.0017796258304905166.
# Normalized cost function value=1.1172636642521254, variation=0.0005955106844752756.
# Normalized cost function value=1.1160921141672007, variation=0.001171550084924755.
# Normalized cost function value=1.1151235351979782, variation=0.0009685789692224223.
# Normalized cost function value=1.114164160975269, variation=0.0009593742227091973.
# Normalized cost function value=1.1138142213935187, variation=0.0003499395817503359.
# Normalized cost function value=1.112963804385518, variation=0.0008504170080008144.
# Normalized cost function value=1.1119085404217761, variation=0.0010552639637417816.
# Normalized cost function value=1.1111880698699073, variation=0.000720470551868857.
# Normalized cost function value=1.1108235164946456, variation=0.0003645533752616448.
# Normalized cost function value=1.1101993566703134, variation=0.0006241598243321711.
# Normalized cost function value=1.1096714093277138, variation=0.0005279473425996439.
# Normalized cost function value=1.1089710635547678, variation=0.0007003457729459761.
# Normalized cost function value=1.1083368915160379, variation=0.0006341720387299521.
# Normalized cost function value=1.1077588150523767, variation=0.000578076463661148.
# Normalized cost function value=1.1072318645025685, variation=0.000526950549808225.
# Normalized cost function value=1.10675152599085, variation=0.00048033851171847.
# Normalized cost function value=1.106312906134794, variation=0.0004386198560559773.
# Normalized cost function value=1.105908577591312, variation=0.0004043285434820465.
# Normalized cost function value=1.105763121782841, variation=0.0001454558084710289.
# Normalized cost function value=1.1053984192207997, variation=0.0003647025620412414.
# Normalized cost function value=1.105063971498757, variation=0.0003344477220428299.
# Normalized cost function value=1.1047551366113777, variation=0.0003088348873792057.
# Normalized cost function value=1.1046553755484811, variation=9.976106289655284e-05.
# Normalized cost function value=1.1044227663491055, variation=0.00023260919937562186.
# Normalized cost function value=1.104163183721919, variation=0.0002595826271865054.
# Normalized cost function value=1.1039234883337352, variation=0.00023969538818380265.
# Normalized cost function value=1.103702220220793, variation=0.00022126811294231885.
# Normalized cost function value=1.1034979769921782, variation=0.0002042432286146756.
# Normalized cost function value=1.1033094612887187, variation=0.00018851570345956858.
# Normalized cost function value=1.103192891445236, variation=0.00011656984348262789.
# Normalized cost function value=1.1030665607546981, variation=0.00012633069053791246.
# Normalized cost function value=1.102958534466773, variation=0.000108026287925167.
# Normalized cost function value=1.1028117333716423, variation=0.0001468010951306553.
# Normalized cost function value=1.102676200141599, variation=0.0001355332300432277.
# Normalized cost function value=1.1025814661667284, variation=9.473397487069768e-05.
# Normalized cost function value=1.1024997177097429, variation=8.17484569854976e-05.
# Normalized cost function value=1.1024562894590344, variation=4.342825070846601e-05.
# Normalized cost function value=1.1024133585080835, variation=4.2930950950870184e-05.
# Normalized cost function value=1.1023070621702373, variation=0.00010629633784620118.
# Normalized cost function value=1.1022104783634799, variation=9.658380675747757e-05.
# Normalized cost function value=1.1021210761648832, variation=8.940219859665532e-05.
# Normalized cost function value=1.1020383020055005, variation=8.277415938273691e-05.
# Normalized cost function value=1.1020084040992804, variation=2.9897906220099912e-05.
# Normalized cost function value=1.1019328629339584, variation=7.554116532193511e-05.
# Normalized cost function value=1.101906006416015, variation=2.685651794331889e-05.
# Normalized cost function value=1.101838173841421, variation=6.783257459419545e-05.
# Normalized cost function value=1.101813934469851, variation=2.4239371569922952e-05.
# Normalized cost function value=1.1017520909101284, variation=6.184355972260747e-05.
# Normalized cost function value=1.1017086969754124, variation=4.339393471597397e-05.
# Normalized cost function value=1.1016848460272002, variation=2.385094821222289e-05.
# Normalized cost function value=1.1016618685936221, variation=2.297743357804194e-05.
# Normalized cost function value=1.101609788008891, variation=5.208058473105126e-05.
# Normalized cost function value=1.1015601581933738, variation=4.962981551726031e-05.
# Normalized cost function value=1.1015287235416862, variation=3.143465168764514e-05.
# Normalized cost function value=1.1014832502183725, variation=4.547332331372722e-05.
# Normalized cost function value=1.101440667175303, variation=4.2583043069477355e-05.
# Normalized cost function value=1.1014249056847654, variation=1.5761490537613554e-05.
# Normalized cost function value=1.1013946674347308, variation=3.0238250034564373e-05.
# Normalized cost function value=1.1013782938679977, variation=1.637356673311885e-05.
# Normalized cost function value=1.1013624424837374, variation=1.5851384260301415e-05.
# Normalized cost function value=1.101326839293782, variation=3.560318995532441e-05.
# Normalized cost function value=1.1012929094378565, variation=3.3929855925540764e-05.
# Normalized cost function value=1.1012608664338432, variation=3.2043004013271315e-05.
# Normalized cost function value=1.1012502188093791, variation=1.0647624464121819e-05.
# Normalized cost function value=1.101225448826201, variation=2.476998317813006e-05.
# Normalized cost function value=1.1012063984251113, variation=1.9050401089737434e-05.
# Normalized cost function value=1.101178941711751, variation=2.7456713360241025e-05.
# Normalized cost function value=1.1011532273427804, variation=2.571436897058632e-05.
# Normalized cost function value=1.1011289417316916, variation=2.428561108880345e-05.
# Normalized cost function value=1.1011060048858003, variation=2.293684589127487e-05.
# Normalized cost function value=1.1010973982299637, variation=8.606655836684851e-06.
# Normalized cost function value=1.1010888266400847, variation=8.571589878991759e-06.
# Normalized cost function value=1.1010804412359776, variation=8.385404107080774e-06.
# Normalized cost function value=1.1010599110227055, variation=2.0530213272085263e-05.
# Normalized cost function value=1.1010531232780545, variation=6.787744651015615e-06.
# Normalized cost function value=1.101037498905789, variation=1.5624372265543585e-05.
# Normalized cost function value=1.1010196492975621, variation=1.784960822681647e-05.
# Normalized cost function value=1.1010027849226751, variation=1.6864374887015643e-05.
# Normalized cost function value=1.100986854189737, variation=1.5930732938151948e-05.
# Normalized cost function value=1.1009808103847523, variation=6.04380498470114e-06.
# Normalized cost function value=1.1009747942492802, variation=6.016135472020068e-06.
# Normalized cost function value=1.1009606207037053, variation=1.4173545574980295e-05.
# Normalized cost function value=1.1009470223492572, variation=1.3598354448030037e-05.
# Normalized cost function value=1.1009341841517108, variation=1.2838197546383157e-05.
# Normalized cost function value=1.100922054186362, variation=1.2129965348828264e-05.
# Normalized cost function value=1.1009105902458824, variation=1.1463940479572443e-05.
# Normalized cost function value=1.1008996937290072, variation=1.0896516875247286e-05.
# Normalized cost function value=1.1008893182025614, variation=1.0375526445782768e-05.
# Normalized cost function value=1.100879438811628, variation=9.879390933331678e-06.
# Normalized cost function value=1.1008700319179976, variation=9.406893630492519e-06.
# Normalized cost function value=1.100866401168248, variation=3.630749749516937e-06.
# Normalized cost function value=1.1008627836800449, variation=3.617488203211394e-06.
# Normalized cost function value=1.1008562264764972, variation=6.557203547696844e-06.
# Normalized cost function value=1.1008525372444662, variation=3.6892320309789284e-06.
# Normalized cost function value=1.1008494880179522, variation=3.049226513951453e-06.
# Normalized cost function value=1.1008436664026613, variation=5.821615290946269e-06.
# Normalized cost function value=1.1008357710179166, variation=7.89538474466056e-06.
# Normalized cost function value=1.1008326706120686, variation=3.1004058480554875e-06.
# Normalized cost function value=1.100829556297582, variation=3.1143144865186656e-06.
# Normalized cost function value=1.100826476920593, variation=3.0793769889569944e-06.
# Normalized cost function value=1.1008189678485951, variation=7.509071997979788e-06.
# Normalized cost function value=1.1008136135905304, variation=5.3542580646936955e-06.
# Normalized cost function value=1.1008086049036714, variation=5.008686859042655e-06.
# Normalized cost function value=1.1008017107941075, variation=6.894109563893025e-06.
# Normalized cost function value=1.1007950109812652, variation=6.699812842292374e-06.
# Normalized cost function value=1.1007885028703235, variation=6.5081109417164384e-06.
# Normalized cost function value=1.100785932052156, variation=2.5708181674577446e-06.
# Normalized cost function value=1.1007795963404943, variation=6.335711661753507e-06.
# Normalized cost function value=1.100777125632098, variation=2.470708396318244e-06.
# Normalized cost function value=1.100771046353615, variation=6.079278483062112e-06.
# Normalized cost function value=1.1007652253055324, variation=5.82104808244388e-06.
# Normalized cost function value=1.1007595705879636, variation=5.654717568859269e-06.
# Normalized cost function value=1.1007540773266205, variation=5.493261343136879e-06.
# Normalized cost function value=1.1007487408501073, variation=5.336476513129185e-06.
# Normalized cost function value=1.1007435566220292, variation=5.184228078158881e-06.
# Normalized cost function value=1.1007385202370767, variation=5.0363849524170945e-06.
# Normalized cost function value=1.1007365112283862, variation=2.0090086905177884e-06.
# Normalized cost function value=1.1007316088178392, variation=4.9024105470696355e-06.
# Normalized cost function value=1.1007269136217828, variation=4.695196056392348e-06.
# Normalized cost function value=1.1007223521611211, variation=4.561460661633987e-06.
# Normalized cost function value=1.100717920516175, variation=4.43164494612347e-06.
# Normalized cost function value=1.1007136149303633, variation=4.305585811659185e-06.
# Normalized cost function value=1.1007094317558543, variation=4.183174509009291e-06.
# Normalized cost function value=1.1007053674504077, variation=4.064305446638272e-06.
# Normalized cost function value=1.1007031507666418, variation=2.2166837658765814e-06.
# Normalized cost function value=1.1007016212748126, variation=1.5294918291886006e-06.
# Normalized cost function value=1.1006977453487357, variation=3.875926076979397e-06.
# Normalized cost function value=1.100694011868704, variation=3.7334800315758088e-06.
# Normalized cost function value=1.1006925036406663, variation=1.508228037794268e-06.
# Normalized cost function value=1.1006888699695097, variation=3.633671156633156e-06.
# Normalized cost function value=1.1006853885797692, variation=3.4813897404895044e-06.
# Normalized cost function value=1.1006839775507034, variation=1.4110290658120306e-06.
# Normalized cost function value=1.100682561819584, variation=1.415731119447372e-06.
# Normalized cost function value=1.1006811620684704, variation=1.3997511134622442e-06.
# Normalized cost function value=1.1006786972851221, variation=2.464783348310462e-06.
# Normalized cost function value=1.1006763760348088, variation=2.3212503132974405e-06.
# Normalized cost function value=1.1006732467938138, variation=3.129240994992344e-06.
# Normalized cost function value=1.1006719720180969, variation=1.2747757169861984e-06.
# Normalized cost function value=1.1006708338515487, variation=1.1381665481202674e-06.
# Normalized cost function value=1.1006695219582023, variation=1.3118933464006943e-06.
# Normalized cost function value=1.1006673149168906, variation=2.2070413117081245e-06.
# Normalized cost function value=1.1006651831465684, variation=2.131770322266746e-06.
# Normalized cost function value=1.1006631276057248, variation=2.055540843537429e-06.
# Normalized cost function value=1.1006603649791409, variation=2.762626583940886e-06.
# Normalized cost function value=1.100659233962303, variation=1.131016837963017e-06.
# Normalized cost function value=1.100657231483655, variation=2.0024786480110635e-06.
# Normalized cost function value=1.1006564063709598, variation=8.251126950575838e-07.
# Normalized cost function value=1.1006544549720552, variation=1.951398904687096e-06.
# Normalized cost function value=1.1006533901566087, variation=1.0648154464831805e-06.
# Normalized cost function value=1.1006508635671508, variation=2.5265894578740955e-06.
# Normalized cost function value=1.1006484416476856, variation=2.4219194652008724e-06.
# Normalized cost function value=1.1006460877911008, variation=2.353856584758063e-06.
# Normalized cost function value=1.100643800005267, variation=2.2877858338876678e-06.
# Normalized cost function value=1.100641576380706, variation=2.223624560926396e-06.
# Normalized cost function value=1.100639415063426, variation=2.1613172800361014e-06.
# Normalized cost function value=1.1006373142533032, variation=2.1008101227515397e-06.
# Normalized cost function value=1.1006358035381925, variation=1.5107151107862649e-06.
# Normalized cost function value=1.100634873101552, variation=9.304366404006004e-07.
# Normalized cost function value=1.1006334162082831, variation=1.4568932689140723e-06.
# Normalized cost function value=1.1006314779038022, variation=1.9383044809195837e-06.
# Normalized cost function value=1.1006295929120966, variation=1.8849917056140697e-06.
# Normalized cost function value=1.1006288996223343, variation=6.932897622657919e-07.
# Normalized cost function value=1.1006273853124258, variation=1.5143099085790368e-06.
# Normalized cost function value=1.1006256135878556, variation=1.7717245701653894e-06.
# Normalized cost function value=1.1006238908704422, variation=1.7227174133882528e-06.
# Normalized cost function value=1.1006222160583004, variation=1.6748121418608264e-06.
# Normalized cost function value=1.100620587769652, variation=1.6282886483587333e-06.
# Normalized cost function value=1.1006199026121497, variation=6.851575022892575e-07.
# Normalized cost function value=1.1006192160548942, variation=6.865572554914934e-07.
# Normalized cost function value=1.1006176508970238, variation=1.5651578704201086e-06.
# Normalized cost function value=1.1006161494360038, variation=1.5014610199592937e-06.
# Normalized cost function value=1.1006155142492502, variation=6.351867536391609e-07.
# Normalized cost function value=1.100614429589508, variation=1.084659742245364e-06.
# Normalized cost function value=1.1006137584874829, variation=6.711020250627087e-07.
# Normalized cost function value=1.1006123556831804, variation=1.4028043024971737e-06.
# Normalized cost function value=1.1006113539423616, variation=1.00174081874016e-06.
# Normalized cost function value=1.100610359839253, variation=9.94103108720168e-07.
# Normalized cost function value=1.1006090569141913, variation=1.30292506161922e-06.
# Normalized cost function value=1.1006081207036909, variation=9.362105004573351e-07.
# Normalized cost function value=1.1006071892181695, variation=9.314855213826689e-07.
# Normalized cost function value=1.1006059711799707, variation=1.2180381987469957e-06.
# Normalized cost function value=1.1006050960387697, variation=8.751412010621351e-07.
# Normalized cost function value=1.10060422303169, variation=8.730070797380307e-07.
# Normalized cost function value=1.100603720339881, variation=5.026918088457677e-07.
# Normalized cost function value=1.1006025806589474, variation=1.1396809336261526e-06.
# Normalized cost function value=1.1006016559382752, variation=9.247206722573509e-07.
# Normalized cost function value=1.1006008628928392, variation=7.930454359872385e-07.
# Normalized cost function value=1.1006003568422658, variation=5.060505734455489e-07.
# Normalized cost function value=1.1005996279497008, variation=7.288925649717726e-07.
# Normalized cost function value=1.1005986065397522, variation=1.0214099486205441e-06.
# Normalized cost function value=1.100598166437201, variation=4.4010255106918805e-07.
# Normalized cost function value=1.100597434447599, variation=7.31989602043015e-07.
# Normalized cost function value=1.100596710608362, variation=7.238392369934843e-07.
# Normalized cost function value=1.1005957737743313, variation=9.368340307958078e-07.
# Normalized cost function value=1.1005948619609136, variation=9.11813417658891e-07.
# Normalized cost function value=1.1005945126021495, variation=3.4935876414010636e-07.
# Normalized cost function value=1.1005937772193437, variation=7.353828057610201e-07.
# Normalized cost function value=1.100593390565073, variation=3.8665427060102786e-07.
# Normalized cost function value=1.1005925300669024, variation=8.604981707183157e-07.
# Normalized cost function value=1.1005916994350038, variation=8.306318985962236e-07.
# Normalized cost function value=1.1005911004994686, variation=5.989355351676551e-07.
# Normalized cost function value=1.1005904938028794, variation=6.066965891893261e-07.
# Normalized cost function value=1.1005901408449106, variation=3.5295796885215225e-07.
# Normalized cost function value=1.100589355049908, variation=7.857950026224358e-07.
# Normalized cost function value=1.100588596284075, variation=7.587658330532321e-07.
# Normalized cost function value=1.1005878547018546, variation=7.41582220298298e-07.
# Normalized cost function value=1.1005871299081782, variation=7.247936764098739e-07.
# Normalized cost function value=1.1005866314119601, variation=4.984962180820673e-07.
# Normalized cost function value=1.1005863157193478, variation=3.156926122738213e-07.
# Normalized cost function value=1.1005856174840165, variation=6.982353313311762e-07.
# Normalized cost function value=1.1005849433374837, variation=6.741465328197194e-07.
# Normalized cost function value=1.100584284462346, variation=6.588751377822888e-07.
# Normalized cost function value=1.1005836405073106, variation=6.439550352954626e-07.
# Normalized cost function value=1.1005830111352322, variation=6.293720784533718e-07.
# Normalized cost function value=1.1005823960165635, variation=6.151186686675914e-07.
# Normalized cost function value=1.1005819525394984, variation=4.43477065070752e-07.
# Normalized cost function value=1.100581503296241, variation=4.492432574831895e-07.
# Normalized cost function value=1.1005809225454157, variation=5.807508252075877e-07.
# Normalized cost function value=1.1005806669196194, variation=2.5562579630822313e-07.
# Normalized cost function value=1.1005800981898797, variation=5.68729739747198e-07.
# Normalized cost function value=1.1005798509611042, variation=2.472287754518021e-07.
# Normalized cost function value=1.1005793009344484, variation=5.500266557767475e-07.
# Normalized cost function value=1.100578769850423, variation=5.310840254235671e-07.
# Normalized cost function value=1.1005782508029207, variation=5.1904750231202e-07.
# Normalized cost function value=1.1005777435148896, variation=5.072880311374206e-07.
# Normalized cost function value=1.1005772477204112, variation=4.957944783612334e-07.
# Normalized cost function value=1.1005770566068411, variation=1.9111357008050334e-07.
# Normalized cost function value=1.100576654812551, variation=4.017942900613747e-07.
# Normalized cost function value=1.1005761837629635, variation=4.7104958755816995e-07.
# Normalized cost function value=1.1005760021531856, variation=1.8160977788284072e-07.
# Normalized cost function value=1.1005757259370532, variation=2.762161324110224e-07.
# Normalized cost function value=1.1005752736822616, variation=4.5225479161636883e-07.
# Normalized cost function value=1.1005750756313117, variation=1.9805094986224958e-07.
# Normalized cost function value=1.1005747492038627, variation=3.264274490710761e-07.
# Normalized cost function value=1.1005744240092057, variation=3.2519465698044314e-07.
# Normalized cost function value=1.1005740035940574, variation=4.204151482500862e-07.
# Normalized cost function value=1.100573592550591, variation=4.1104346637510503e-07.
# Normalized cost function value=1.1005731908234981, variation=4.017270929246308e-07.
# Normalized cost function value=1.1005727982020928, variation=3.926214053873167e-07.
# Normalized cost function value=1.100572414480327, variation=3.83721765695455e-07.
# Normalized cost function value=1.1005720394568026, variation=3.750235244570632e-07.
# Normalized cost function value=1.1005716729346666, variation=3.665221359749893e-07.
# Normalized cost function value=1.1005714087401364, variation=2.64194530252837e-07.
# Normalized cost function value=1.100571236639804, variation=1.721003324295367e-07.
# Normalized cost function value=1.1005708864074957, variation=3.502323082660297e-07.
# Normalized cost function value=1.1005705460243627, variation=3.4038313301287815e-07.
# Normalized cost function value=1.1005702133600004, variation=3.3266436227918916e-07.
# Normalized cost function value=1.1005698882382258, variation=3.251217746136348e-07.
# Normalized cost function value=1.1005695704882819, variation=3.1774994391220446e-07.
# Normalized cost function value=1.100569259943268, variation=3.1054501392624445e-07.
# Normalized cost function value=1.1005691232428192, variation=1.3670044873848042e-07.
# Normalized cost function value=1.1005688416028323, variation=2.816399868876829e-07.
# Normalized cost function value=1.1005686014789957, variation=2.4012383659233194e-07.
# Normalized cost function value=1.1005683887179931, variation=2.1276100259370878e-07.
# Normalized cost function value=1.100568173114424, variation=2.1560356922023516e-07.
# Normalized cost function value=1.1005680475529183, variation=1.2556150563725055e-07.
# Normalized cost function value=1.1005677682428299, variation=2.7931008839132687e-07.
# Normalized cost function value=1.1005674985658136, variation=2.696770162735618e-07.
# Normalized cost function value=1.10056723500762, variation=2.6355819349177523e-07.
# Normalized cost function value=1.1005669774271738, variation=2.575804463056386e-07.
# Normalized cost function value=1.1005667256890765, variation=2.5173809725664853e-07.
# Normalized cost function value=1.1005664979983927, variation=2.2769068386274682e-07.
# Normalized cost function value=1.1005663541357777, variation=1.438626149319333e-07.
# Normalized cost function value=1.1005662466382669, variation=1.0749751089278448e-07.
# Normalized cost function value=1.1005660086471967, variation=2.379910701844068e-07.
# Normalized cost function value=1.1005657788821437, variation=2.297650529836659e-07.
# Normalized cost function value=1.100565690287901, variation=8.859424260876381e-08.
# Normalized cost function value=1.1005655636522336, variation=1.2663566750781285e-07.
# Normalized cost function value=1.1005653967410154, variation=1.6691121818013244e-07.
# Normalized cost function value=1.1005651809408574, variation=2.1580015796551777e-07.
# Normalized cost function value=1.1005649699553095, variation=2.1098554792153834e-07.
# Normalized cost function value=1.1005648885992252, variation=8.135608431381058e-08.
# Normalized cost function value=1.1005648053348291, variation=8.326439604466884e-08.
# Normalized cost function value=1.1005647133223333, variation=9.201249584478433e-08.
# Normalized cost function value=1.1005645105216952, variation=2.0280063806055182e-07.
# Normalized cost function value=1.100564422320003, variation=8.820169217216289e-08.
# Normalized cost function value=1.100564334014092, variation=8.83059110279305e-08.
# Normalized cost function value=1.100564139916265, variation=1.9409782714419066e-07.
# Normalized cost function value=1.1005639525484492, variation=1.8736781570716232e-07.
# Normalized cost function value=1.100563769433891, variation=1.831145581832061e-07.
# Normalized cost function value=1.1005636888050219, variation=8.062886913684508e-08.
# Normalized cost function value=1.1005635560153475, variation=1.327896743674728e-07.
# Normalized cost function value=1.1005634237229114, variation=1.3229243611689867e-07.
# Normalized cost function value=1.100563346654162, variation=7.706874938229191e-08.
# Normalized cost function value=1.100563225979447, variation=1.2067471510945893e-07.
# Normalized cost function value=1.1005630582635402, variation=1.6771590671815773e-07.
# Normalized cost function value=1.1005629849020742, variation=7.3361466013111e-08.
# Normalized cost function value=1.1005628218149448, variation=1.6308712935675374e-07.
# Normalized cost function value=1.100562664358503, variation=1.574564418849178e-07.
# Normalized cost function value=1.1005625508896149, variation=1.1346888806329503e-07.
# Normalized cost function value=1.1005624769366982, variation=7.395291667933179e-08.
# Normalized cost function value=1.1005623264866942, variation=1.5045000401059383e-07.
# Normalized cost function value=1.1005621802728787, variation=1.462138154995074e-07.
# Normalized cost function value=1.10056203737827, variation=1.4289460859018277e-07.
# Normalized cost function value=1.1005619744521609, variation=6.292610921221353e-08.
# Normalized cost function value=1.1005618345724049, variation=1.3987975600038283e-07.
# Normalized cost function value=1.100561773719072, variation=6.085333281724559e-08.
# Normalized cost function value=1.1005616384500703, variation=1.35269001777516e-07.
# Normalized cost function value=1.1005615078525772, variation=1.305974930421172e-07.
# Normalized cost function value=1.1005613802207677, variation=1.2763180956554265e-07.
# Normalized cost function value=1.1005612554861781, variation=1.2473458954609384e-07.
# Normalized cost function value=1.100561133583104, variation=1.2190307407955459e-07.
# Normalized cost function value=1.1005610144473275, variation=1.191357765772949e-07.
# Normalized cost function value=1.1005609619799825, variation=5.246734491315408e-08.
# Normalized cost function value=1.100560909450012, variation=5.252997059557174e-08.
# Normalized cost function value=1.1005608281663628, variation=8.128364914483655e-08.
# Normalized cost function value=1.100560715230213, variation=1.129361497653747e-07.
# Normalized cost function value=1.1005606055912833, variation=1.0963892971282974e-07.
# Normalized cost function value=1.1005605573050816, variation=4.828620170371778e-08.
# Normalized cost function value=1.100560477806184, variation=7.94988976871025e-08.
# Normalized cost function value=1.100560427088023, variation=5.0718161004326134e-08.
# Normalized cost function value=1.1005603487521356, variation=7.83358873324147e-08.
# Normalized cost function value=1.1005603031093074, variation=4.564282818364518e-08.
# Normalized cost function value=1.1005602016253533, variation=1.0148395412912237e-07.
# Normalized cost function value=1.1005601293837854, variation=7.224156783891544e-08.
# Normalized cost function value=1.1005600822920298, variation=4.7091755606132324e-08.
# Normalized cost function value=1.100559986500108, variation=9.579192195019459e-08.
# Normalized cost function value=1.1005598934066658, variation=9.309344206620551e-08.
# Normalized cost function value=1.1005598092179736, variation=8.418869223980607e-08.
# Normalized cost function value=1.100559736494067, variation=7.27239066744545e-08.
# Normalized cost function value=1.1005596720588178, variation=6.443524913635201e-08.
# Normalized cost function value=1.1005596067572414, variation=6.530157636852607e-08.
# Normalized cost function value=1.1005595286239513, variation=7.813329006012282e-08.
# Normalized cost function value=1.100559494750093, variation=3.3873858384936284e-08.
# Normalized cost function value=1.1005594575209368, variation=3.722915620230083e-08.
# Normalized cost function value=1.1005593967333367, variation=6.078760006467121e-08.
# Normalized cost function value=1.100559369706253, variation=2.7027083682185093e-08.
# Normalized cost function value=1.1005593083353942, variation=6.13708588392825e-08.
# Normalized cost function value=1.1005592306632728, variation=7.767212140130653e-08.
# Normalized cost function value=1.100559154733558, variation=7.59297147379101e-08.
# Normalized cost function value=1.1005590805281678, variation=7.420539027691575e-08.
# Normalized cost function value=1.1005590478430605, variation=3.2685107287377946e-08.
# Normalized cost function value=1.1005589752038103, variation=7.263925017042538e-08.
# Normalized cost function value=1.1005589050749545, variation=7.012885583357331e-08.
# Normalized cost function value=1.1005588545450868, variation=5.052986762343892e-08.
# Normalized cost function value=1.100558821765023, variation=3.2780063774495716e-08.
# Normalized cost function value=1.1005587711292426, variation=5.0635780457497503e-08.
# Normalized cost function value=1.1005587056607657, variation=6.546847686195179e-08.
# Normalized cost function value=1.1005586416543178, variation=6.400644791959564e-08.
# Normalized cost function value=1.1005585791015924, variation=6.255272544386514e-08.
# Normalized cost function value=1.1005585179696138, variation=6.113197859036745e-08.
# Normalized cost function value=1.1005584739226895, variation=4.404692433013224e-08.
# Normalized cost function value=1.100558429294935, variation=4.462775438085487e-08.
# Normalized cost function value=1.1005583886471935, variation=4.0647741617050315e-08.
# Normalized cost function value=1.1005583483804209, variation=4.026677258295308e-08.
# Normalized cost function value=1.1005583087598254, variation=3.9620595471134834e-08.
# Normalized cost function value=1.100558253410649, variation=5.5349176353303164e-08.
# Normalized cost function value=1.1005582291902165, variation=2.4220432548460735e-08.
# Normalized cost function value=1.1005582049409168, variation=2.424929967936862e-08.
# Normalized cost function value=1.1005581654805316, variation=3.946038518165551e-08.
# Normalized cost function value=1.1005581479365973, variation=1.754393430530854e-08.
# Normalized cost function value=1.1005581257493593, variation=2.218723804681133e-08.
# Normalized cost function value=1.1005580745494634, variation=5.119989587853979e-08.
# Normalized cost function value=1.1005580521598886, variation=2.2389574860781636e-08.
# Normalized cost function value=1.1005580024068322, variation=4.9753056341472757e-08.
# Normalized cost function value=1.1005579807556864, variation=2.1651145765133606e-08.
# Normalized cost function value=1.1005579590788146, variation=2.167687185306022e-08.
# Normalized cost function value=1.100557925539973, variation=3.353884170387289e-08.
# Normalized cost function value=1.100557891104952, variation=3.4435020834777674e-08.
# Normalized cost function value=1.1005578631747353, variation=2.793021680602692e-08.
# Normalized cost function value=1.10055784289551, variation=2.02792251879913e-08.
# Normalized cost function value=1.1005578228380173, variation=2.0057492777780794e-08.
# Normalized cost function value=1.1005577806896114, variation=4.21484058765742e-08.
# Normalized cost function value=1.1005577489928802, variation=3.16967312397054e-08.
# Normalized cost function value=1.1005577283243317, variation=2.0668548428304234e-08.
# Normalized cost function value=1.1005577093804144, variation=1.894391732371048e-08.
# Normalized cost function value=1.100557667504637, variation=4.1875777512245804e-08.
# Normalized cost function value=1.1005576382140962, variation=2.9290540659587805e-08.
# Normalized cost function value=1.1005576080030373, variation=3.021105898781684e-08.
# Normalized cost function value=1.1005575792119828, variation=2.8791054429433416e-08.
# Normalized cost function value=1.1005575604288094, variation=1.878317346104552e-08.
# Normalized cost function value=1.1005575222278918, variation=3.8200917540365253e-08.
# Normalized cost function value=1.1005574851038409, variation=3.7124050944470355e-08.
# Normalized cost function value=1.1005574583569113, variation=2.674692956006197e-08.
# Normalized cost function value=1.100557441007208, variation=1.7349703229641023e-08.
# Normalized cost function value=1.1005574238520444, variation=1.7155163734017265e-08.
# Normalized cost function value=1.100557397344519, variation=2.6507525285879296e-08.
# Normalized cost function value=1.100557372081039, variation=2.5263479974668712e-08.
# Normalized cost function value=1.1005573476614225, variation=2.441961655108571e-08.
# Normalized cost function value=1.1005573232035044, variation=2.4457918135212253e-08.
# Normalized cost function value=1.1005572984363021, variation=2.476720228905549e-08.
# Normalized cost function value=1.1005572839982398, variation=1.4438062301280752e-08.
# Normalized cost function value=1.100557261394899, variation=2.2603340754656642e-08.
# Normalized cost function value=1.1005572299929636, variation=3.140193549633352e-08.
# Normalized cost function value=1.100557199508692, variation=3.04842715515008e-08.
# Normalized cost function value=1.1005571697172363, variation=2.9791455746774886e-08.
# Normalized cost function value=1.1005571565922587, variation=1.3124977549239247e-08.
# Normalized cost function value=1.1005571274297699, variation=2.916248886819517e-08.
# Normalized cost function value=1.1005571147377622, variation=1.2692007667070015e-08.
# Normalized cost function value=1.1005571020306557, variation=1.2707106478160313e-08.
# Normalized cost function value=1.1005570741183597, variation=2.791229603005263e-08.
# Normalized cost function value=1.1005570471758366, variation=2.694252310142531e-08.
# Normalized cost function value=1.1005570277651453, variation=1.9410691276533498e-08.
# Normalized cost function value=1.1005570151072321, variation=1.2657913162072987e-08.
# Normalized cost function value=1.1005570049202804, variation=1.018695172660955e-08.
# Normalized cost function value=1.100556994577807, variation=1.0342473322211276e-08.
# Normalized cost function value=1.100556983146708, variation=1.14310991783384e-08.
# Normalized cost function value=1.10055697315273, variation=9.993977867495119e-09.
# Converged in 443 iterations.

# %%
errors[-1], len(errors)
# Out:
# (1.10055697315273, 444)

# %% [markdown]
# ## MU with Beta-Divergence
#
# ### Beta = 2 (Frobenius Norm)

# %%
rank = 2
U_lines = 500
V_col = 250

U_0 = np.random.rand(U_lines, rank)
V_0 = np.random.rand(rank, V_col)
M = U_0@V_0 + 1e-2 * np.random.rand(U_lines, V_col)
U, V, errors, toc = nmf.nmf(M, rank, init = "random", n_iter_max = 1000, tol = 1e-8,update_rule = "mu",beta = 2,
           sparsity_coefficients = [None, None], fixed_modes = [], normalize = [False, False],
           verbose=True, return_costs = True)
# Out:
# Normalized cost function value=996.445500552096
# Normalized cost function value=824.5702932351552, variation=171.87520731694076.
# Normalized cost function value=710.191845176706, variation=114.37844805844918.
# Normalized cost function value=632.2147645963024, variation=77.9770805804036.
# Normalized cost function value=577.4815049804937, variation=54.73325961580872.
# Normalized cost function value=538.0077338711491, variation=39.473771109344625.
# Normalized cost function value=508.8320114975283, variation=29.175722373620772.
# Normalized cost function value=486.78843267028356, variation=22.043578827244744.
# Normalized cost function value=469.8035475386967, variation=16.98488513158685.
# Normalized cost function value=456.48542202932435, variation=13.31812550937235.
# Normalized cost function value=445.8778529558328, variation=10.607569073491561.
# Normalized cost function value=437.30982574907364, variation=8.568027206759155.
# Normalized cost function value=430.3011239576667, variation=7.008701791406963.
# Normalized cost function value=424.5018000941116, variation=5.79932386355506.
# Normalized cost function value=419.65252355182537, variation=4.849276542286248.
# Normalized cost function value=415.558076322424, variation=4.094447229401396.
# Normalized cost function value=412.06929602773437, variation=3.4887802946896045.
# Normalized cost function value=409.0705478510521, variation=2.998748176682284.
# Normalized cost function value=406.47087682438524, variation=2.59967102666684.
# Normalized cost function value=404.1976467153415, variation=2.273230109043766.
# Normalized cost function value=402.1918797913351, variation=2.005766924006366.
# Normalized cost function value=400.40477022238343, variation=1.7871095689516778.
# Normalized cost function value=398.7950099963843, variation=1.609760225999139.
# Normalized cost function value=397.32667420376004, variation=1.4683357926242593.
# Normalized cost function value=395.96748326203124, variation=1.359190941728798.
# Normalized cost function value=394.6873060230858, variation=1.2801772389454413.
# Normalized cost function value=393.4567979032069, variation=1.2305081198788912.
# Normalized cost function value=392.24608749766713, variation=1.2107104055397713.
# Normalized cost function value=391.0234371961476, variation=1.2226503015195362.
# Normalized cost function value=389.75381080065057, variation=1.2696263954970277.
# Normalized cost function value=388.39728643483767, variation=1.356524365812902.
# Normalized cost function value=386.9072586778474, variation=1.490027756990287.
# Normalized cost function value=385.22838312481554, variation=1.678875553031844.
# Normalized cost function value=383.2942340554704, variation=1.9341490693451533.
# Normalized cost function value=381.02467817288925, variation=2.2695558825811304.
# Normalized cost function value=378.3230237499999, variation=2.701654422889362.
# Normalized cost function value=375.07309741668644, variation=3.2499263333134536.
# Normalized cost function value=371.1365453287931, variation=3.9365520878933467.
# Normalized cost function value=366.35086676021245, variation=4.785678568580636.
# Normalized cost function value=360.52897474748147, variation=5.821892012730984.
# Normalized cost function value=353.46142831235414, variation=7.067546435127326.
# Normalized cost function value=344.9228381133113, variation=8.538590199042858.
# Normalized cost function value=334.6841802433687, variation=10.238657869942585.
# Normalized cost function value=322.53262394815295, variation=12.151556295215755.
# Normalized cost function value=308.29965025310327, variation=14.23297369504968.
# Normalized cost function value=291.89636663767385, variation=16.403283615429416.
# Normalized cost function value=273.3519052991632, variation=18.544461338510644.
# Normalized cost function value=252.8471488756211, variation=20.50475642354212.
# Normalized cost function value=230.73320675588153, variation=22.113942119739562.
# Normalized cost function value=207.52422889906617, variation=23.208977856815352.
# Normalized cost function value=183.85902531556997, variation=23.665203583496208.
# Normalized cost function value=160.43511271639377, variation=23.42391259917619.
# Normalized cost function value=137.9286907294247, variation=22.506421986969087.
# Normalized cost function value=116.91951625662205, variation=21.00917447280264.
# Normalized cost function value=97.8375087971461, variation=19.082007459475946.
# Normalized cost function value=80.93955743661884, variation=16.89795136052726.
# Normalized cost function value=66.31524633420001, variation=14.62431110241883.
# Normalized cost function value=53.913538687129716, variation=12.401707647070296.
# Normalized cost function value=43.580264716506036, variation=10.33327397062368.
# Normalized cost function value=35.097376418884025, variation=8.482888297622011.
# Normalized cost function value=28.217603055361582, variation=6.8797733635224425.
# Normalized cost function value=22.691132191485615, variation=5.526470863875968.
# Normalized cost function value=18.2835222376065, variation=4.407609953879113.
# Normalized cost function value=14.785813624833064, variation=3.4977086127734367.
# Normalized cost function value=12.018656390796616, variation=2.767157234036448.
# Normalized cost function value=9.832401386547675, variation=2.1862550042489417.
# Normalized cost function value=8.104817053008167, variation=1.7275843335395074.
# Normalized cost function value=6.737660512366485, variation=1.3671565406416821.
# Normalized cost function value=5.652913681060744, variation=1.0847468313057416.
# Normalized cost function value=4.7891622833922, variation=0.863751397668544.
# Normalized cost function value=4.098360677671829, variation=0.6908016057203703.
# Normalized cost function value=3.5430745382412687, variation=0.5552861394305606.
# Normalized cost function value=3.094205245409641, variation=0.4488692928316276.
# Normalized cost function value=2.729154129593627, variation=0.36505111581601435.
# Normalized cost function value=2.430365631183907, variation=0.29878849840971977.
# Normalized cost function value=2.1841847439452544, variation=0.2461808872386526.
# Normalized cost function value=1.979968440073993, variation=0.20421630387126144.
# Normalized cost function value=1.8093986104028512, variation=0.17056982967114176.
# Normalized cost function value=1.6659528123462568, variation=0.1434457980565944.
# Normalized cost function value=1.544497456735935, variation=0.12145535561032172.
# Normalized cost function value=1.4409753827675338, variation=0.1035220739684013.
# Normalized cost function value=1.3521658877325649, variation=0.08880949503496893.
# Normalized cost function value=1.2755002324194955, variation=0.07666565531306935.
# Normalized cost function value=1.2089195693083272, variation=0.06658066311116828.
# Normalized cost function value=1.1507653055692886, variation=0.05815426373903865.
# Normalized cost function value=1.0996942801162881, variation=0.05107102545300046.
# Normalized cost function value=1.0546129489317744, variation=0.04508133118451374.
# Normalized cost function value=1.0146261575394189, variation=0.0399867913923555.
# Normalized cost function value=0.9789971325717493, variation=0.03562902496766962.
# Normalized cost function value=0.9471161238960996, variation=0.03188100867564969.
# Normalized cost function value=0.9184757353978249, variation=0.02864038849827466.
# Normalized cost function value=0.8926514429136004, variation=0.025824292484224465.
# Normalized cost function value=0.8692861475307603, variation=0.023365295382840157.
# Normalized cost function value=0.8480778785012599, variation=0.02120826902950035.
# Normalized cost function value=0.8287699627569749, variation=0.01930791574428503.
# Normalized cost function value=0.8111431328460866, variation=0.017626829910888264.
# Normalized cost function value=0.7950091636339616, variation=0.016133969212125066.
# Normalized cost function value=0.7802057190717797, variation=0.014803444562181856.
# Normalized cost function value=0.7665921603292855, variation=0.013613558742494258.
# Normalized cost function value=0.7540461205910337, variation=0.012546039738251746.
# Normalized cost function value=0.742460693602367, variation=0.011585426988666714.
# Normalized cost function value=0.7317421154766037, variation=0.010718578125763267.
# Normalized cost function value=0.7218078445066622, variation=0.009934270969941483.
# Normalized cost function value=0.7125849634193098, variation=0.009222881087352475.
# Normalized cost function value=0.7040088439259156, variation=0.008576119493394208.
# Normalized cost function value=0.6960220255269866, variation=0.007986818398929008.
# Normalized cost function value=0.6885732700586392, variation=0.0074487554683473345.
# Normalized cost function value=0.681616760998351, variation=0.0069565090602882185.
# Normalized cost function value=0.6751114225107586, variation=0.0065053384875923825.
# Normalized cost function value=0.6690203379572739, variation=0.006091084553484727.
# Normalized cost function value=0.6633102513713244, variation=0.005710086585949514.
# Normalized cost function value=0.6579511384261116, variation=0.005359112945212741.
# Normalized cost function value=0.6529158358484575, variation=0.005035302577654166.
# Normalized cost function value=0.6481797201858474, variation=0.004736115662610119.
# Normalized cost function value=0.6437204284141053, variation=0.004459291771742091.
# Normalized cost function value=0.6395176141522386, variation=0.004202814261866639.
# Normalized cost function value=0.6355527342943833, variation=0.003964879857855319.
# Normalized cost function value=0.6318088617184717, variation=0.0037438725759115776.
# Normalized cost function value=0.6282705204292787, variation=0.003538341289193059.
# Normalized cost function value=0.6249235400674188, variation=0.003346980361859875.
# Normalized cost function value=0.6217549271890993, variation=0.003168612878319488.
# Normalized cost function value=0.6187527511146413, variation=0.003002176074457963.
# Normalized cost function value=0.6159060424695985, variation=0.0028467086450428836.
# Normalized cost function value=0.6132047028158739, variation=0.0027013396537245438.
# Normalized cost function value=0.6106394239974763, variation=0.0025652788183976316.
# Normalized cost function value=0.6082016160192931, variation=0.0024378079781831596.
# Normalized cost function value=0.6058833424373431, variation=0.0023182735819500255.
# Normalized cost function value=0.6036772623779697, variation=0.0022060800593733942.
# Normalized cost function value=0.601576578419275, variation=0.0021006839586946713.
# Normalized cost function value=0.5995749896676155, variation=0.0020015887516595665.
# Normalized cost function value=0.5976666494465114, variation=0.0019083402211040879.
# Normalized cost function value=0.5958461270900942, variation=0.0018205223564171646.
# Normalized cost function value=0.5941083733926975, variation=0.0017377536973967045.
# Normalized cost function value=0.592448689324183, variation=0.0016596840685144665.
# Normalized cost function value=0.5908626976642359, variation=0.0015859916599471058.
# Normalized cost function value=0.5893463172512164, variation=0.0015163804130194913.
# Normalized cost function value=0.5878957395762688, variation=0.0014505776749476063.
# Normalized cost function value=0.5865074074834326, variation=0.0013883320928362863.
# Normalized cost function value=0.5851779957643624, variation=0.0013294117190701948.
# Normalized cost function value=0.5839043934594237, variation=0.0012736023049386702.
# Normalized cost function value=0.5826836876971582, variation=0.001220705762265517.
# Normalized cost function value=0.5815131489234, variation=0.0011705387737581674.
# Normalized cost function value=0.5803902173857634, variation=0.001122931537636651.
# Normalized cost function value=0.5793124907553702, variation=0.0010777266303931832.
# Normalized cost function value=0.5782777127775899, variation=0.001034777977780288.
# Normalized cost function value=0.5772837628578348, variation=0.0009939499197550994.
# Normalized cost function value=0.5763286464946779, variation=0.000955116363156927.
# Normalized cost function value=0.5754104864843117, variation=0.0009181600103661536.
# Normalized cost function value=0.574527514826583, variation=0.0008829716577286595.
# Normalized cost function value=0.5736780652696591, variation=0.000849449556923898.
# Normalized cost function value=0.5728605664372424, variation=0.0008174988324167742.
# Normalized cost function value=0.5720735354873981, variation=0.0007870309498442252.
# Normalized cost function value=0.5713155722567135, variation=0.0007579632306846662.
# Normalized cost function value=0.5705853538482977, variation=0.0007302184084158059.
# Normalized cost function value=0.5698816296260172, variation=0.0007037242222804885.
# Normalized cost function value=0.5692032165804701, variation=0.000678413045547055.
# Normalized cost function value=0.5685489950360706, variation=0.0006542215443995358.
# Normalized cost function value=0.5679179046707132, variation=0.0006310903653573563.
# Normalized cost function value=0.5673089408228679, variation=0.0006089638478453674.
# Normalized cost function value=0.5667211510622546, variation=0.0005877897606132443.
# Normalized cost function value=0.5661536320033697, variation=0.0005675190588849688.
# Normalized cost function value=0.5656055263425639, variation=0.0005481056608057644.
# Normalized cost function value=0.5650760201004293, variation=0.0005295062421345476.
# Normalized cost function value=0.5645643400543412, variation=0.0005116800460881477.
# Normalized cost function value=0.5640697513455203, variation=0.0004945887088209089.
# Normalized cost function value=0.5635915552481068, variation=0.000478196097413508.
# Normalized cost function value=0.5631290870870342, variation=0.00046246816107253785.
# Normalized cost function value=0.5626817142942462, variation=0.00044737279278805886.
# Normalized cost function value=0.5622488345923233, variation=0.0004328797019228503.
# Normalized cost function value=0.5618298742965394, variation=0.00041896029578392113.
# Normalized cost function value=0.561424286726184, variation=0.0004055875703553591.
# Normalized cost function value=0.5610315507178283, variation=0.00039273600835576516.
# Normalized cost function value=0.5606511692322687, variation=0.00038038148555963325.
# Normalized cost function value=0.5602826680495617, variation=0.0003685011827069262.
# Normalized cost function value=0.559925594544665, variation=0.0003570735048967766.
# Normalized cost function value=0.559579516539219, variation=0.0003460780054459489.
# Normalized cost function value=0.5592440212231891, variation=0.0003354953160299434.
# Normalized cost function value=0.5589187141420489, variation=0.00032530708114020257.
# Normalized cost function value=0.5586032182449848, variation=0.00031549589706403314.
# Normalized cost function value=0.5582971729896904, variation=0.0003060452552944293.
# Normalized cost function value=0.5580002335001418, variation=0.0002969394895485644.
# Normalized cost function value=0.5577120697740259, variation=0.0002881637261159531.
# Normalized cost function value=0.5574323659357042, variation=0.00027970383832165435.
# Normalized cost function value=0.5571608195330029, variation=0.0002715464027013281.
# Normalized cost function value=0.5568971408736173, variation=0.0002636786593855911.
# Normalized cost function value=0.5566410523996081, variation=0.0002560884740091529.
# Normalized cost function value=0.5563922880967704, variation=0.0002487643028377118.
# Normalized cost function value=0.5561505929373399, variation=0.00024169515943051056.
# Normalized cost function value=0.5559157223533812, variation=0.00023487058395876836.
# Normalized cost function value=0.5556874417391807, variation=0.00022828061420043788.
# Normalized cost function value=0.5554655259808414, variation=0.00022191575833929722.
# Normalized cost function value=0.5552497590112032, variation=0.00021576696963820918.
# Normalized cost function value=0.5550399333889169, variation=0.0002098256222863304.
# Normalized cost function value=0.5548358498997943, variation=0.00020408348912259733.
# Normalized cost function value=0.554637317179233, variation=0.00019853272056125082.
# Normalized cost function value=0.5544441513548457, variation=0.00019316582438733132.
# Normalized cost function value=0.5542561757069762, variation=0.00018797564786954268.
# Normalized cost function value=0.5540732203476494, variation=0.0001829553593267752.
# Normalized cost function value=0.5538951219155267, variation=0.0001780984321226864.
# Normalized cost function value=0.5537217232864021, variation=0.00017339862912457704.
# Normalized cost function value=0.553552873298859, variation=0.0001688499875430738.
# Normalized cost function value=0.5533884264928676, variation=0.00016444680599148054.
# Normalized cost function value=0.553228242862457, variation=0.00016018363041059303.
# Normalized cost function value=0.5530721876198227, variation=0.00015605524263428983.
# Normalized cost function value=0.5529201309715492, variation=0.00015205664827344645.
# Normalized cost function value=0.5527719479056022, variation=0.00014818306594699404.
# Normalized cost function value=0.552627517988637, variation=0.00014442991696528296.
# Normalized cost function value=0.5524867251734005, variation=0.00014079281523649012.
# Normalized cost function value=0.5523494576147704, variation=0.0001372675586300831.
# Normalized cost function value=0.5522156074953092, variation=0.00013385011946120962.
# Normalized cost function value=0.5520850708583911, variation=0.00013053663691808826.
# Normalized cost function value=0.5519577474497372, variation=0.0001273234086538455.
# Normalized cost function value=0.551833540565886, variation=0.00012420688385128553.
# Normalized cost function value=0.5517123569101168, variation=0.00012118365576918588.
# Normalized cost function value=0.5515941064547537, variation=0.000118250455363067.
# Normalized cost function value=0.5514787023098621, variation=0.00011540414489163986.
# Normalized cost function value=0.5513660605978731, variation=0.0001126417119889922.
# Normalized cost function value=0.5512561003341426, variation=0.00010996026373044643.
# Normalized cost function value=0.5511487433125503, variation=0.00010735702159236915.
# Normalized cost function value=0.5510439139963342, variation=0.00010482931621602631.
# Normalized cost function value=0.5509415394139032, variation=0.0001023745824310085.
# Normalized cost function value=0.5508415490592731, variation=9.999035463015282e-05.
# Normalized cost function value=0.5507438747965214, variation=9.767426275164581e-05.
# Normalized cost function value=0.5506484507689791, variation=9.54240275423679e-05.
# Normalized cost function value=0.5505552133118211, variation=9.32374571579464e-05.
# Normalized cost function value=0.5504641008688574, variation=9.111244296367005e-05.
# Normalized cost function value=0.5503750539127452, variation=8.904695611222646e-05.
# Normalized cost function value=0.550288014868527, variation=8.703904421825115e-05.
# Normalized cost function value=0.550202928040381, variation=8.508682814600821e-05.
# Normalized cost function value=0.5501197395419067, variation=8.318849847421816e-05.
# Normalized cost function value=0.5500383972287888, variation=8.134231311796025e-05.
# Normalized cost function value=0.5499588506345047, variation=7.954659428410782e-05.
# Normalized cost function value=0.5498810509088775, variation=7.779972562715898e-05.
# Normalized cost function value=0.5498049507587985, variation=7.610015007897264e-05.
# Normalized cost function value=0.5497305043917671, variation=7.444636703146656e-05.
# Normalized cost function value=0.5496576674615751, variation=7.283693019199955e-05.
# Normalized cost function value=0.5495863970160756, variation=7.12704454994828e-05.
# Normalized cost function value=0.5495166514472952, variation=6.974556878036609e-05.
# Normalized cost function value=0.5494483904434598, variation=6.826100383539035e-05.
# Normalized cost function value=0.549381574943023, variation=6.681550043685647e-05.
# Normalized cost function value=0.5493161670902761, variation=6.540785274689043e-05.
# Normalized cost function value=0.5492521301930882, variation=6.40368971879246e-05.
# Normalized cost function value=0.5491894286820718, variation=6.270151101639421e-05.
# Normalized cost function value=0.5491280280713832, variation=6.140061068860003e-05.
# Normalized cost function value=0.5490678949211467, variation=6.013315023645216e-05.
# Normalized cost function value=0.5490089968013179, variation=5.8898119828842965e-05.
# Normalized cost function value=0.548951302256904, variation=5.769454441384436e-05.
# Normalized cost function value=0.5488947807744575, variation=5.6521482446503235e-05.
# Normalized cost function value=0.5488394027500572, variation=5.537802440036543e-05.
# Normalized cost function value=0.5487851394584843, variation=5.4263291572875794e-05.
# Normalized cost function value=0.5487319630232419, variation=5.31764352423858e-05.
# Normalized cost function value=0.548679846388279, variation=5.2116634962851016e-05.
# Normalized cost function value=0.548628763290207, variation=5.1083098072002286e-05.
# Normalized cost function value=0.5485786882319701, variation=5.0075058236953573e-05.
# Normalized cost function value=0.5485295964573311, variation=4.909177463896519e-05.
# Normalized cost function value=0.5484814639262927, variation=4.813253103841397e-05.
# Normalized cost function value=0.5484342672915324, variation=4.719663476027147e-05.
# Normalized cost function value=0.5483879838756138, variation=4.628341591861318e-05.
# Normalized cost function value=0.5483425916490084, variation=4.539222660537856e-05.
# Normalized cost function value=0.5482980692091735, variation=4.4522439834993044e-05.
# Normalized cost function value=0.5482543957598827, variation=4.367344929079309e-05.
# Normalized cost function value=0.5482115510919929, variation=4.284466788972985e-05.
# Normalized cost function value=0.5481695155642786, variation=4.2035527714312515e-05.
# Normalized cost function value=0.5481282700853578, variation=4.124547892081498e-05.
# Normalized cost function value=0.5480877960960279, variation=4.047398932993662e-05.
# Normalized cost function value=0.5480480755524715, variation=3.972054355638743e-05.
# Normalized cost function value=0.5480090909097023, variation=3.898464276919089e-05.
# Normalized cost function value=0.5479708251060535, variation=3.826580364874044e-05.
# Normalized cost function value=0.5479332615478487, variation=3.7563558204833924e-05.
# Normalized cost function value=0.5478963840947838, variation=3.687745306490964e-05.
# Normalized cost function value=0.5478601770457966, variation=3.62070489872135e-05.
# Normalized cost function value=0.5478246251252682, variation=3.5551920528398284e-05.
# Normalized cost function value=0.547789713470058, variation=3.491165521019024e-05.
# Normalized cost function value=0.5477554276167055, variation=3.4285853352522544e-05.
# Normalized cost function value=0.5477217534889703, variation=3.3674127735139336e-05.
# Normalized cost function value=0.5476886773863089, variation=3.3076102661455664e-05.
# Normalized cost function value=0.5476561859721271, variation=3.249141418182333e-05.
# Normalized cost function value=0.5476242662628045, variation=3.191970932259203e-05.
# Normalized cost function value=0.5475929056171406, variation=3.136064566389152e-05.
# Normalized cost function value=0.5475620917257582, variation=3.0813891382375225e-05.
# Normalized cost function value=0.5475318126013816, variation=3.027912437658653e-05.
# Normalized cost function value=0.547502056568999, variation=2.9756032382644015e-05.
# Normalized cost function value=0.5474728122567597, variation=2.9244312239273818e-05.
# Normalized cost function value=0.5474440685867241, variation=2.8743670035580315e-05.
# Normalized cost function value=0.5474158147663467, variation=2.8253820377410754e-05.
# Normalized cost function value=0.5473880402799126, variation=2.7774486434095635e-05.
# Normalized cost function value=0.5473607348804976, variation=2.730539941497856e-05.
# Normalized cost function value=0.5473338885820449, variation=2.6846298452731787e-05.
# Normalized cost function value=0.5473074916518283, variation=2.6396930216554537e-05.
# Normalized cost function value=0.5472815346028832, variation=2.595704894514661e-05.
# Normalized cost function value=0.5472560081870802, variation=2.552641580300108e-05.
# Normalized cost function value=0.5472309033881575, variation=2.5104798922703786e-05.
# Normalized cost function value=0.5472062114150664, variation=2.4691973091073294e-05.
# Normalized cost function value=0.5471819236954749, variation=2.4287719591509216e-05.
# Normalized cost function value=0.5471580318695003, variation=2.389182597462014e-05.
# Normalized cost function value=0.5471345277837801, variation=2.3504085720160717e-05.
# Normalized cost function value=0.5471114034854523, variation=2.3124298327847903e-05.
# Normalized cost function value=0.547088651216558, variation=2.2752268894254968e-05.
# Normalized cost function value=0.5470662634086045, variation=2.2387807953494487e-05.
# Normalized cost function value=0.547044232677154, variation=2.2030731450572993e-05.
# Normalized cost function value=0.5470225518167116, variation=2.1680860442407912e-05.
# Normalized cost function value=0.5470012137957116, variation=2.1338020999905893e-05.
# Normalized cost function value=0.5469802117517486, variation=2.1002043963047612e-05.
# Normalized cost function value=0.5469595389868543, variation=2.06727648942584e-05.
# Normalized cost function value=0.5469391889628836, variation=2.0350023970716613e-05.
# Normalized cost function value=0.5469191552972205, variation=2.003366566316611e-05.
# Normalized cost function value=0.5468994317585183, variation=1.9723538702165477e-05.
# Normalized cost function value=0.5468800122624617, variation=1.941949605654969e-05.
# Normalized cost function value=0.5468608908679212, variation=1.9121394540522196e-05.
# Normalized cost function value=0.5468420617729576, variation=1.8829094963646043e-05.
# Normalized cost function value=0.5468235193110255, variation=1.854246193211395e-05.
# Normalized cost function value=0.5468052579473967, variation=1.8261363628813143e-05.
# Normalized cost function value=0.5467872722756952, variation=1.798567170141485e-05.
# Normalized cost function value=0.5467695570142488, variation=1.7715261446449304e-05.
# Normalized cost function value=0.5467521070030004, variation=1.745001124842105e-05.
# Normalized cost function value=0.5467349172001311, variation=1.7189802869244097e-05.
# Normalized cost function value=0.5467179826788637, variation=1.6934521267386593e-05.
# Normalized cost function value=0.5467012986246366, variation=1.6684054227167344e-05.
# Normalized cost function value=0.5466848603320651, variation=1.6438292571474555e-05.
# Normalized cost function value=0.5466686632018966, variation=1.6197130168538187e-05.
# Normalized cost function value=0.5466527027385123, variation=1.596046338425694e-05.
# Normalized cost function value=0.5466369745470664, variation=1.5728191445907314e-05.
# Normalized cost function value=0.5466214743309697, variation=1.5500216096642205e-05.
# Normalized cost function value=0.5466061978891597, variation=1.527644181009702e-05.
# Normalized cost function value=0.546591141113869, variation=1.5056775290678281e-05.
# Normalized cost function value=0.5465762999881372, variation=1.4841125731801519e-05.
# Normalized cost function value=0.5465616705833786, variation=1.4629404758603748e-05.
# Normalized cost function value=0.5465472490572469, variation=1.4421526131624951e-05.
# Normalized cost function value=0.5465330316514423, variation=1.4217405804650696e-05.
# Normalized cost function value=0.5465190146896262, variation=1.4016961816132323e-05.
# Normalized cost function value=0.5465051945750765, variation=1.3820114549645268e-05.
# Normalized cost function value=0.546491567789066, variation=1.362678601046774e-05.
# Normalized cost function value=0.5464781308885809, variation=1.3436900485164216e-05.
# Normalized cost function value=0.5464648805046629, variation=1.3250383917973174e-05.
# Normalized cost function value=0.5464518133403998, variation=1.3067164263080855e-05.
# Normalized cost function value=0.5464389261692072, variation=1.2887171192632607e-05.
# Normalized cost function value=0.5464262158331096, variation=1.2710336097621067e-05.
# Normalized cost function value=0.5464136792409927, variation=1.2536592116862977e-05.
# Normalized cost function value=0.5464013133668905, variation=1.2365874102249208e-05.
# Normalized cost function value=0.54638911524865, variation=1.2198118240491773e-05.
# Normalized cost function value=0.5463770819860213, variation=1.2033262628663444e-05.
# Normalized cost function value=0.5463652107394197, variation=1.1871246601624641e-05.
# Normalized cost function value=0.5463534987283025, variation=1.1712011117159804e-05.
# Normalized cost function value=0.5463419432297891, variation=1.1555498513393658e-05.
# Normalized cost function value=0.546330541577284, variation=1.140165250512748e-05.
# Normalized cost function value=0.5463192911591936, variation=1.1250418090358316e-05.
# Normalized cost function value=0.5463081894173382, variation=1.1101741855479297e-05.
# Normalized cost function value=0.5462972338460055, variation=1.0955571332682545e-05.
# Normalized cost function value=0.5462864219904832, variation=1.0811855522319114e-05.
# Normalized cost function value=0.546275751445932, variation=1.0670544551172334e-05.
# Normalized cost function value=0.5462652198561979, variation=1.0531589734075197e-05.
# Normalized cost function value=0.5462548249126946, variation=1.0394943503300169e-05.
# Normalized cost function value=0.5462445643531545, variation=1.0260559540120617e-05.
# Normalized cost function value=0.5462344359606986, variation=1.0128392455843738e-05.
# Normalized cost function value=0.5462244375627672, variation=9.99839793147661e-06.
# Normalized cost function value=0.5462145670299012, variation=9.870532865940973e-06.
# Normalized cost function value=0.5462048222749183, variation=9.744754982943249e-06.
# Normalized cost function value=0.5461952012519709, variation=9.621022947436941e-06.
# Normalized cost function value=0.5461857019554074, variation=9.499296563464377e-06.
# Normalized cost function value=0.5461763224190199, variation=9.379536387466025e-06.
# Normalized cost function value=0.5461670607150954, variation=9.261703924567932e-06.
# Normalized cost function value=0.5461579149533501, variation=9.145761745266157e-06.
# Normalized cost function value=0.5461488832804283, variation=9.031672921766543e-06.
# Normalized cost function value=0.5461399638787936, variation=8.919401634721602e-06.
# Normalized cost function value=0.5461311549659883, variation=8.808912805302604e-06.
# Normalized cost function value=0.5461224547938867, variation=8.70017210163887e-06.
# Normalized cost function value=0.5461138616478796, variation=8.593146007096486e-06.
# Normalized cost function value=0.5461053738461018, variation=8.487801777756765e-06.
# Normalized cost function value=0.5460969897388184, variation=8.384107283432307e-06.
# Normalized cost function value=0.5460887077074924, variation=8.282031325967942e-06.
# Normalized cost function value=0.5460805261643703, variation=8.181543122098844e-06.
# Normalized cost function value=0.5460724435515348, variation=8.082612835469405e-06.
# Normalized cost function value=0.5460644583404227, variation=7.98521111211592e-06.
# Normalized cost function value=0.546056569031093, variation=7.889309329711658e-06.
# Normalized cost function value=0.5460487741516602, variation=7.794879432809765e-06.
# Normalized cost function value=0.546041072257594, variation=7.701894066181048e-06.
# Normalized cost function value=0.5460334619312596, variation=7.61032633445069e-06.
# Normalized cost function value=0.5460259417811866, variation=7.520150072992671e-06.
# Normalized cost function value=0.5460185104415918, variation=7.431339594798914e-06.
# Normalized cost function value=0.5460111665717977, variation=7.343869794063096e-06.
# Normalized cost function value=0.5460039088556592, variation=7.2577161385201094e-06.
# Normalized cost function value=0.5459967360011504, variation=7.172854508796789e-06.
# Normalized cost function value=0.5459896467396773, variation=7.089261473081088e-06.
# Normalized cost function value=0.54598263982578, variation=7.006913897322775e-06.
# Normalized cost function value=0.5459757140364341, variation=6.925789345912925e-06.
# Normalized cost function value=0.5459688681707016, variation=6.845865732518774e-06.
# Normalized cost function value=0.5459621010492868, variation=6.767121414785748e-06.
# Normalized cost function value=0.545955411513961, variation=6.689535325787865e-06.
# Normalized cost function value=0.5459487984272098, variation=6.6130867512059766e-06.
# Normalized cost function value=0.5459422606718259, variation=6.537755383839716e-06.
# Normalized cost function value=0.5459357971504005, variation=6.463521425414953e-06.
# Normalized cost function value=0.5459294067849518, variation=6.390365448694091e-06.
# Normalized cost function value=0.5459230885164945, variation=6.318268457317089e-06.
# Normalized cost function value=0.5459168413047205, variation=6.247211774002004e-06.
# Normalized cost function value=0.545910664127539, variation=6.177177181543314e-06.
# Normalized cost function value=0.5459045559806942, variation=6.10814684476324e-06.
# Normalized cost function value=0.545898515877527, variation=6.040103167181954e-06.
# Normalized cost function value=0.5458925428484572, variation=5.973029069794578e-06.
# Normalized cost function value=0.5458866359406994, variation=5.906907757813329e-06.
# Normalized cost function value=0.5458807942178888, variation=5.841722810595584e-06.
# Normalized cost function value=0.5458750167598901, variation=5.777457998679125e-06.
# Normalized cost function value=0.5458693026622943, variation=5.71409759586583e-06.
# Normalized cost function value=0.545863651036155, variation=5.651626139302479e-06.
# Normalized cost function value=0.5458580610077347, variation=5.590028420265902e-06.
# Normalized cost function value=0.545852531718186, variation=5.529289548666938e-06.
# Normalized cost function value=0.545847062323068, variation=5.469395118029574e-06.
# Normalized cost function value=0.5458416519924281, variation=5.410330639943339e-06.
# Normalized cost function value=0.5458362999101538, variation=5.352082274256986e-06.
# Normalized cost function value=0.5458310052739789, variation=5.294636174935086e-06.
# Normalized cost function value=0.5458257672949608, variation=5.237979018080097e-06.
# Normalized cost function value=0.5458205851974217, variation=5.182097539080388e-06.
# Normalized cost function value=0.5458154582185695, variation=5.126978852243447e-06.
# Normalized cost function value=0.5458103856082885, variation=5.072610280931755e-06.
# Normalized cost function value=0.5458053666288563, variation=5.018979432280801e-06.
# Normalized cost function value=0.5458004005548682, variation=4.9660739880330595e-06.
# Normalized cost function value=0.5457954866726751, variation=4.9138821931471455e-06.
# Normalized cost function value=0.5457906242804688, variation=4.862392206317345e-06.
# Normalized cost function value=0.5457858126879375, variation=4.811592531295261e-06.
# Normalized cost function value=0.5457810512159281, variation=4.761472009340295e-06.
# Normalized cost function value=0.5457763391964918, variation=4.712019436303727e-06.
# Normalized cost function value=0.5457716759723685, variation=4.663224123291343e-06.
# Normalized cost function value=0.5457670608970547, variation=4.615075313796346e-06.
# Normalized cost function value=0.5457624933344652, variation=4.567562589485874e-06.
# Normalized cost function value=0.5457579726586126, variation=4.520675852659473e-06.
# Normalized cost function value=0.5457534982537506, variation=4.474404861953829e-06.
# Normalized cost function value=0.5457490695138648, variation=4.428739885820043e-06.
# Normalized cost function value=0.5457446858427057, variation=4.383671159069458e-06.
# Normalized cost function value=0.5457403466533335, variation=4.339189372259966e-06.
# Normalized cost function value=0.5457360513682777, variation=4.29528505574428e-06.
# Normalized cost function value=0.5457317994191726, variation=4.251949105138486e-06.
# Normalized cost function value=0.5457275902466049, variation=4.209172567715136e-06.
# Normalized cost function value=0.5457234232999444, variation=4.166946660499882e-06.
# Normalized cost function value=0.5457192980372466, variation=4.125262697773913e-06.
# Normalized cost function value=0.5457152139249658, variation=4.08411228081107e-06.
# Normalized cost function value=0.5457111704379685, variation=4.043486997340473e-06.
# Normalized cost function value=0.5457071670592181, variation=4.003378750394582e-06.
# Normalized cost function value=0.5457032032797632, variation=3.963779454885241e-06.
# Normalized cost function value=0.5456992785984691, variation=3.924681294065202e-06.
# Normalized cost function value=0.5456953925219716, variation=3.886076497483515e-06.
# Normalized cost function value=0.545691544564501, variation=3.84795747065958e-06.
# Normalized cost function value=0.5456877342477582, variation=3.8103167427916418e-06.
# Normalized cost function value=0.5456839611006995, variation=3.773147058683257e-06.
# Normalized cost function value=0.5456802246595007, variation=3.7364411987761414e-06.
# Normalized cost function value=0.5456765244673926, variation=3.7001921081580846e-06.
# Normalized cost function value=0.545672860074543, variation=3.6643928496005174e-06.
# Normalized cost function value=0.5456692310380178, variation=3.6290365251767653e-06.
# Normalized cost function value=0.5456656369213956, variation=3.594116622207544e-06.
# Normalized cost function value=0.545662077294967, variation=3.5596264286175128e-06.
# Normalized cost function value=0.5456585517354404, variation=3.525559526540434e-06.
# Normalized cost function value=0.5456550598258001, variation=3.491909640329638e-06.
# Normalized cost function value=0.5456516011553676, variation=3.4586704324990336e-06.
# Normalized cost function value=0.5456481753194651, variation=3.4258359025152174e-06.
# Normalized cost function value=0.5456447819195285, variation=3.3933999366020373e-06.
# Normalized cost function value=0.545641420562874, variation=3.3613566544632434e-06.
# Normalized cost function value=0.5456380908625992, variation=3.3297002748344795e-06.
# Normalized cost function value=0.5456347924375119, variation=3.2984250872836185e-06.
# Normalized cost function value=0.5456315249119992, variation=3.267525512717917e-06.
# Normalized cost function value=0.5456282879159955, variation=3.236996003685988e-06.
# Normalized cost function value=0.545625081084871, variation=3.2068311245359027e-06.
# Normalized cost function value=0.545621904059255, variation=3.177025615919149e-06.
# Normalized cost function value=0.5456187564849725, variation=3.147574282547083e-06.
# Normalized cost function value=0.5456156380131472, variation=3.1184718253252086e-06.
# Normalized cost function value=0.545612548299769, variation=3.0897133781460084e-06.
# Normalized cost function value=0.5456094870058845, variation=3.061293884498717e-06.
# Normalized cost function value=0.545606453797451, variation=3.0332084335338294e-06.
# Normalized cost function value=0.545603448345154, variation=3.0054522970335285e-06.
# Normalized cost function value=0.5456004703244487, variation=2.9780207052576557e-06.
# Normalized cost function value=0.5455975194153685, variation=2.950909080201569e-06.
# Normalized cost function value=0.5455945953025558, variation=2.9241128126633598e-06.
# Normalized cost function value=0.5455916976751174, variation=2.8976274384362455e-06.
# Normalized cost function value=0.5455888262266195, variation=2.8714484978653587e-06.
# Normalized cost function value=0.545585980654835, variation=2.8455717845377038e-06.
# Normalized cost function value=0.545583160661961, variation=2.819992873992483e-06.
# Normalized cost function value=0.5455803659542598, variation=2.7947077011480914e-06.
# Normalized cost function value=0.5455775962421932, variation=2.769712066696961e-06.
# Normalized cost function value=0.5455748512401587, variation=2.74500203445438e-06.
# Normalized cost function value=0.5455721306667817, variation=2.720573377024138e-06.
# Normalized cost function value=0.5455694342443445, variation=2.696422437220569e-06.
# Normalized cost function value=0.5455667616991499, variation=2.6725451945930345e-06.
# Normalized cost function value=0.545564112761152, variation=2.6489379978400507e-06.
# Normalized cost function value=0.5455614871642431, variation=2.625596908889527e-06.
# Normalized cost function value=0.5455588846458296, variation=2.6025184135525237e-06.
# Normalized cost function value=0.5455563049469696, variation=2.5796988599724457e-06.
# Normalized cost function value=0.5455537478123049, variation=2.5571346646824367e-06.
# Normalized cost function value=0.5455512129899469, variation=2.5348223580135e-06.
# Normalized cost function value=0.5455487002313726, variation=2.512758574324536e-06.
# Normalized cost function value=0.5455462092915913, variation=2.4909397813299705e-06.
# Normalized cost function value=0.545543739928872, variation=2.4693627193039802e-06.
# Normalized cost function value=0.5455412919047158, variation=2.448024156165296e-06.
# Normalized cost function value=0.545538864983945, variation=2.426920770792762e-06.
# Normalized cost function value=0.545536458934484, variation=2.406049461001203e-06.
# Normalized cost function value=0.5455340735273781, variation=2.385407105842674e-06.
# Normalized cost function value=0.5455317085367618, variation=2.364990616343654e-06.
# Normalized cost function value=0.5455293637398364, variation=2.344796925402015e-06.
# Normalized cost function value=0.5455270389166735, variation=2.324823162869194e-06.
# Normalized cost function value=0.5455247338504061, variation=2.3050662674162226e-06.
# Normalized cost function value=0.5455224483269462, variation=2.2855234599328256e-06.
# Normalized cost function value=0.5455201821351212, variation=2.2661918249733404e-06.
# Normalized cost function value=0.5455179350664842, variation=2.247068637051264e-06.
# Normalized cost function value=0.5455157069153884, variation=2.2281510957400386e-06.
# Normalized cost function value=0.5455134974788695, variation=2.2094365189628817e-06.
# Normalized cost function value=0.5455113065566344, variation=2.190922235079107e-06.
# Normalized cost function value=0.5455091339510334, variation=2.1726056009807593e-06.
# Normalized cost function value=0.5455069794669716, variation=2.1544840618226146e-06.
# Normalized cost function value=0.5455048429119518, variation=2.1365550197938177e-06.
# Normalized cost function value=0.5455027240958641, variation=2.118816087692821e-06.
# Normalized cost function value=0.5455006228311938, variation=2.1012646702622817e-06.
# Normalized cost function value=0.5454985389328203, variation=2.0838983735282923e-06.
# Normalized cost function value=0.5454964722179704, variation=2.066714849924267e-06.
# Normalized cost function value=0.5454944225062629, variation=2.0497117074746996e-06.
# Normalized cost function value=0.5454923896195903, variation=2.0328866725538575e-06.
# Normalized cost function value=0.5454903733822536, variation=2.0162373367549336e-06.
# Normalized cost function value=0.5454883736206343, variation=1.999761619297935e-06.
# Normalized cost function value=0.5454863901634223, variation=1.9834572120291938e-06.
# Normalized cost function value=0.5454844228414863, variation=1.9673219359139793e-06.
# Normalized cost function value=0.5454824714878739, variation=1.9513536124726727e-06.
# Normalized cost function value=0.5454805359376503, variation=1.93555022354186e-06.
# Normalized cost function value=0.5454786160280944, variation=1.919909555891941e-06.
# Normalized cost function value=0.545476711598448, variation=1.9044296464265642e-06.
# Normalized cost function value=0.545474822489941, variation=1.8891085070693592e-06.
# Normalized cost function value=0.5454729485459543, variation=1.8739439866521934e-06.
# Normalized cost function value=0.545471089611677, variation=1.8589342772878936e-06.
# Normalized cost function value=0.5454692455343253, variation=1.8440773517092168e-06.
# Normalized cost function value=0.5454674161629572, variation=1.8293713680561652e-06.
# Normalized cost function value=0.545465601348509, variation=1.8148144482754702e-06.
# Normalized cost function value=0.5454638009439196, variation=1.8004045894137732e-06.
# Normalized cost function value=0.5454620148036533, variation=1.786140266246683e-06.
# Normalized cost function value=0.5454602427843428, variation=1.7720193105086324e-06.
# Normalized cost function value=0.545458484744021, variation=1.7580403217642981e-06.
# Normalized cost function value=0.5454567405427582, variation=1.7442012628654524e-06.
# Normalized cost function value=0.5454550100421682, variation=1.7305005899359571e-06.
# Normalized cost function value=0.5454532931056234, variation=1.7169365448266305e-06.
# Normalized cost function value=0.5454515895981434, variation=1.703507479966504e-06.
# Normalized cost function value=0.5454498993865006, variation=1.6902116428685332e-06.
# Normalized cost function value=0.545448222338877, variation=1.677047623549477e-06.
# Normalized cost function value=0.5454465583252578, variation=1.6640136192291877e-06.
# Normalized cost function value=0.5454449072170646, variation=1.6511081931680494e-06.
# Normalized cost function value=0.5454432688873818, variation=1.6383296828070826e-06.
# Normalized cost function value=0.5454416432106683, variation=1.6256767134681382e-06.
# Normalized cost function value=0.5454400300630854, variation=1.613147582957275e-06.
# Normalized cost function value=0.5454384293221812, variation=1.6007409041618459e-06.
# Normalized cost function value=0.5454368408669478, variation=1.588455233458852e-06.
# Normalized cost function value=0.54543526457789, variation=1.576289057725333e-06.
# Normalized cost function value=0.54543370033684, variation=1.56424105002273e-06.
# Normalized cost function value=0.5454321480271556, variation=1.5523096844605178e-06.
# Normalized cost function value=0.5454306075334698, variation=1.540493685725508e-06.
# Normalized cost function value=0.5454290787418118, variation=1.5287916580453143e-06.
# Normalized cost function value=0.5454275615396783, variation=1.5172021334830532e-06.
# Normalized cost function value=0.5454260558156908, variation=1.5057239874938233e-06.
# Normalized cost function value=0.545424561459941, variation=1.494355749809273e-06.
# Normalized cost function value=0.5454230783636722, variation=1.4830962687950588e-06.
# Normalized cost function value=0.5454216064195705, variation=1.4719441017163604e-06.
# Normalized cost function value=0.5454201455214507, variation=1.4608981198094284e-06.
# Normalized cost function value=0.545418695564355, variation=1.4499570957227093e-06.
# Normalized cost function value=0.545417256444634, variation=1.439119720947346e-06.
# Normalized cost function value=0.5454158280598103, variation=1.4283848237539587e-06.
# Normalized cost function value=0.5454144103085043, variation=1.4177513059099311e-06.
# Normalized cost function value=0.545413003090732, variation=1.4072177723090107e-06.
# Normalized cost function value=0.545411606307356, variation=1.3967833760730741e-06.
# Normalized cost function value=0.5454102198606741, variation=1.3864466819057952e-06.
# Normalized cost function value=0.5454088436538234, variation=1.376206850700612e-06.
# Normalized cost function value=0.5454074775913131, variation=1.366062510221866e-06.
# Normalized cost function value=0.5454061215785737, variation=1.356012739428536e-06.
# Normalized cost function value=0.54540477552221, variation=1.3460563637046619e-06.
# Normalized cost function value=0.5454034393298571, variation=1.3361923528742992e-06.
# Normalized cost function value=0.545402112910133, variation=1.3264197241680264e-06.
# Normalized cost function value=0.5454007961728207, variation=1.316737312295757e-06.
# Normalized cost function value=0.5453994890285941, variation=1.3071442265255584e-06.
# Normalized cost function value=0.5453981913892331, variation=1.2976393610752979e-06.
# Normalized cost function value=0.5453969031674346, variation=1.288221798456668e-06.
# Normalized cost function value=0.5453956242769746, variation=1.278890459976978e-06.
# Normalized cost function value=0.5453943546324651, variation=1.269644509527268e-06.
# Normalized cost function value=0.5453930941496269, variation=1.260482838216781e-06.
# Normalized cost function value=0.5453918427449127, variation=1.2514047141864992e-06.
# Normalized cost function value=0.5453906003359841, variation=1.2424089286255935e-06.
# ...
# Normalized cost function value=0.5452401305210024, variation=3.003906772214293e-07.
# Normalized cost function value=0.5452398316418825, variation=2.98879119897677e-07.
# Normalized cost function value=0.545239534264691, variation=2.973771915382173e-07.
# Normalized cost function value=0.5452392383801191, variation=2.9588457184370753e-07.
# Normalized cost function value=0.5452389439786659, variation=2.944014532157979e-07.
# Normalized cost function value=0.5452386510511118, variation=2.929275541019294e-07.
# Normalized cost function value=0.5452383595881798, variation=2.9146293201165463e-07.
# Normalized cost function value=0.5452380695806707, variation=2.900075091183396e-07.
# Normalized cost function value=0.5452377810195665, variation=2.885611041225644e-07.
# Normalized cost function value=0.545237493895735, variation=2.871238315993452e-07.
# Normalized cost function value=0.5452372082002316, variation=2.8569550336587923e-07.
# Normalized cost function value=0.545236923924172, variation=2.8427605958114555e-07.
# Normalized cost function value=0.545236641058711, variation=2.8286546105427135e-07.
# Normalized cost function value=0.5452363595950521, variation=2.8146365882442126e-07.
# Normalized cost function value=0.5452360795245469, variation=2.80070505231933e-07.
# Normalized cost function value=0.5452358008384608, variation=2.7868608609704637e-07.
# Normalized cost function value=0.5452355235282653, variation=2.773101954733903e-07.
# Normalized cost function value=0.5452352475854009, variation=2.759428644472095e-07.
# Normalized cost function value=0.5452349730014412, variation=2.745839596807187e-07.
# Normalized cost function value=0.5452346997680179, variation=2.732334233312983e-07.
# Normalized cost function value=0.5452344278767068, variation=2.7189131102112185e-07.
# Normalized cost function value=0.545234157319318, variation=2.7055738882619806e-07.
# Normalized cost function value=0.5452338880875816, variation=2.692317364605401e-07.
# Normalized cost function value=0.5452336201733384, variation=2.679142431238901e-07.
# Normalized cost function value=0.5452333535685345, variation=2.6660480390017227e-07.
# Normalized cost function value=0.5452330882650943, variation=2.6530344021669094e-07.
# Normalized cost function value=0.54523282425504, variation=2.6401005426279767e-07.
# Normalized cost function value=0.5452325615304686, variation=2.627245714315052e-07.
# Normalized cost function value=0.5452323000835012, variation=2.6144696740892925e-07.
# Normalized cost function value=0.5452320399063051, variation=2.6017719612081436e-07.
# Normalized cost function value=0.5452317809911362, variation=2.5891516886034083e-07.
# Normalized cost function value=0.545231523330357, variation=2.576607792681429e-07.
# Normalized cost function value=0.5452312669162314, variation=2.5641412559895826e-07.
# Normalized cost function value=0.5452310117412157, variation=2.5517501567318135e-07.
# Normalized cost function value=0.5452307577977871, variation=2.539434286186193e-07.
# Normalized cost function value=0.5452305050784024, variation=2.5271938464133115e-07.
# Normalized cost function value=0.5452302535757406, variation=2.515026618077343e-07.
# Normalized cost function value=0.5452300032823233, variation=2.50293417325409e-07.
# Normalized cost function value=0.5452297541908943, variation=2.4909142903872805e-07.
# Normalized cost function value=0.5452295062941701, variation=2.4789672414815556e-07.
# Normalized cost function value=0.5452292595848881, variation=2.4670928200354325e-07.
# Normalized cost function value=0.5452290140559384, variation=2.4552894972718065e-07.
# Normalized cost function value=0.5452287697001695, variation=2.4435576884140886e-07.
# Normalized cost function value=0.5452285265105341, variation=2.431896354293528e-07.
# Normalized cost function value=0.5452282844800102, variation=2.4203052395588287e-07.
# Normalized cost function value=0.5452280436016279, variation=2.4087838224051694e-07.
# Normalized cost function value=0.545227803868431, variation=2.397331969605787e-07.
# Normalized cost function value=0.5452275652736623, variation=2.3859476860899065e-07.
# Normalized cost function value=0.5452273278103592, variation=2.3746330313212383e-07.
# Normalized cost function value=0.5452270914718436, variation=2.3633851564675012e-07.
# Normalized cost function value=0.5452268562513551, variation=2.3522048842039567e-07.
# Normalized cost function value=0.5452266221422282, variation=2.3410912697308106e-07.
# Normalized cost function value=0.5452263891378403, variation=2.3300438789508604e-07.
# Normalized cost function value=0.5452261572315494, variation=2.3190629083735814e-07.
# Normalized cost function value=0.5452259264168889, variation=2.3081466049568178e-07.
# Normalized cost function value=0.5452256966873384, variation=2.2972955049382904e-07.
# Normalized cost function value=0.5452254680364509, variation=2.286508875570803e-07.
# Normalized cost function value=0.5452252404577677, variation=2.27578683231755e-07.
# Normalized cost function value=0.5452250139450769, variation=2.265126907152748e-07.
# Normalized cost function value=0.5452247884918617, variation=2.2545321520794914e-07.
# Normalized cost function value=0.545224564091988, variation=2.2439987368283454e-07.
# Normalized cost function value=0.5452243407392098, variation=2.2335277827245648e-07.
# Normalized cost function value=0.5452241184273307, variation=2.2231187912780115e-07.
# Normalized cost function value=0.5452238971502197, variation=2.212771109677547e-07.
# Normalized cost function value=0.5452236769017459, variation=2.2024847379231716e-07.
# Normalized cost function value=0.5452234576758557, variation=2.1922589021894368e-07.
# Normalized cost function value=0.5452232394665433, variation=2.182093123970219e-07.
# Normalized cost function value=0.545223022267838, variation=2.1719870524350426e-07.
# Normalized cost function value=0.5452228060738191, variation=2.1619401890937695e-07.
# Normalized cost function value=0.5452225908785612, variation=2.1519525794655436e-07.
# Normalized cost function value=0.5452223766762867, variation=2.1420227447332962e-07.
# Normalized cost function value=0.5452221634611044, variation=2.1321518228756275e-07.
# Normalized cost function value=0.5452219512272384, variation=2.122338660370815e-07.
# Normalized cost function value=0.545221739969036, variation=2.1125820237610782e-07.
# Normalized cost function value=0.5452215296807396, variation=2.1028829644276215e-07.
# Normalized cost function value=0.5452213203566662, variation=2.0932407340801262e-07.
# Normalized cost function value=0.5452211119912489, variation=2.0836541725355318e-07.
# Normalized cost function value=0.5452209045789291, variation=2.0741231976373342e-07.
# Normalized cost function value=0.545220698114183, variation=2.064647461885727e-07.
# Normalized cost function value=0.545220492591435, variation=2.0552274793139702e-07.
# Normalized cost function value=0.5452202880052376, variation=2.0458619742758088e-07.
# Normalized cost function value=0.5452200843501828, variation=2.036550548201177e-07.
# Normalized cost function value=0.5452198816208628, variation=2.0272931999798516e-07.
# Normalized cost function value=0.5452196798119675, variation=2.018088952615571e-07.
# Normalized cost function value=0.5452194789181221, variation=2.0089384544785815e-07.
# Normalized cost function value=0.5452192789340905, variation=1.9998403155696565e-07.
# Normalized cost function value=0.5452190798545814, variation=1.990795091000308e-07.
# Normalized cost function value=0.5452188816744222, variation=1.981801591721677e-07.
# Normalized cost function value=0.5452186843884215, variation=1.9728600075819003e-07.
# Normalized cost function value=0.5452184879914134, variation=1.9639700810092364e-07.
# Normalized cost function value=0.5452182924783743, variation=1.9551303909182138e-07.
# Normalized cost function value=0.5452180978440883, variation=1.9463428602151112e-07.
# Normalized cost function value=0.5452179040836505, variation=1.9376043780550134e-07.
# Normalized cost function value=0.5452177111919844, variation=1.9289166608427166e-07.
# Normalized cost function value=0.5452175191641448, variation=1.9202783951843827e-07.
# Normalized cost function value=0.5452173279952138, variation=1.9116893101855936e-07.
# Normalized cost function value=0.5452171376802281, variation=1.9031498577071204e-07.
# Normalized cost function value=0.5452169482143673, variation=1.8946586077817074e-07.
# Normalized cost function value=0.5452167595927709, variation=1.8862159634203124e-07.
# Normalized cost function value=0.5452165718106172, variation=1.8778215371551e-07.
# Normalized cost function value=0.5452163848631331, variation=1.869474841598162e-07.
# Normalized cost function value=0.5452161987456208, variation=1.8611751229080653e-07.
# Normalized cost function value=0.5452160134533277, variation=1.8529229306452066e-07.
# Normalized cost function value=0.5452158289815491, variation=1.8447177863034625e-07.
# Normalized cost function value=0.5452156453257221, variation=1.8365582699075844e-07.
# Normalized cost function value=0.5452154624811394, variation=1.8284458269679504e-07.
# Normalized cost function value=0.5452152804432168, variation=1.8203792262472263e-07.
# Normalized cost function value=0.5452150992074387, variation=1.8123577805173596e-07.
# Normalized cost function value=0.5452149187692661, variation=1.8043817262558548e-07.
# Normalized cost function value=0.5452147391241903, variation=1.79645075815138e-07.
# Normalized cost function value=0.5452145602677283, variation=1.7885646197424165e-07.
# Normalized cost function value=0.5452143821954906, variation=1.7807223773314007e-07.
# Normalized cost function value=0.5452142049030467, variation=1.7729244383701825e-07.
# Normalized cost function value=0.5452140283859298, variation=1.7651711692323602e-07.
# Normalized cost function value=0.5452138526399178, variation=1.7574601196557182e-07.
# Normalized cost function value=0.5452136776606205, variation=1.749792973848585e-07.
# Normalized cost function value=0.5452135034437268, variation=1.7421689368912752e-07.
# Normalized cost function value=0.5452133299849694, variation=1.7345875735763627e-07.
# Normalized cost function value=0.5452131572801687, variation=1.7270480068276584e-07.
# Normalized cost function value=0.5452129853250938, variation=1.7195507495681994e-07.
# Normalized cost function value=0.5452128141155057, variation=1.7120958806238207e-07.
# Normalized cost function value=0.5452126436472317, variation=1.7046827405220455e-07.
# Normalized cost function value=0.5452124739162497, variation=1.6973098193595604e-07.
# Normalized cost function value=0.5452123049183583, variation=1.6899789145874422e-07.
# Normalized cost function value=0.5452121366495574, variation=1.6826880089304552e-07.
# Normalized cost function value=0.5452119691057551, variation=1.6754380227634869e-07.
# Normalized cost function value=0.5452118022829356, variation=1.6682281944735422e-07.
# Normalized cost function value=0.5452116361770388, variation=1.661058968149831e-07.
# Normalized cost function value=0.5452114707841688, variation=1.6539287006622772e-07.
# Normalized cost function value=0.5452113061003524, variation=1.6468381636158824e-07.
# Normalized cost function value=0.5452111421217055, variation=1.6397864688322272e-07.
# Normalized cost function value=0.545210978844248, variation=1.6327745755440048e-07.
# Normalized cost function value=0.5452108162641947, variation=1.625800533089361e-07.
# Normalized cost function value=0.5452106543776493, variation=1.6188654539117664e-07.
# Normalized cost function value=0.5452104931808177, variation=1.6119683154958153e-07.
# Normalized cost function value=0.5452103326698756, variation=1.6051094209323935e-07.
# Normalized cost function value=0.5452101728410913, variation=1.5982878431852754e-07.
# Normalized cost function value=0.5452100136906706, variation=1.5915042073100238e-07.
# Normalized cost function value=0.5452098552149123, variation=1.5847575829397442e-07.
# Normalized cost function value=0.5452096974101039, variation=1.578048083317185e-07.
# Normalized cost function value=0.5452095402725963, variation=1.5713750767254453e-07.
# Normalized cost function value=0.5452093837987146, variation=1.5647388162953746e-07.
# Normalized cost function value=0.5452092279848555, variation=1.5581385914842372e-07.
# Normalized cost function value=0.5452090728273642, variation=1.5515749129946244e-07.
# Normalized cost function value=0.5452089183226821, variation=1.5450468204836199e-07.
# Normalized cost function value=0.5452087644672583, variation=1.538554238456058e-07.
# Normalized cost function value=0.5452086112575565, variation=1.5320970181420535e-07.
# Normalized cost function value=0.5452084586900251, variation=1.5256753138626067e-07.
# Normalized cost function value=0.5452083067612358, variation=1.5192878932701603e-07.
# Normalized cost function value=0.5452081554676499, variation=1.512935858816178e-07.
# Normalized cost function value=0.5452080048058464, variation=1.5066180347744762e-07.
# Normalized cost function value=0.5452078547724171, variation=1.5003342934694075e-07.
# Normalized cost function value=0.5452077053639138, variation=1.4940850323608146e-07.
# Normalized cost function value=0.5452075565770043, variation=1.4878690957065288e-07.
# Normalized cost function value=0.5452074084082787, variation=1.4816872551115523e-07.
# Normalized cost function value=0.5452072608544302, variation=1.4755384858400333e-07.
# Normalized cost function value=0.5452071139121443, variation=1.4694228589462455e-07.
# Normalized cost function value=0.545206967578017, variation=1.4633412726006156e-07.
# Normalized cost function value=0.5452068218489314, variation=1.4572908557664022e-07.
# Normalized cost function value=0.5452066767215382, variation=1.4512739321403956e-07.
# Normalized cost function value=0.5452065321925896, variation=1.4452894858685283e-07.
# Normalized cost function value=0.5452063882589225, variation=1.4393366709608557e-07.
# Normalized cost function value=0.5452062449172733, variation=1.433416492169215e-07.
# Normalized cost function value=0.5452061021645271, variation=1.427527461794753e-07.
# Normalized cost function value=0.5452059599975018, variation=1.421670253742846e-07.
# Normalized cost function value=0.5452058184130086, variation=1.4158449312962063e-07.
# Normalized cost function value=0.5452056774080477, variation=1.410049609296138e-07.
# Normalized cost function value=0.545205536979406, variation=1.4042864171504021e-07.
# Normalized cost function value=0.5452053971240639, variation=1.3985534208504902e-07.
# Normalized cost function value=0.5452052578389572, variation=1.3928510667060578e-07.
# Normalized cost function value=0.5452051191210171, variation=1.3871794013464722e-07.
# Normalized cost function value=0.5452049809672391, variation=1.381537779732156e-07.
# Normalized cost function value=0.5452048433746612, variation=1.3759257788681367e-07.
# Normalized cost function value=0.5452047063402428, variation=1.370344184792316e-07.
# Normalized cost function value=0.545204569861013, variation=1.364792298064188e-07.
# Normalized cost function value=0.5452044339340433, variation=1.3592696967990037e-07.
# Normalized cost function value=0.5452042985564496, variation=1.353775936907553e-07.
# Normalized cost function value=0.5452041637252469, variation=1.3483120264723425e-07.
# Normalized cost function value=0.5452040294375514, variation=1.3428769551904196e-07.
# Normalized cost function value=0.5452038956905224, variation=1.3374702900748048e-07.
# Normalized cost function value=0.5452037624813301, variation=1.3320919234338646e-07.
# Normalized cost function value=0.5452036298070588, variation=1.3267427123597741e-07.
# Normalized cost function value=0.5452034976649113, variation=1.3214214755752351e-07.
# Normalized cost function value=0.5452033660521083, variation=1.3161280298934486e-07.
# Normalized cost function value=0.5452032349658333, variation=1.3108627494595737e-07.
# Normalized cost function value=0.5452031044033558, variation=1.3056247749609895e-07.
# Normalized cost function value=0.5452029743618687, variation=1.30041487134136e-07.
# Normalized cost function value=0.5452028448386573, variation=1.2952321137849054e-07.
# Normalized cost function value=0.545202715831006, variation=1.2900765133938563e-07.

# %%
errors[-1], len(errors)
# Out:
# (0.545202715831006, 1000)

# %% [markdown]
# ### Beta = 1 (Kullback-Leibler Divergence)

# %%
rank = 2
U_lines = 500
V_col = 250

U_0 = np.random.rand(U_lines, rank)
V_0 = np.random.rand(rank, V_col)
M = U_0@V_0 + 1e-2 * np.random.rand(U_lines, V_col)
U, V, errors, toc = nmf.nmf(M, rank, init = "random", n_iter_max = 1000, tol = 1e-8,update_rule = "mu",beta = 1,
           sparsity_coefficients = [None, None], fixed_modes = [], normalize = [False, False],
           verbose=True, return_costs = True)
# Out:
# Normalized cost function value=2302.6329613356233
# Normalized cost function value=1880.21299832267, variation=422.4199630129533.
# Normalized cost function value=1650.1270555237406, variation=230.0859427989294.
# Normalized cost function value=1511.883428170004, variation=138.24362735373666.
# Normalized cost function value=1422.5809811161223, variation=89.30244705388168.
# Normalized cost function value=1361.229411620643, variation=61.351569495479225.
# Normalized cost function value=1316.5876733641196, variation=44.64173825652347.
# Normalized cost function value=1282.1359139965114, variation=34.45175936760825.
# Normalized cost function value=1253.7825616912448, variation=28.353352305266526.
# Normalized cost function value=1228.729651755431, variation=25.052909935813886.
# Normalized cost function value=1204.870062928895, variation=23.859588826535855.
# Normalized cost function value=1180.4482536887108, variation=24.421809240184302.
# Normalized cost function value=1153.8645056823786, variation=26.583748006332144.
# Normalized cost function value=1123.5706123361022, variation=30.29389334627649.
# Normalized cost function value=1088.039466435524, variation=35.53114590057817.
# Normalized cost function value=1045.8093008029816, variation=42.230165632542366.
# Normalized cost function value=995.6097205160022, variation=50.199580286979426.
# Normalized cost function value=936.5690071295639, variation=59.040713386438256.
# Normalized cost function value=868.4769605278556, variation=68.09204660170838.
# Normalized cost function value=792.0374819871137, variation=76.4394785407419.
# Normalized cost function value=709.0080184350422, variation=83.02946355207143.
# Normalized cost function value=622.1221941148974, variation=86.88582432014482.
# Normalized cost function value=534.7548194002022, variation=87.36737471469519.
# Normalized cost function value=450.39947830683667, variation=84.35534109336555.
# Normalized cost function value=372.120405959384, variation=78.27907234745265.
# Normalized cost function value=302.14617450785937, variation=69.97423145152464.
# Normalized cost function value=241.69536703886305, variation=60.45080746899632.
# Normalized cost function value=191.027106782549, variation=50.668260256314056.
# Normalized cost function value=149.6457633082714, variation=41.3813434742776.
# Normalized cost function value=116.56955228434435, variation=33.076211023927044.
# Normalized cost function value=90.5856229543755, variation=25.98392932996886.
# Normalized cost function value=70.44564213019815, variation=20.139980824177343.
# Normalized cost function value=54.98968904019087, variation=15.455953090007284.
# Normalized cost function value=43.2088575048983, variation=11.78083153529257.
# Normalized cost function value=34.26501948331249, variation=8.943838021585805.
# Normalized cost function value=27.484885679939786, variation=6.780133803372706.
# Normalized cost function value=22.340978489015768, variation=5.143907190924018.
# Normalized cost function value=18.42772840423331, variation=3.913250084782458.
# Normalized cost function value=15.437541972860728, variation=2.9901864313725817.
# Normalized cost function value=13.139350230809473, variation=2.298191742051255.
# Normalized cost function value=11.360630327617848, variation=1.7787199031916252.
# Normalized cost function value=9.972999081164225, variation=1.3876312464536227.
# Normalized cost function value=8.88102179552054, variation=1.0919772856436847.
# Normalized cost function value=8.013704510090749, variation=0.8673172854297917.
# Normalized cost function value=7.318121122621001, variation=0.6955833874697479.
# Normalized cost function value=6.754685958204154, variation=0.5634351644168474.
# Normalized cost function value=6.293667898306985, variation=0.46101805989716826.
# Normalized cost function value=5.912628221086732, variation=0.38103967722025356.
# Normalized cost function value=5.5945395025662625, variation=0.31808871852046927.
# Normalized cost function value=5.326403966293357, variation=0.2681355362729052.
# Normalized cost function value=5.098237079335217, variation=0.22816688695814058.
# Normalized cost function value=4.90231801404192, variation=0.19591906529329695.
# Normalized cost function value=4.732635187741489, variation=0.16968282630043063.
# Normalized cost function value=4.584474615498446, variation=0.14816057224304302.
# Normalized cost function value=4.4541130471148875, variation=0.1303615683835586.
# Normalized cost function value=4.338588201301019, variation=0.11552484581386846.
# Normalized cost function value=4.23552590989684, variation=0.10306229140417944.
# Normalized cost function value=4.143009422664754, variation=0.09251648723208561.
# Normalized cost function value=4.0594800685364945, variation=0.08352935412825957.
# Normalized cost function value=3.983661335996983, variation=0.07581873253951166.
# Normalized cost function value=3.914500522501416, variation=0.06916081349556702.
# Normalized cost function value=3.8511236260361685, variation=0.06337689646524725.
# Normalized cost function value=3.792800266516016, variation=0.05832335952015244.
# Normalized cost function value=3.738916242674188, variation=0.05388402384182811.
# Normalized cost function value=3.6889519322721585, variation=0.04996431040202953.
# Normalized cost function value=3.6424651882643837, variation=0.04648674400777475.
# Normalized cost function value=3.5990777132915297, variation=0.043387474972854.
# Normalized cost function value=3.558464140242669, variation=0.04061357304886082.
# Normalized cost function value=3.5203432299345256, variation=0.03812091030814324.
# Normalized cost function value=3.4844707344762105, variation=0.03587249545831517.
# Normalized cost function value=3.450633578502836, variation=0.03383715597337433.
# Normalized cost function value=3.418645088892085, variation=0.03198848961075118.
# Normalized cost function value=3.3883410632128173, variation=0.03030402567926771.
# Normalized cost function value=3.359576512726798, variation=0.028764550486019225.
# Normalized cost function value=3.3322229507533705, variation=0.02735356197342753.
# Normalized cost function value=3.3061661242073814, variation=0.026056826545989065.
# Normalized cost function value=3.281304107061346, variation=0.02486201714603542.
# Normalized cost function value=3.257545690803563, variation=0.023758416257782855.
# Normalized cost function value=3.2348090197516663, variation=0.022736671051896806.
# Normalized cost function value=3.2130204291453928, variation=0.021788590606273583.
# Normalized cost function value=3.1921134519058723, variation=0.020906977239520508.
# Normalized cost function value=3.1720279662814868, variation=0.020085485624385502.
# Normalized cost function value=3.1527094616542426, variation=0.01931850462724416.
# Normalized cost function value=3.1341084038392317, variation=0.01860105781501087.
# Normalized cost function value=3.116179684479396, variation=0.017928719359835643.
# Normalized cost function value=3.098882141784461, variation=0.017297542694934886.
# Normalized cost function value=3.0821781420140537, variation=0.016703999770407485.
# Normalized cost function value=3.066033212861834, variation=0.016144929152219767.
# Normalized cost function value=3.0504157213350553, variation=0.015617491526778604.
# Normalized cost function value=3.035296589907534, variation=0.015119131427521193.
# Normalized cost function value=3.02064904570027, variation=0.014647544207264218.
# Normalized cost function value=3.0064483982531156, variation=0.014200647447154324.
# Normalized cost function value=2.9926718421223755, variation=0.013776556130740136.
# Normalized cost function value=2.979298281099948, variation=0.01337356102242726.
# Normalized cost function value=2.966308171318687, variation=0.01299010978126125.
# Normalized cost function value=2.953683380900765, variation=0.012624790417921972.
# Normalized cost function value=2.9414070641382537, variation=0.012276316762511286.
# Normalized cost function value=2.929463548472648, variation=0.011943515665605808.
# Normalized cost function value=2.917838232777268, variation=0.011625315695380056.
# Normalized cost function value=2.9065174956476167, variation=0.011320737129651093.
# Normalized cost function value=2.8954886125728265, variation=0.011028883074790219.
# Normalized cost function value=2.8847396810102253, variation=0.01074893156260126.
# Normalized cost function value=2.8742595525061394, variation=0.010480128504085862.
# Normalized cost function value=2.864037771115513, variation=0.010221781390626461.
# Normalized cost function value=2.8540645174621617, variation=0.009973253653351222.
# Normalized cost function value=2.844330557862845, variation=0.009733959599316666.
# Normalized cost function value=2.8348271980039805, variation=0.009503359858864524.
# Normalized cost function value=2.8255462407213146, variation=0.00928095728266598.
# Normalized cost function value=2.816479947482184, variation=0.009066293239130552.
# Normalized cost function value=2.8076210032161377, variation=0.008858944266046276.
# Normalized cost function value=2.7989624841768026, variation=0.008658519039335122.
# Normalized cost function value=2.7904978285534283, variation=0.008464655623374284.
# Normalized cost function value=2.782220809579657, variation=0.008277018973771533.
# Normalized cost function value=2.7741255109124756, variation=0.008095298667181172.
# Normalized cost function value=2.766206304078565, variation=0.007919206833910675.
# Normalized cost function value=2.758457827804583, variation=0.007748476273981897.
# Normalized cost function value=2.750874969066051, variation=0.007582858738532039.
# Normalized cost function value=2.743452845705485, variation=0.007422123360565802.
# Normalized cost function value=2.7361867904843793, variation=0.007266055221105905.
# Normalized cost function value=2.7290723364462792, variation=0.007114454038100071.
# Normalized cost function value=2.7221052034793694, variation=0.0069671329669098725.
# Normalized cost function value=2.7152812859768996, variation=0.006823917502469801.
# Normalized cost function value=2.7085966415027145, variation=0.006684644474185042.
# Normalized cost function value=2.702047480377584, variation=0.006549161125130709.
# Normalized cost function value=2.69563015610876, variation=0.0064173242688236876.
# Normalized cost function value=2.689341156592221, variation=0.00628899951653894.
# Normalized cost function value=2.6831770960224732, variation=0.006164060569747942.
# Normalized cost function value=2.6771347074511738, variation=0.006042388571299462.
# Normalized cost function value=2.671210835938648, variation=0.0059238715125258246.
# Normalized cost function value=2.66540243225026, variation=0.005808403688388086.
# Normalized cost function value=2.659706547049553, variation=0.005695885200706741.
# Normalized cost function value=2.6541203255474186, variation=0.005586221502134503.
# Normalized cost function value=2.6486410025675178, variation=0.005479322979900836.
# Normalized cost function value=2.643265897992817, variation=0.005375104574700806.
# Normalized cost function value=2.637992412560218, variation=0.005273485432598868.
# Normalized cost function value=2.6328180239728334, variation=0.005174388587384726.
# Normalized cost function value=2.6277402833027574, variation=0.0050777406700759364.
# Normalized cost function value=2.6227568116587863, variation=0.004983471643971171.
# Normalized cost function value=2.6178652970954763, variation=0.00489151456330994.
# Normalized cost function value=2.613063491742398, variation=0.004801805353078503.
# Normalized cost function value=2.608349209134531, variation=0.004714282607866771.
# Normalized cost function value=2.6037203217249503, variation=0.004628887409580784.
# Normalized cost function value=2.5991747585645952, variation=0.004545563160355037.
# Normalized cost function value=2.5947105031336437, variation=0.004464255430951525.
# Normalized cost function value=2.5903255913111742, variation=0.004384911822469473.
# Normalized cost function value=2.586018109471095, variation=0.00430748184007923.
# Normalized cost function value=2.5817861926930017, variation=0.004231916778093314.
# Normalized cost function value=2.577628023078065, variation=0.0041581696149366465.
# Normalized cost function value=2.5735418281610842, variation=0.004086194916980812.
# Normalized cost function value=2.5695258794104787, variation=0.004015948750605514.
# Normalized cost function value=2.5655784908087176, variation=0.003947388601761137.
# Normalized cost function value=2.561698017507733, variation=0.0038804733009847325.
# Normalized cost function value=2.557882854551937, variation=0.00381516295579587.
# Normalized cost function value=2.554131435665237, variation=0.003751418886699831.
# Normalized cost function value=2.5504422320965454, variation=0.0036892035686917346.
# Normalized cost function value=2.5468137515205007, variation=0.0036284805760447014.
# Normalized cost function value=2.543244536989079, variation=0.0035692145314216717.
# Normalized cost function value=2.539733165931648, variation=0.0035113710574310453.
# Normalized cost function value=2.536278249200631, variation=0.0034549167310169437.
# Normalized cost function value=2.532878430160126, variation=0.0033998190405051254.
# Normalized cost function value=2.5295323838156745, variation=0.0033460463444514588.
# Normalized cost function value=2.5262388159831546, variation=0.0032935678325198836.
# Normalized cost function value=2.5229964624955796, variation=0.003242353487574956.
# Normalized cost function value=2.519804088445638, variation=0.0031923740499415487.
# Normalized cost function value=2.5166604874635774, variation=0.003143600982060679.
# Normalized cost function value=2.513564481028576, variation=0.0030960064350011862.
# Normalized cost function value=2.5105149178131403, variation=0.0030495632154359242.
# Normalized cost function value=2.5075106730587633, variation=0.0030042447543769946.
# Normalized cost function value=2.504550647983141, variation=0.002960025075622319.
# Normalized cost function value=2.5016337692164385, variation=0.0029168787667024354.
# Normalized cost function value=2.4987589882675545, variation=0.002874780948884048.
# Normalized cost function value=2.4959252810176835, variation=0.002833707249870976.
# Normalized cost function value=2.4931316472419547, variation=0.002793633775728832.
# Normalized cost function value=2.4903771101570316, variation=0.0027545370849231254.
# Normalized cost function value=2.4876607159942266, variation=0.0027163941628050026.
# Normalized cost function value=2.484981533597383, variation=0.0026791823968435047.
# Normalized cost function value=2.4823386540439856, variation=0.0026428795533974814.
# Normalized cost function value=2.4797311902888284, variation=0.002607463755157191.
# Normalized cost function value=2.477158276829062, variation=0.0025729134597662906.
# Normalized cost function value=2.474619069389558, variation=0.0025392074395043096.
# Normalized cost function value=2.47211274462669, variation=0.0025063247628676066.
# Normalized cost function value=2.469638499851016, variation=0.0024742447756742614.
# Normalized cost function value=2.4671955527653355, variation=0.0024429470856803803.
# Normalized cost function value=2.464783141218635, variation=0.002412411546700355.
# Normalized cost function value=2.4624005229738595, variation=0.0023826182447757027.
# Normalized cost function value=2.4600469754876153, variation=0.0023535474862441674.
# Normalized cost function value=2.4577217957018704, variation=0.0023251797857448686.
# Normalized cost function value=2.45542429984461, variation=0.0022974958572605786.
# Normalized cost function value=2.453153823239189, variation=0.0022704766054206793.
# Normalized cost function value=2.450909720120693, variation=0.002244103118496099.
# Normalized cost function value=2.448691363457249, variation=0.0022183566634441654.
# Normalized cost function value=2.44649814477624, variation=0.0021932186810089682.
# Normalized cost function value=2.4443294739923807, variation=0.0021686707838592945.
# Normalized cost function value=2.4421847792382105, variation=0.002144694754170118.
# Normalized cost function value=2.440063506693804, variation=0.002121272544406416.
# Normalized cost function value=2.437965120415898, variation=0.002098386277906261.
# Normalized cost function value=2.435889102164399, variation=0.0020760182514987235.
# Normalized cost function value=2.4338349512256503, variation=0.0020541509387488333.
# Normalized cost function value=2.4318021842307123, variation=0.00203276699493804.
# Normalized cost function value=2.4297903349683576, variation=0.002011849262354648.
# Normalized cost function value=2.427798954191324, variation=0.0019913807770337577.
# Normalized cost function value=2.4258276094149513, variation=0.001971344776372508.
# Normalized cost function value=2.423875884707826, variation=0.0019517247071254573.
# Normalized cost function value=2.421943380473161, variation=0.0019325042346647336.
# Normalized cost function value=2.420029713220526, variation=0.0019136672526349763.
# Normalized cost function value=2.418134515327474, variation=0.0018951978930523694.
# Normalized cost function value=2.416257434790354, variation=0.0018770805371199906.
# Normalized cost function value=2.4143981349640833, variation=0.001859299826270533.
# Normalized cost function value=2.4125562942908485, variation=0.0018418406732347847.
# Normalized cost function value=2.4107316060165034, variation=0.001824688274345121.
# Normalized cost function value=2.4089237778963923, variation=0.0018078281201110435.
# Normalized cost function value=2.407132531888446, variation=0.0017912460079463344.
# Normalized cost function value=2.4053576038354603, variation=0.0017749280529857359.
# Normalized cost function value=2.4035987431354218, variation=0.0017588607000385004.
# Normalized cost function value=2.4018557124011455, variation=0.0017430307342762852.
# Normalized cost function value=2.4001282871087173, variation=0.0017274252924281974.
# Normalized cost function value=2.3984162552354125, variation=0.00171203187330482.
# Normalized cost function value=2.396719416888126, variation=0.0016968383472866222.
# Normalized cost function value=2.39503758392187, variation=0.0016818329662560139.
# Normalized cost function value=2.3933705795499387, variation=0.0016670043719311245.
# Normalized cost function value=2.3917182379455624, variation=0.0016523416043763284.
# Normalized cost function value=2.3900804038367895, variation=0.0016378341087728288.
# Normalized cost function value=2.388456932094067, variation=0.001623471742722593.
# Normalized cost function value=2.3868476873128213, variation=0.001609244781245689.
# Normalized cost function value=2.385252543390899, variation=0.0015951439219223928.
# Normalized cost function value=2.3836713831019116, variation=0.001581160288987249.
# Normalized cost function value=2.3821040976661116, variation=0.001567285435799981.
# Normalized cost function value=2.38055058631895, variation=0.0015535113471618622.
# Normalized cost function value=2.3790107558784657, variation=0.0015398304404841134.
# Normalized cost function value=2.3774845203132906, variation=0.0015262355651750603.
# Normalized cost function value=2.375971800310972, variation=0.0015127200023186127.
# Normalized cost function value=2.3744725228488184, variation=0.0014992774621536142.
# Normalized cost function value=2.372986620767378, variation=0.0014859020814403934.
# Normalized cost function value=2.3715140323482466, variation=0.0014725884191313376.
# Normalized cost function value=2.3700547008963424, variation=0.0014593314519042444.
# Normalized cost function value=2.368608574328713, variation=0.0014461265676293245.
# Normalized cost function value=2.367175604769563, variation=0.0014329695591501768.
# Normalized cost function value=2.365755748153112, variation=0.001419856616450943.
# Normalized cost function value=2.3643489638352877, variation=0.0014067843178242612.
# Normalized cost function value=2.3629552142141113, variation=0.0013937496211764433.
# Normalized cost function value=2.361574464360766, variation=0.0013807498533453533.
# Normalized cost function value=2.3602066816610545, variation=0.001367782699711384.
# Normalized cost function value=2.3588518354682533, variation=0.00135484619280124.
# Normalized cost function value=2.357509896768208, variation=0.0013419387000452865.
# Normalized cost function value=2.3561808378567086, variation=0.00132905891149937.
# Normalized cost function value=2.354864632030136, variation=0.0013162058265727694.
# Normalized cost function value=2.3535612532893517, variation=0.0013033787407841224.
# Normalized cost function value=2.3522706760573207, variation=0.001290577232031076.
# Normalized cost function value=2.3509928749112814, variation=0.001277801146039259.
# Normalized cost function value=2.349727824328715, variation=0.0012650505825662073.
# Normalized cost function value=2.348475498448059, variation=0.0012523258806562687.
# Normalized cost function value=2.3472358708442544, variation=0.0012396276038044718.
# Normalized cost function value=2.3460089143186447, variation=0.0012269565256097792.
# Normalized cost function value=2.344794600703734, variation=0.0012143136149105338.
# Normalized cost function value=2.343592900682778, variation=0.00120170002095632.
# Normalized cost function value=2.342403783623549, variation=0.0011891170592286393.
# Normalized cost function value=2.3412272174268227, variation=0.0011765661967264585.
# Normalized cost function value=2.340063168388941, variation=0.0011640490378819202.
# Normalized cost function value=2.3389116010782343, variation=0.001151567310706536.
# Normalized cost function value=2.337772478225285, variation=0.0011391228529493702.
# Normalized cost function value=2.3366457606262543, variation=0.0011267175990306022.
# Normalized cost function value=2.335531407059691, variation=0.0011143535665634197.
# Normalized cost function value=2.3344293742148587, variation=0.0011020328448321237.
# Normalized cost function value=2.3333396166336797, variation=0.0010897575811790183.
# Normalized cost function value=2.3322620866630293, variation=0.0010775299706504704.
# Normalized cost function value=2.3311967344189073, variation=0.0010653522441219643.
# Normalized cost function value=2.3301435077611146, variation=0.0010532266577927274.
# Normalized cost function value=2.329102352278404, variation=0.001041155482710554.
# Normalized cost function value=2.328073211282809, variation=0.0010291409955951458.
# Normalized cost function value=2.3270560258134774, variation=0.0010171854693314941.
# Normalized cost function value=2.3260507346491157, variation=0.0010052911643616547.
# Normalized cost function value=2.3250572743282216, variation=0.0009934603208940906.
# Normalized cost function value=2.32407557917715, variation=0.0009816951510717153.
# Normalized cost function value=2.323105581344764, variation=0.0009699978323860492.
# Normalized cost function value=2.3221472108438523, variation=0.0009583705009115207.
# Normalized cost function value=2.3212003955984155, variation=0.0009468152454368273.
# Normalized cost function value=2.320265061495968, variation=0.0009353341024476158.
# Normalized cost function value=2.3193411324450204, variation=0.000923929050947514.
# Normalized cost function value=2.3184285304370005, variation=0.0009126020080199027.
# Normalized cost function value=2.3175271756116165, variation=0.0009013548253840042.
# Normalized cost function value=2.3166369863261336, variation=0.0008901892854829008.
# Normalized cost function value=2.315757879227083, variation=0.0008791070990503691.
# Normalized cost function value=2.314889769324911, variation=0.0008681099021723426.
# Normalized cost function value=2.3140325700704802, variation=0.0008571992544306184.
# Normalized cost function value=2.313186193433257, variation=0.0008463766372233117.
# Normalized cost function value=2.3123505499810344, variation=0.0008356434522225342.
# Normalized cost function value=2.3115255489601814, variation=0.0008250010208530334.
# Normalized cost function value=2.3107110983770385, variation=0.0008144505831428894.
# Normalized cost function value=2.3099071050790907, variation=0.0008039932979477804.
# Normalized cost function value=2.3091134748366513, variation=0.0007936302424393915.
# Normalized cost function value=2.3083301124237985, variation=0.0007833624128528172.
# Normalized cost function value=2.307556921699168, variation=0.0007731907246304459.
# Normalized cost function value=2.306793805685708, variation=0.000763116013460241.
# Normalized cost function value=2.306040666649792, variation=0.0007531390359156731.
# Normalized cost function value=2.3052974061785547, variation=0.0007432604712374058.
# Normalized cost function value=2.304563925256847, variation=0.0007334809217076632.
# Normalized cost function value=2.3038401243415505, variation=0.0007238009152965574.
# Normalized cost function value=2.303125903435242, variation=0.0007142209063086824.
# Normalized cost function value=2.30242116215746, variation=0.0007047412777816398.
# Normalized cost function value=2.301725799814507, variation=0.0006953623429533096.
# Normalized cost function value=2.301039715466757, variation=0.0006860843477500822.
# Normalized cost function value=2.3003628079946785, variation=0.0006769074720782697.
# Normalized cost function value=2.2996949761619927, variation=0.0006678318326858168.
# Normalized cost function value=2.2990361186772272, variation=0.0006588574847654627.
# Normalized cost function value=2.298386134252559, variation=0.0006499844246681263.
# Normalized cost function value=2.297744921661065, variation=0.0006412125914940781.
# Normalized cost function value=2.2971123797912663, variation=0.000632541869798775.
# Normalized cost function value=2.2964884076993473, variation=0.0006239720919190006.
# Normalized cost function value=2.295872904659573, variation=0.0006155030397740902.
# Normalized cost function value=2.2952657702120467, variation=0.0006071344475264695.
# Normalized cost function value=2.2946669042084977, variation=0.0005988660035489701.
# Normalized cost function value=2.2940762068555847, variation=0.000590697352913061.
# Normalized cost function value=2.293493578756503, variation=0.0005826280990817168.
# Normalized cost function value=2.2929189209498584, variation=0.0005746578066445629.
# Normalized cost function value=2.2923521349469556, variation=0.0005667860029028304.
# Normalized cost function value=2.291793122766665, variation=0.0005590121802905301.
# Normalized cost function value=2.29124178696845, variation=0.0005513357982152023.
# Normalized cost function value=2.290698030683541, variation=0.0005437562849088806.
# Normalized cost function value=2.2901617576438844, variation=0.0005362730396565318.
# Normalized cost function value=2.2896328722097072, variation=0.0005288854341771732.
# Normalized cost function value=2.2891112793945196, variation=0.0005215928151875993.
# Normalized cost function value=2.288596884889389, variation=0.0005143945051306886.
# Normalized cost function value=2.288089595084848, variation=0.0005072898045410668.
# Normalized cost function value=2.2875893170911747, variation=0.0005002779936731372.
# Normalized cost function value=2.2870959587574067, variation=0.000493358333768068.
# Normalized cost function value=2.2866094286889185, variation=0.00048653006848820013.
# Normalized cost function value=2.286129636263073, variation=0.00047979242584528237.
# Normalized cost function value=2.2856564916440862, variation=0.0004731446189869537.
# Normalized cost function value=2.285189905796023, variation=0.0004665858480632501.
# Normalized cost function value=2.2847297904951107, variation=0.00046011530091227826.
# Normalized cost function value=2.284276058340167, variation=0.000453732154943598.
# Normalized cost function value=2.2838286227626554, variation=0.00044743557751170115.
# Normalized cost function value=2.2833873980348502, variation=0.0004412247278051673.
# Normalized cost function value=2.282952299277646, variation=0.00043509875720415536.
# Normalized cost function value=2.2825232424668425, variation=0.0004290568108036297.
# Normalized cost function value=2.282100144438996, variation=0.000423098027846347.
# Normalized cost function value=2.2816829228957003, variation=0.0004172215432958204.
# Normalized cost function value=2.281271496407958, variation=0.0004114264877421725.
# Normalized cost function value=2.2808657844187747, variation=0.00040571198918337714.
# Normalized cost function value=2.2804657072456567, variation=0.0004000771731180741.
# Normalized cost function value=2.280071186082313, variation=0.00039452116334359744.
# Normalized cost function value=2.279682142999272, variation=0.0003890430830408853.
# Normalized cost function value=2.2792985009443996, variation=0.0003836420548726238.
# Normalized cost function value=2.278920183742532, variation=0.00037831720186742857.
# Normalized cost function value=2.278547116094618, variation=0.00037306764791411595.
# Normalized cost function value=2.278179223576282, variation=0.0003678925183359105.
# Normalized cost function value=2.2778164326360355, variation=0.0003627909402466045.
# Normalized cost function value=2.2774586705927793, variation=0.00035776204325621563.
# Normalized cost function value=2.2771058656333083, variation=0.000352804959470987.
# Normalized cost function value=2.2767579468088557, variation=0.0003479188244526199.
# Normalized cost function value=2.2764148440317156, variation=0.00034310277714011406.
# Normalized cost function value=2.2760764880713276, variation=0.00033835596038800375.
# Normalized cost function value=2.2757428105501525, variation=0.00033367752117507976.
# Normalized cost function value=2.2754137439388114, variation=0.00032906661134113335.
# Normalized cost function value=2.275089221551919, variation=0.00032452238689240076.
# Normalized cost function value=2.2747691775423577, variation=0.0003200440095612045.
# Normalized cost function value=2.2744535468965106, variation=0.0003156306458471647.
# Normalized cost function value=2.2741422654284547, variation=0.00031128146805592394.
# Normalized cost function value=2.2738352697742905, variation=0.00030699565416414387.
# Normalized cost function value=2.273532497386446, variation=0.00030277238784437444.
# Normalized cost function value=2.2732338865273882, variation=0.00029861085905791285.
# Normalized cost function value=2.2729393762634746, variation=0.00029451026391358326.
# Normalized cost function value=2.2726489064586044, variation=0.00029046980487024143.
# Normalized cost function value=2.2723624177677566, variation=0.00028648869084779705.
# Normalized cost function value=2.27207985163026, variation=0.00028256613749677584.
# Normalized cost function value=2.2718011502632445, variation=0.00027870136701535486.
# Normalized cost function value=2.2715262566546635, variation=0.0002748936085810172.
# Normalized cost function value=2.271255114556554, variation=0.0002711420981094115.
# Normalized cost function value=2.270987668477911, variation=0.00026744607864293.
# Normalized cost function value=2.270723863677746, variation=0.00026380480016507946.
# Normalized cost function value=2.2704636461579946, variation=0.0002602175197514711.
# Normalized cost function value=2.2702069626563617, variation=0.00025668350163288167.
# Normalized cost function value=2.269953760639041, variation=0.0002532020173204863.
# Normalized cost function value=2.2697039882935957, variation=0.0002497723454455425.
# Normalized cost function value=2.269457594521719, variation=0.0002463937718766296.
# Normalized cost function value=2.26921452893181, variation=0.00024306558990883076.
# Normalized cost function value=2.2689747418318715, variation=0.00023978709993865976.
# Normalized cost function value=2.268738184222091, variation=0.0002365576097806965.
# Normalized cost function value=2.268504807787494, variation=0.00023337643459697688.
# Normalized cost function value=2.268274564890583, variation=0.0002302428969107595.
# Normalized cost function value=2.2680474085643016, variation=0.00022715632628145244.
# Normalized cost function value=2.26782329250439, variation=0.00022411605991168315.
# Normalized cost function value=2.267602171062168, variation=0.00022112144222186103.
# Normalized cost function value=2.267383999237393, variation=0.0002181718247751263.
# Normalized cost function value=2.267168732670801, variation=0.00021526656659176524.
# Normalized cost function value=2.266956327636913, variation=0.00021240503388808563.
# Normalized cost function value=2.266746741036801, variation=0.00020958660011194397.
# Normalized cost function value=2.2665399303909117, variation=0.00020681064588945475.
# Normalized cost function value=2.2663358538318716, variation=0.00020407655904008948.
# Normalized cost function value=2.2661344700972164, variation=0.00020138373465528048.
# Normalized cost function value=2.265935738522378, variation=0.0001987315748381846.
# Normalized cost function value=2.2657396190336443, variation=0.0001961194887338813.
# Normalized cost function value=2.2655460721409098, variation=0.00019354689273454184.
# Normalized cost function value=2.2653550589309215, variation=0.00019101320998826665.
# Normalized cost function value=2.265166541059966, variation=0.00018851787095552908.
# Normalized cost function value=2.2649804807472718, variation=0.00018606031269419177.
# Normalized cost function value=2.2647968407678465, variation=0.00018363997942527632.
# Normalized cost function value=2.2646155844459233, variation=0.00018125632192322882.
# Normalized cost function value=2.264436675647628, variation=0.00017890879829529638.
# Normalized cost function value=2.2642600787748273, variation=0.00017659687280069392.
# Normalized cost function value=2.2640857587580014, variation=0.0001743200168258241.
# Normalized cost function value=2.263913681049691, variation=0.00017207770831051405.
# Normalized cost function value=2.2637438116178688, variation=0.00016986943182217829.
# Normalized cost function value=2.2635761169394453, variation=0.00016769467842348007.
# Normalized cost function value=2.2634105639935567, variation=0.00016555294588860292.
# Normalized cost function value=2.2632471202553432, variation=0.00016344373821342018.
# Normalized cost function value=2.2630857536893134, variation=0.00016136656602983024.
# Normalized cost function value=2.262926432742983, variation=0.00015932094633042126.
# Normalized cost function value=2.2627691263407446, variation=0.00015730640223843295.
# Normalized cost function value=2.2626138038773846, variation=0.00015532246335991928.
# Normalized cost function value=2.262460435212047, variation=0.00015336866533743887.
# Normalized cost function value=2.262308990661944, variation=0.0001514445501031858.
# Normalized cost function value=2.262159440996385, variation=0.00014954966555880134.
# Normalized cost function value=2.2620117574304963, variation=0.00014768356588890086.
# Normalized cost function value=2.261865911619551, variation=0.00014584581094512217.
# Normalized cost function value=2.2617218756527704, variation=0.00014403596678080888.
# Normalized cost function value=2.2615796220475173, variation=0.00014225360525310649.
# Normalized cost function value=2.2614391237435427, variation=0.00014049830397455665.
# Normalized cost function value=2.2613003540971786, variation=0.00013876964636416744.
# Normalized cost function value=2.2611632868754508, variation=0.0001370672217277935.
# Normalized cost function value=2.261027896250734, variation=0.0001353906247167913.
# Normalized cost function value=2.260894156794947, variation=0.00013373945578676327.
# Normalized cost function value=2.2607620434739286, variation=0.00013211332101858986.
# Normalized cost function value=2.2606315316421792, variation=0.0001305118317493914.
# Normalized cost function value=2.260502597037307, variation=0.00012893460487228836.
# Normalized cost function value=2.260375215774571, variation=0.00012738126273603712.
# Normalized cost function value=2.260249364341728, variation=0.00012585143284304934.
# Normalized cost function value=2.260125019593593, variation=0.00012434474813494134.
# Normalized cost function value=2.260002158746942, variation=0.00012286084665102948.
# Normalized cost function value=2.2598807593753625, variation=0.0001213993715794004.
# Normalized cost function value=2.2597607994041033, variation=0.00011995997125913149.
# Normalized cost function value=2.2596422571049932, variation=0.00011854229911012482.
# Normalized cost function value=2.259525111091646, variation=0.00011714601334711361.
# Normalized cost function value=2.2594093403143076, variation=0.0001157707773384864.
# Normalized cost function value=2.2592949240550353, variation=0.0001144162592723319.
# Normalized cost function value=2.2591818419230085, variation=0.00011308213202676498.
# Normalized cost function value=2.259070073849556, variation=0.00011176807345236739.
# Normalized cost function value=2.258959600083737, variation=0.00011047376581929669.
# Normalized cost function value=2.258850401187283, variation=0.0001091988964536661.
# Normalized cost function value=2.258742458030305, variation=0.00010794315697815193.
# Normalized cost function value=2.2586357517867928, variation=0.00010670624351227787.
# Normalized cost function value=2.258530263929804, variation=0.00010548785698860641.
# Normalized cost function value=2.2584259762272803, variation=0.00010428770252390862.
# Normalized cost function value=2.258322870737612, variation=0.00010310548966829813.
# Normalized cost function value=2.2582209298052174, variation=0.00010194093239457303.
# Normalized cost function value=2.2581201360564016, variation=0.00010079374881577507.
# Normalized cost function value=2.2580204723949486, variation=9.966366145297556e-05.
# Normalized cost function value=2.257921921998148, variation=9.855039680051192e-05.
# Normalized cost function value=2.2578244683125237, variation=9.74536856244157e-05.
# Normalized cost function value=2.2577280950498158, variation=9.637326270794944e-05.
# Normalized cost function value=2.2576327861829073, variation=9.530886690845009e-05.
# Normalized cost function value=2.25753852594191, variation=9.426024099745689e-05.
# Normalized cost function value=2.2574452988102505, variation=9.322713165937913e-05.
# Normalized cost function value=2.257353089520747, variation=9.22092895034865e-05.
# Normalized cost function value=2.2572618830518008, variation=9.120646894622553e-05.
# Normalized cost function value=2.2571716646236593, variation=9.02184281414975e-05.
# Normalized cost function value=2.2570824196946724, variation=8.924492898687575e-05.
# Normalized cost function value=2.256994133957601, variation=8.828573707120313e-05.
# Normalized cost function value=2.2569067933359617, variation=8.734062163950895e-05.
# Normalized cost function value=2.2568203839805197, variation=8.640935544201866e-05.
# Normalized cost function value=2.2567348922658144, variation=8.549171470528805e-05.
# Normalized cost function value=2.2566503047863424, variation=8.458747947193146e-05.
# Normalized cost function value=2.2565666083536824, variation=8.36964326600409e-05.
# Normalized cost function value=2.25648378999249, variation=8.281836119250485e-05.
# Normalized cost function value=2.256401836937638, variation=8.195305485170223e-05.
# Normalized cost function value=2.2563207366305975, variation=8.110030704067128e-05.
# Normalized cost function value=2.256240476716414, variation=8.025991418358913e-05.
# Normalized cost function value=2.256161045040229, variation=7.943167618496005e-05.
# Normalized cost function value=2.2560824296444855, variation=7.861539574349763e-05.
# Normalized cost function value=2.256004618765404, variation=7.781087908131923e-05.
# Normalized cost function value=2.2559276008301183, variation=7.70179352858058e-05.
# Normalized cost function value=2.255851364453682, variation=7.623637643616732e-05.
# Normalized cost function value=2.255775898435957, variation=7.546601772512318e-05.
# Normalized cost function value=2.2557011917586602, variation=7.470667729680969e-05.
# Normalized cost function value=2.2556272335825374, variation=7.395817612287914e-05.
# Normalized cost function value=2.255554013244439, variation=7.32203380984231e-05.
# Normalized cost function value=2.2554815202545204, variation=7.24929899185156e-05.
# Normalized cost function value=2.255409744293331, variation=7.177596118923546e-05.
# Normalized cost function value=2.255338675209271, variation=7.106908406040446e-05.
# Normalized cost function value=2.255268303015731, variation=7.037219354000257e-05.
# Normalized cost function value=2.2551986178885066, variation=6.968512722416165e-05.
# Normalized cost function value=2.2551296101630136, variation=6.900772549300882e-05.
# Normalized cost function value=2.2550612703319683, variation=6.833983104526098e-05.
# Normalized cost function value=2.254993589042526, variation=6.768128944223406e-05.
# Normalized cost function value=2.254926557093932, variation=6.703194859403183e-05.
# Normalized cost function value=2.2548601654350318, variation=6.639165890032217e-05.
# Normalized cost function value=2.2547944051618436, variation=6.576027318816458e-05.
# Normalized cost function value=2.2547292675150414, variation=6.513764680216028e-05.
# Normalized cost function value=2.2546647438776515, variation=6.452363738995714e-05.
# Normalized cost function value=2.2546008257727355, variation=6.391810491601646e-05.
# Normalized cost function value=2.2545375048611245, variation=6.332091161098674e-05.
# Normalized cost function value=2.2544747729389654, variation=6.273192215910939e-05.
# Normalized cost function value=2.2544126219356593, variation=6.215100330608792e-05.
# Normalized cost function value=2.254351043911658, variation=6.15780240011965e-05.
# Normalized cost function value=2.2542900310561347, variation=6.10128555234013e-05.
# Normalized cost function value=2.2542295756850703, variation=6.045537106436072e-05.
# Normalized cost function value=2.254169670239047, variation=5.990544602330061e-05.
# Normalized cost function value=2.254110307281006, variation=5.936295804120917e-05.
# Normalized cost function value=2.254051479494546, variation=5.882778645993625e-05.
# Normalized cost function value=2.2539931796817387, variation=5.829981280713881e-05.
# Normalized cost function value=2.253935400760938, variation=5.777892080072178e-05.
# Normalized cost function value=2.2538781357653104, variation=5.7264995627637205e-05.
# Normalized cost function value=2.253821377840531, variation=5.675792477921604e-05.
# Normalized cost function value=2.25376512024301, variation=5.625759752136972e-05.
# Normalized cost function value=2.253709356338102, variation=5.576390490791283e-05.
# Normalized cost function value=2.253654079598167, variation=5.527673993466209e-05.
# Normalized cost function value=2.253599283600848, variation=5.4795997319168066e-05.
# Normalized cost function value=2.2535449620272012, variation=5.4321573646820553e-05.
# Normalized cost function value=2.2534911086602025, variation=5.38533669987018e-05.
# Normalized cost function value=2.2534377173826763, variation=5.339127752623796e-05.
# Normalized cost function value=2.2533847821757886, variation=5.2935206887649855e-05.
# Normalized cost function value=2.2533322971174763, variation=5.2485058312345956e-05.
# Normalized cost function value=2.2532802563805747, variation=5.204073690157074e-05.
# Normalized cost function value=2.2532286542315236, variation=5.160214905108873e-05.
# Normalized cost function value=2.253177485028358, variation=5.116920316572404e-05.
# Normalized cost function value=2.2531267432195627, variation=5.074180879516277e-05.
# Normalized cost function value=2.2530764233422778, variation=5.031987728498777e-05.
# Normalized cost function value=2.2530265200209465, variation=4.990332133125719e-05.
# Normalized cost function value=2.2529770279655277, variation=4.949205541882051e-05.
# Normalized cost function value=2.252927941970596, variation=4.9085994931807875e-05.
# Normalized cost function value=2.25287925691329, variation=4.868505730604156e-05.
# Normalized cost function value=2.2528309677521623, variation=4.8289161127534896e-05.
# Normalized cost function value=2.2527830695260427, variation=4.7898226119613696e-05.
# Normalized cost function value=2.252735557352143, variation=4.751217389964424e-05.
# Normalized cost function value=2.2526884264251024, variation=4.713092704067279e-05.
# Normalized cost function value=2.2526416720154616, variation=4.675440964074795e-05.
# Normalized cost function value=2.252595289468501, variation=4.638254696054389e-05.
# Normalized cost function value=2.252549274202896, variation=4.6015265604992805e-05.
# Normalized cost function value=2.2525036217093355, variation=4.5652493560588425e-05.
# Normalized cost function value=2.2524583275495256, variation=4.529415980991658e-05.
# Normalized cost function value=2.2524133873547516, variation=4.4940194773968045e-05.
# Normalized cost function value=2.2523687968247263, variation=4.4590530025256925e-05.
# Normalized cost function value=2.252324551726496, variation=4.424509823053313e-05.
# Normalized cost function value=2.2522806478931976, variation=4.390383329822001e-05.
# Normalized cost function value=2.252237081222825, variation=4.356667037264117e-05.
# Normalized cost function value=2.252193847677491, variation=4.323354533397605e-05.
# Normalized cost function value=2.252150943281716, variation=4.290439577481209e-05.
# Normalized cost function value=2.2521083641218813, variation=4.257915983485461e-05.
# Normalized cost function value=2.252066106344844, variation=4.225777703714684e-05.
# Normalized cost function value=2.2520241661570255, variation=4.1940187818667596e-05.
# Normalized cost function value=2.2519825398233007, variation=4.162633372484237e-05.
# Normalized cost function value=2.2519412236660563, variation=4.131615724434212e-05.
# Normalized cost function value=2.2519002140641495, variation=4.100960190678293e-05.
# Normalized cost function value=2.2518595074518406, variation=4.070661230892725e-05.
# Normalized cost function value=2.251819100318023, variation=4.04071338175882e-05.
# Normalized cost function value=2.2517789892051168, variation=4.011111290624925e-05.
# Normalized cost function value=2.2517391707081407, variation=3.9818496976096185e-05.
# Normalized cost function value=2.251699641473841, variation=3.9529234299617855e-05.
# Normalized cost function value=2.251660398199841, variation=3.924327400017802e-05.
# Normalized cost function value=2.251621437633629, variation=3.896056621188748e-05.
# Normalized cost function value=2.251582756571684, variation=3.868106194504506e-05.
# Normalized cost function value=2.251544351858792, variation=3.840471289207059e-05.
# Normalized cost function value=2.2515062203869767, variation=3.813147181519483e-05.
# Normalized cost function value=2.251468359094873, variation=3.786129210370248e-05.
# Normalized cost function value=2.251430764966731, variation=3.7594128142082184e-05.
# Normalized cost function value=2.2513934350317846, variation=3.732993494631742e-05.
# Normalized cost function value=2.251356366363252, variation=3.7068668532480586e-05.
# Normalized cost function value=2.251319556077822, variation=3.681028543001119e-05.
# Normalized cost function value=2.2512830013346425, variation=3.6554743179539884e-05.
# Normalized cost function value=2.2512466993347573, variation=3.6301999885246516e-05.
# Normalized cost function value=2.251210647320293, variation=3.605201446443829e-05.
# Normalized cost function value=2.251174842573665, variation=3.580474662800981e-05.
# Normalized cost function value=2.251139282417019, variation=3.5560156645964014e-05.
# Normalized cost function value=2.251103964211466, variation=3.531820555302545e-05.
# Normalized cost function value=2.251068885356235, variation=3.507885523079679e-05.
# Normalized cost function value=2.251034043288345, variation=3.484206788995081e-05.
# Normalized cost function value=2.250999435481647, variation=3.460780669817254e-05.
# Normalized cost function value=2.2509650594462753, variation=3.437603537159717e-05.
# Normalized cost function value=2.2509309127279375, variation=3.4146718337790816e-05.
# Normalized cost function value=2.2508969929074523, variation=3.391982048528419e-05.
# Normalized cost function value=2.2508632975999667, variation=3.3695307485537285e-05.
# Normalized cost function value=2.2508298244543914, variation=3.347314557533565e-05.
# Normalized cost function value=2.250796571152848, variation=3.325330154346773e-05.
# Normalized cost function value=2.2507635354100763, variation=3.3035742771581056e-05.
# Normalized cost function value=2.250730714972684, variation=3.2820437392278023e-05.
# Normalized cost function value=2.2506981076189376, variation=3.260735374643886e-05.
# Normalized cost function value=2.2506657111578985, variation=3.23964610391414e-05.
# Normalized cost function value=2.2506335234288146, variation=3.218772908386569e-05.
# ...
# Normalized cost function value=2.246159536602944, variation=1.3372668170141822e-05.
# Normalized cost function value=2.2461461684229365, variation=1.3368180007411468e-05.
# Normalized cost function value=2.2461328043115647, variation=1.3364111371760856e-05.
# Normalized cost function value=2.246119443852788, variation=1.33604587766456e-05.
# Normalized cost function value=2.2461060866341285, variation=1.335721865958206e-05.
# Normalized cost function value=2.2460927322465807, variation=1.3354387547792612e-05.
# Normalized cost function value=2.2460793802846366, variation=1.335196194407473e-05.
# Normalized cost function value=2.2460660303465194, variation=1.3349938117190874e-05.
# Normalized cost function value=2.2460526820340525, variation=1.3348312466909817e-05.
# Normalized cost function value=2.2460393349527905, variation=1.334708126199402e-05.
# Normalized cost function value=2.2460259887120233, variation=1.3346240767209139e-05.
# Normalized cost function value=2.2460126429249905, variation=1.334578703282574e-05.
# Normalized cost function value=2.245999297208654, variation=1.3345716336488067e-05.
# Normalized cost function value=2.2459859511839877, variation=1.3346024666294198e-05.
# Normalized cost function value=2.2459726044759476, variation=1.3346708040096189e-05.
# Normalized cost function value=2.2459592567134625, variation=1.3347762485071968e-05.
# Normalized cost function value=2.2459459075295958, variation=1.3349183866750991e-05.
# Normalized cost function value=2.245932556561589, variation=1.3350968006697883e-05.
# Normalized cost function value=2.2459192034507534, variation=1.3353110835723214e-05.
# Normalized cost function value=2.2459058478427614, variation=1.3355607991982765e-05.
# Normalized cost function value=2.2458924893874905, variation=1.3358455270839897e-05.
# Normalized cost function value=2.245879127739302, variation=1.3361648188325859e-05.
# Normalized cost function value=2.2458657625567637, variation=1.3365182538471743e-05.
# Normalized cost function value=2.245852393503108, variation=1.336905365567631e-05.
# Normalized cost function value=2.245839020245946, variation=1.3373257162108132e-05.
# Normalized cost function value=2.245825642457466, variation=1.3377788480095631e-05.
# Normalized cost function value=2.245812259814496, variation=1.3382642969794745e-05.
# Normalized cost function value=2.2457988719985016, variation=1.3387815994470031e-05.
# Normalized cost function value=2.2457854786957423, variation=1.3393302759290293e-05.
# Normalized cost function value=2.245772079597157, variation=1.3399098585331615e-05.
# Normalized cost function value=2.245758674398518, variation=1.3405198639127036e-05.
# Normalized cost function value=2.245745262800505, variation=1.34115980130467e-05.
# Normalized cost function value=2.2457318445087346, variation=1.3418291770150859e-05.
# Normalized cost function value=2.245718419233698, variation=1.3425275036560436e-05.
# Normalized cost function value=2.2457049866910705, variation=1.3432542627533905e-05.
# Normalized cost function value=2.2456915466014045, variation=1.3440089666083566e-05.
# Normalized cost function value=2.2456780986905702, variation=1.3447910834241128e-05.
# Normalized cost function value=2.2456646426893947, variation=1.3456001175526922e-05.
# Normalized cost function value=2.2456511783341147, variation=1.3464355280046192e-05.
# Normalized cost function value=2.245637705366153, variation=1.3472967961725146e-05.
# Normalized cost function value=2.245624223532139, variation=1.3481834014061889e-05.
# Normalized cost function value=2.245610732584168, variation=1.3490947970762335e-05.
# Normalized cost function value=2.2455972322797146, variation=1.3500304453462064e-05.
# Normalized cost function value=2.245583722381707, variation=1.3509898007857402e-05.
# Normalized cost function value=2.2455702026584627, variation=1.3519723244037607e-05.
# Normalized cost function value=2.2455566728839247, variation=1.3529774538056927e-05.
# Normalized cost function value=2.2455431328374984, variation=1.3540046426285812e-05.
# Normalized cost function value=2.2455295823043127, variation=1.3550533185746616e-05.
# Normalized cost function value=2.2455160210749647, variation=1.3561229347924808e-05.
# Normalized cost function value=2.245502448945924, variation=1.3572129040628766e-05.
# Normalized cost function value=2.24548886571921, variation=1.3583226714075636e-05.
# Normalized cost function value=2.2454752712027113, variation=1.359451649873833e-05.
# Normalized cost function value=2.245461665209956, variation=1.3605992755127971e-05.
# Normalized cost function value=2.245448047560407, variation=1.361764954932454e-05.
# Normalized cost function value=2.2454344180792716, variation=1.3629481135257748e-05.
# Normalized cost function value=2.2454207765977245, variation=1.3641481547033152e-05.
# Normalized cost function value=2.2454071229527766, variation=1.3653644947986265e-05.
# Normalized cost function value=2.2453934569873577, variation=1.366596541885201e-05.
# Normalized cost function value=2.2453797785503737, variation=1.367843698396598e-05.
# Normalized cost function value=2.2453660874966244, variation=1.369105374937618e-05.
# Normalized cost function value=2.2453523836870524, variation=1.3703809571996572e-05.
# Normalized cost function value=2.245338666988487, variation=1.3716698565424679e-05.
# Normalized cost function value=2.245324937273829, variation=1.3729714658072822e-05.
# Normalized cost function value=2.245311194422023, variation=1.3742851805886858e-05.
# Normalized cost function value=2.245297438318105, variation=1.3756103918183271e-05.
# Normalized cost function value=2.2452836688530913, variation=1.3769465013524496e-05.
# Normalized cost function value=2.2452698859242375, variation=1.37829288537894e-05.
# Normalized cost function value=2.2452560894346854, variation=1.3796489552131419e-05.
# Normalized cost function value=2.2452422792939104, variation=1.3810140774950241e-05.
# Normalized cost function value=2.24522845541733, variation=1.382387658033224e-05.
# Normalized cost function value=2.24521461772654, variation=1.3837690790108326e-05.
# Normalized cost function value=2.2452007661492237, variation=1.3851577316259522e-05.
# Normalized cost function value=2.2451869006191414, variation=1.3865530082313171e-05.
# Normalized cost function value=2.2451730210762486, variation=1.3879542892780705e-05.
# Normalized cost function value=2.2451591274665863, variation=1.3893609662307682e-05.
# Normalized cost function value=2.245145219742175, variation=1.3907724411232891e-05.
# Normalized cost function value=2.245131297861233, variation=1.392188094184732e-05.
# Normalized cost function value=2.2451173617880817, variation=1.3936073151477046e-05.
# Normalized cost function value=2.2451034114929325, variation=1.3950295149278702e-05.
# Normalized cost function value=2.2450894469522207, variation=1.39645407117861e-05.
# Normalized cost function value=2.24507546814839, variation=1.397880383047223e-05.
# Normalized cost function value=2.2450614750697335, variation=1.39930786566822e-05.
# Normalized cost function value=2.245047467710665, variation=1.4007359068646252e-05.
# Normalized cost function value=2.2450334460715604, variation=1.4021639104466743e-05.
# Normalized cost function value=2.2450194101587164, variation=1.4035912843990417e-05.
# Normalized cost function value=2.2450053599841593, variation=1.4050174557134198e-05.
# Normalized cost function value=2.2449912955660394, variation=1.4064418119907884e-05.
# Normalized cost function value=2.2449772169281803, variation=1.4078637859071819e-05.
# Normalized cost function value=2.244963124100264, variation=1.4092827916201145e-05.
# Normalized cost function value=2.244949017117708, variation=1.4106982556327807e-05.
# Normalized cost function value=2.244934896021573, variation=1.412109613463386e-05.
# Normalized cost function value=2.2449207608587747, variation=1.4135162798467604e-05.
# Normalized cost function value=2.2449066116816483, variation=1.4149177126387968e-05.
# Normalized cost function value=2.244892448548201, variation=1.4163133447375742e-05.
# Normalized cost function value=2.244878271521982, variation=1.4177026218753497e-05.
# Normalized cost function value=2.244864080671966, variation=1.4190850015971535e-05.
# Normalized cost function value=2.24484987607249, variation=1.4204599476208557e-05.
# Normalized cost function value=2.2448356578034283, variation=1.4218269061672117e-05.
# Normalized cost function value=2.24482142594972, variation=1.4231853708412956e-05.
# Normalized cost function value=2.244807180601665, variation=1.4245348054942042e-05.
# Normalized cost function value=2.2447929218547134, variation=1.4258746951600898e-05.
# Normalized cost function value=2.2447786498093762, variation=1.42720453371048e-05.
# Normalized cost function value=2.2447643645712287, variation=1.4285238147504487e-05.
# Normalized cost function value=2.2447500662508215, variation=1.4298320407224452e-05.
# Normalized cost function value=2.24473575496342, variation=1.4311287401369555e-05.
# Normalized cost function value=2.2447214308292898, variation=1.432413413038347e-05.
# Normalized cost function value=2.2447070939733007, variation=1.4336855989061092e-05.
# Normalized cost function value=2.244692744524983, variation=1.4349448317574343e-05.
# Normalized cost function value=2.2446783826184586, variation=1.436190652448488e-05.
# Normalized cost function value=2.244664008392255, variation=1.4374226203539564e-05.
# Normalized cost function value=2.2446496219893284, variation=1.4386402926724884e-05.
# Normalized cost function value=2.2446352235569313, variation=1.4398432397033645e-05.
# Normalized cost function value=2.2446208132464114, variation=1.4410310519963332e-05.
# Normalized cost function value=2.2446063912134084, variation=1.4422033002947643e-05.
# Normalized cost function value=2.244591957617342, variation=1.4433596066343313e-05.
# Normalized cost function value=2.2445775126217677, variation=1.444499557434753e-05.
# Normalized cost function value=2.2445630563938614, variation=1.4456227906300967e-05.
# Normalized cost function value=2.244548589104537, variation=1.4467289324304744e-05.
# Normalized cost function value=2.244534110928468, variation=1.44781760691437e-05.
# Normalized cost function value=2.2445196220436583, variation=1.4488884809704672e-05.
# Normalized cost function value=2.24450512263154, variation=1.4499412118507138e-05.
# Normalized cost function value=2.2444906128769224, variation=1.4509754617364479e-05.
# Normalized cost function value=2.2444760929676466, variation=1.4519909275811926e-05.
# Normalized cost function value=2.2444615630946902, variation=1.4529872956359213e-05.
# Normalized cost function value=2.24444702345199, variation=1.4539642700039934e-05.
# Normalized cost function value=2.2444324742362265, variation=1.454921576371504e-05.
# Normalized cost function value=2.244417915646947, variation=1.4558589279456413e-05.
# Normalized cost function value=2.2444033478861845, variation=1.4567760762584925e-05.
# Normalized cost function value=2.2443887711584796, variation=1.4576727704884718e-05.
# Normalized cost function value=2.2443741856707633, variation=1.4585487716267664e-05.
# Normalized cost function value=2.2443595916322034, variation=1.4594038559856415e-05.
# Normalized cost function value=2.2443449892540674, variation=1.4602378135997185e-05.
# Normalized cost function value=2.2443303787496545, variation=1.461050441298184e-05.
# Normalized cost function value=2.2443157603341617, variation=1.4618415492773096e-05.
# Normalized cost function value=2.2443011342244397, variation=1.4626109722026825e-05.
# Normalized cost function value=2.244286500639082, variation=1.463358535769288e-05.
# Normalized cost function value=2.2442718597981317, variation=1.4640840950264078e-05.
# Normalized cost function value=2.2442572119230615, variation=1.4647875070217253e-05.
# Normalized cost function value=2.2442425572365563, variation=1.4654686505188863e-05.
# Normalized cost function value=2.2442278959623954, variation=1.4661274160943094e-05.
# Normalized cost function value=2.2442132283254743, variation=1.4667636921039673e-05.
# Normalized cost function value=2.2441985545514553, variation=1.4673774018980623e-05.
# Normalized cost function value=2.244183874866794, variation=1.4679684661178527e-05.
# Normalized cost function value=2.2441691894985736, variation=1.468536822057942e-05.
# Normalized cost function value=2.2441544986744053, variation=1.4690824168273053e-05.
# Normalized cost function value=2.244139802622228, variation=1.4696052177409769e-05.
# Normalized cost function value=2.2441251015701984, variation=1.4701052029497674e-05.
# Normalized cost function value=2.244110395746638, variation=1.4705823560223763e-05.
# Normalized cost function value=2.2440956853799054, variation=1.471036673272863e-05.
# Normalized cost function value=2.2440809706981137, variation=1.471468179170543e-05.
# Normalized cost function value=2.244066251929194, variation=1.471876891967483e-05.
# Normalized cost function value=2.2440515293006804, variation=1.472262851365258e-05.
# Normalized cost function value=2.2440368030395774, variation=1.4726261102993021e-05.
# Normalized cost function value=2.244022073372363, variation=1.4729667214385955e-05.
# Normalized cost function value=2.2440073405246372, variation=1.473284772579575e-05.
# Normalized cost function value=2.243992604721149, variation=1.4735803488097332e-05.
# Normalized cost function value=2.243977866185789, variation=1.4738535360159233e-05.
# Normalized cost function value=2.2439631251411294, variation=1.4741044659594138e-05.
# Normalized cost function value=2.243948381808738, variation=1.474333239137593e-05.
# Normalized cost function value=2.243933636408668, variation=1.4745400069848813e-05.
# Normalized cost function value=2.243918889159598, variation=1.4747249070357071e-05.
# Normalized cost function value=2.2439041402786497, variation=1.4748880948101117e-05.
# Normalized cost function value=2.243889389981166, variation=1.4750297483878683e-05.
# Normalized cost function value=2.243874638480796, variation=1.4751500369669657e-05.
# Normalized cost function value=2.2438598859891945, variation=1.4752491601655038e-05.
# Normalized cost function value=2.2438451327161526, variation=1.4753273041900883e-05.
# Normalized cost function value=2.2438303788691667, variation=1.4753846985904318e-05.
# Normalized cost function value=2.2438156246536365, variation=1.4754215530210502e-05.
# Normalized cost function value=2.2438008702725005, variation=1.4754381135961836e-05.
# Normalized cost function value=2.243786115926477, variation=1.475434602360437e-05.
# Normalized cost function value=2.2437713618136104, variation=1.4754112866555147e-05.
# Normalized cost function value=2.2437566081293725, variation=1.4753684237867049e-05.
# Normalized cost function value=2.243741855066391, variation=1.4753062981487375e-05.
# Normalized cost function value=2.2437271028147507, variation=1.4752251640270941e-05.
# Normalized cost function value=2.243712351561357, variation=1.475125339389649e-05.
# Normalized cost function value=2.2436976014904335, variation=1.4750070923330583e-05.
# Normalized cost function value=2.24368285278279, variation=1.4748707643619241e-05.
# Normalized cost function value=2.243668105616339, variation=1.4747166451112292e-05.
# Normalized cost function value=2.2436533601656357, variation=1.4745450703124163e-05.
# Normalized cost function value=2.2436386166019733, variation=1.4743563662378278e-05.
# Normalized cost function value=2.2436238750931956, variation=1.4741508777671442e-05.
# Normalized cost function value=2.2436091358037515, variation=1.4739289444065662e-05.
# Normalized cost function value=2.243594398894454, variation=1.473690929776339e-05.
# Normalized cost function value=2.2435796645226325, variation=1.4734371821312209e-05.
# Normalized cost function value=2.243564932841885, variation=1.4731680747281928e-05.
# Normalized cost function value=2.24355020400199, variation=1.472883989528384e-05.
# Normalized cost function value=2.243535478149044, variation=1.4725852945929319e-05.
# Normalized cost function value=2.2435207554252803, variation=1.4722723763682666e-05.
# Normalized cost function value=2.2435060359689256, variation=1.4719456354672644e-05.

# %%
errors[-1], len(errors)
# Out:
# (2.2435060359689256, 1000)

# %% [markdown]
# ### Beta = 0 (Itakura-Saito Divergence)

# %%
rank = 2
U_lines = 500
V_col = 250

U_0 = np.random.rand(U_lines, rank)
V_0 = np.random.rand(rank, V_col)
M = U_0@V_0 + 1e-2 * np.random.rand(U_lines, V_col)
U, V, errors, toc = nmf.nmf(M, rank, init = "random", n_iter_max = 1000, tol = 1e-8,update_rule = "mu",beta = 0,
           sparsity_coefficients = [None, None], fixed_modes = [], normalize = [False, False],
           verbose=True, return_costs = True)
# Out:
# Normalized cost function value=24706.352910197107
# Normalized cost function value=10001.4308653295, variation=14704.922044867608.
# Normalized cost function value=6264.243479565171, variation=3737.1873857643286.
# Normalized cost function value=5132.2216344404715, variation=1132.0218451246992.
# Normalized cost function value=4688.760792402879, variation=443.46084203759256.
# Normalized cost function value=4452.379148902639, variation=236.38164350024.
# Normalized cost function value=4295.094466316533, variation=157.2846825861061.
# Normalized cost function value=4178.121064141164, variation=116.97340217536839.
# Normalized cost function value=4086.6591946160374, variation=91.46186952512699.
# Normalized cost function value=4013.303993043774, variation=73.35520157226347.
# Normalized cost function value=3953.508857975731, variation=59.79513506804278.
# Normalized cost function value=3904.1532632344683, variation=49.35559474126285.
# Normalized cost function value=3862.976702201892, variation=41.1765610325765.
# Normalized cost function value=3828.294134426411, variation=34.68256777548095.
# Normalized cost function value=3798.8259153441313, variation=29.468219082279575.
# Normalized cost function value=3773.5860310606163, variation=25.23988428351504.
# Normalized cost function value=3751.8050184258136, variation=21.781012634802664.
# Normalized cost function value=3732.875336612936, variation=18.92968181287779.
# Normalized cost function value=3716.3119168949856, variation=16.563419717950183.
# Normalized cost function value=3701.7232315955284, variation=14.588685299457211.
# Normalized cost function value=3688.7897769043366, variation=12.933454691191855.
# Normalized cost function value=3677.2478489487357, variation=11.54192795560084.
# Normalized cost function value=3666.877138509446, variation=10.370710439289724.
# Normalized cost function value=3657.491102588697, variation=9.386035920749237.
# Normalized cost function value=3648.9293653945583, variation=8.561737194138459.
# Normalized cost function value=3641.05160382296, variation=7.877761571598512.
# Normalized cost function value=3633.7325130911913, variation=7.319090731768483.
# Normalized cost function value=3626.8575463256416, variation=6.874966765549743.
# Normalized cost function value=3620.3191905710296, variation=6.538355754611985.
# Normalized cost function value=3614.0135895637495, variation=6.3056010072800746.
# Normalized cost function value=3607.8373566324876, variation=6.176232931261893.
# Normalized cost function value=3601.684443388159, variation=6.152913244328829.
# Normalized cost function value=3595.442944417942, variation=6.2414989702169805.
# Normalized cost function value=3588.9917272711095, variation=6.451217146832278.
# Normalized cost function value=3582.196782513936, variation=6.794944757173653.
# Normalized cost function value=3574.90719234379, variation=7.289590170145857.
# Normalized cost function value=3566.9506201708573, variation=7.956572172932738.
# Normalized cost function value=3558.128230133343, variation=8.822390037514197.
# Normalized cost function value=3548.2089579055614, variation=9.919272227781676.
# Normalized cost function value=3536.9230767061335, variation=11.285881199427877.
# Normalized cost function value=3523.955040955929, variation=12.968035750204763.
# Normalized cost function value=3508.9356523440365, variation=15.019388611892282.
# Normalized cost function value=3491.4336891692546, variation=17.50196317478185.
# Normalized cost function value=3470.947282106503, variation=20.486407062751823.
# Normalized cost function value=3446.8955222174964, variation=24.051759889006462.
# Normalized cost function value=3418.611064560845, variation=28.284457656651284.
# Normalized cost function value=3385.334854476546, variation=33.27621008429924.
# Normalized cost function value=3346.214555424101, variation=39.12029905244481.
# Normalized cost function value=3300.308779483699, variation=45.905775940402236.
# Normalized cost function value=3246.5997624156294, variation=53.70901706806944.
# Normalized cost function value=3184.017580065373, variation=62.58218235025652.
# Normalized cost function value=3111.479196666322, variation=72.53838339905087.
# Normalized cost function value=3027.945313203617, variation=83.53388346270503.
# Normalized cost function value=2932.4968266446112, variation=95.44848655900569.
# Normalized cost function value=2824.4303982287133, variation=108.06642841589792.
# Normalized cost function value=2703.368967375098, variation=121.06143085361555.
# Normalized cost function value=2569.378164036014, variation=133.99080333908387.
# Normalized cost function value=2423.074131805859, variation=146.30403223015492.
# Normalized cost function value=2265.7036160095067, variation=157.37051579635227.
# Normalized cost function value=2099.1752023830923, variation=166.52841362641448.
# Normalized cost function value=1926.0232931910095, variation=173.1519091920827.
# Normalized cost function value=1749.2949457079542, variation=176.72834748305536.
# Normalized cost function value=1572.3634302699982, variation=176.93151543795602.
# Normalized cost function value=1398.6883192859973, variation=173.67511098400087.
# Normalized cost function value=1231.5553630415066, variation=167.13295624449074.
# Normalized cost function value=1073.835616227772, variation=157.71974681373445.
# Normalized cost function value=927.7997205270563, variation=146.03589570071586.
# Normalized cost function value=795.0109166215215, variation=132.7888039055348.
# Normalized cost function value=676.303367049423, variation=118.70754957209851.
# Normalized cost function value=571.8360599166958, variation=104.46730713272711.
# Normalized cost function value=481.20125314783354, variation=90.63480676886229.
# Normalized cost function value=403.56199127218736, variation=77.63926187564618.
# Normalized cost function value=337.7950362400736, variation=65.76695503211374.
# Normalized cost function value=282.6213630432922, variation=55.17367319678141.
# Normalized cost function value=236.71358678188466, variation=45.90777626140755.
# Normalized cost function value=198.77628189177116, variation=37.937304890113495.
# Normalized cost function value=167.60003017672415, variation=31.176251715047016.
# Normalized cost function value=142.09293979917655, variation=25.5070903775476.
# Normalized cost function value=121.29459850409648, variation=20.798341295080064.
# Normalized cost function value=104.37746809588452, variation=16.91713040821196.
# Normalized cost function value=90.64009888435562, variation=13.7373692115289.
# Normalized cost function value=79.49563590095704, variation=11.144462983398583.
# Normalized cost function value=70.45815859651967, variation=9.037477304437374.
# Normalized cost function value=63.12857932465617, variation=7.329579271863494.
# Normalized cost function value=57.18117642880527, variation=5.9474028958508995.
# Normalized cost function value=52.35135824462597, variation=4.829818184179302.
# Normalized cost function value=48.424922860090604, variation=3.926435384535367.
# Normalized cost function value=45.22886427823424, variation=3.196058581856363.
# Normalized cost function value=42.6236481109879, variation=2.60521616724634.
# Normalized cost function value=40.49681283368811, variation=2.12683527729979.
# Normalized cost function value=38.7577253007851, variation=1.7390875329030138.
# Normalized cost function value=37.33331643113861, variation=1.4244088696464843.
# Normalized cost function value=36.16463405995189, variation=1.1686823711867262.
# Normalized cost function value=35.204067838077094, variation=0.9605662218747923.
# Normalized cost function value=34.413121279169665, variation=0.7909465589074287.
# Normalized cost function value=33.76062599173943, variation=0.6524952874302343.
# Normalized cost function value=33.22131139676211, variation=0.5393145949773199.
# Normalized cost function value=32.77465921426558, variation=0.4466521824965284.
# Normalized cost function value=32.4039855650332, variation=0.3706736492323799.
# Normalized cost function value=32.095704796478245, variation=0.30828076855495823.
# Normalized cost function value=31.838738350741906, variation=0.25696644573633876.
# Normalized cost function value=31.62403943879881, variation=0.21469891194309554.
# Normalized cost function value=31.444210256389663, variation=0.17982918240914714.
# Normalized cost function value=31.293193240970865, variation=0.1510170154187982.
# Normalized cost function value=31.166021654260295, variation=0.1271715867105705.
# Normalized cost function value=31.058617776606592, variation=0.1074038776537023.
# Normalized cost function value=30.967629377263094, variation=0.09098839934349812.
# Normalized cost function value=30.890297008252777, variation=0.07733236901031759.
# Normalized cost function value=30.824346162640037, variation=0.06595084561273978.
# Normalized cost function value=30.76789952309241, variation=0.05644663954762663.
# Normalized cost function value=30.719405468732166, variation=0.04849405436024412.
# Normalized cost function value=30.677579758675304, variation=0.04182571005686242.
# Normalized cost function value=30.64135790959168, variation=0.036221849083624136.
# Normalized cost function value=30.60985626367115, variation=0.031501645920528176.
# Normalized cost function value=30.58234012737112, variation=0.027516136300032912.
# Normalized cost function value=30.558197669729623, variation=0.024142457641495696.
# Normalized cost function value=30.53691851723105, variation=0.02127915249857182.
# Normalized cost function value=30.518076182315646, variation=0.01884233491540499.
# Normalized cost function value=30.501313624228796, variation=0.016762558086849566.
# Normalized cost function value=30.486331371618526, variation=0.014982252610270308.
# Normalized cost function value=30.47287774216258, variation=0.013453629455945304.
# Normalized cost function value=30.460740780375215, variation=0.012136961787366118.
# Normalized cost function value=30.449741604459934, variation=0.010999175915280546.
# Normalized cost function value=30.43972890974834, variation=0.010012694711594605.
# Normalized cost function value=30.430574422369897, variation=0.009154487378442155.
# Normalized cost function value=30.422169134347932, variation=0.008405288021965163.
# Normalized cost function value=30.414420181918523, variation=0.007748952429409428.
# Normalized cost function value=30.40724825383268, variation=0.007171928085842438.
# Normalized cost function value=30.40058543678111, variation=0.0066628170515699026.
# Normalized cost function value=30.39437342172591, variation=0.006212015055201192.
# Normalized cost function value=30.388562008535956, variation=0.00581141318995293.
# Normalized cost function value=30.383107857455883, variation=0.0054541510800731885.
# Normalized cost function value=30.377973445056206, variation=0.005134412399677046.
# Normalized cost function value=30.37312618978057, variation=0.004847255275635121.
# Normalized cost function value=30.368537718332618, variation=0.004588471447952713.
# Normalized cost function value=30.364183249169848, variation=0.004354469162770158.
# Normalized cost function value=30.36004107349966, variation=0.004142175670189374.
# Normalized cost function value=30.356092117567545, variation=0.003948955932113307.
# Normalized cost function value=30.352319572815695, variation=0.003772544751850404.
# Normalized cost function value=30.34870858278986, variation=0.003610990025833871.
# Normalized cost function value=30.345245977568144, variation=0.003462605221717041.
# Normalized cost function value=30.34192004804225, variation=0.0033259295258929455.
# Normalized cost function value=30.33872035367816, variation=0.003199694364091954.
# Normalized cost function value=30.335637558444578, variation=0.003082795233581237.
# Normalized cost function value=30.33266329048092, variation=0.0029742679636584057.
# Normalized cost function value=30.329790021808403, variation=0.0028732686725163603.
# Normalized cost function value=30.327010964992063, variation=0.002779056816340386.
# Normalized cost function value=30.324319984164283, variation=0.002690980827779299.
# Normalized cost function value=30.32171151823973, variation=0.002608465924552661.
# Normalized cost function value=30.31918051449776, variation=0.0025310037419714604.
# Normalized cost function value=30.31672237099858, variation=0.0024581434991794993.
# Normalized cost function value=30.31433288654173, variation=0.002389484456848834.
# Normalized cost function value=30.31200821707517, variation=0.002324669466560181.
# Normalized cost function value=30.309744837635307, variation=0.0022633794398636553.
# Normalized cost function value=30.307539509036324, variation=0.002205328598982703.
# Normalized cost function value=30.305389248647383, variation=0.00215026038894095.
# Normalized cost function value=30.30329130469604, variation=0.0020979439513446607.
# Normalized cost function value=30.301243133619018, variation=0.0020481710770212658.
# Normalized cost function value=30.29924238005234, variation=0.0020007535666763943.
# Normalized cost function value=30.297286859112656, variation=0.001955520939684874.
# Normalized cost function value=30.295374540671542, variation=0.0019123184411142802.
# Normalized cost function value=30.29350353536674, variation=0.0018710053048032194.
# Normalized cost function value=30.29167208213137, variation=0.0018314532353684854.
# Normalized cost function value=30.2898785370515, variation=0.0017935450798702846.
# Normalized cost function value=30.288121363389365, variation=0.0017571736621349032.
# Normalized cost function value=30.286399122631757, variation=0.0017222407576085175.
# Normalized cost function value=30.28471046644078, variation=0.0016886561909750242.
# Normalized cost function value=30.28305412940236, variation=0.0016563370384226062.
# Normalized cost function value=30.28142892247981, variation=0.0016252069225473065.
# Normalized cost function value=30.27983372709265, variation=0.001595195387160686.
# Normalized cost function value=30.278267489751364, variation=0.0015662373412865804.
# Normalized cost function value=30.27672921718599, variation=0.0015382725653729779.
# Normalized cost function value=30.275217971916376, variation=0.0015112452696151024.
# Normalized cost function value=30.273732868216534, variation=0.0014851036998422273.
# Normalized cost function value=30.272273068431154, variation=0.0014597997853798006.
# Normalized cost function value=30.270837779609682, variation=0.0014352888214723691.
# Normalized cost function value=30.269426250424264, variation=0.0014115291854182033.
# Normalized cost function value=30.268037768344072, variation=0.0013884820801912667.
# Normalized cost function value=30.26667165704061, variation=0.0013661113034615369.
# Normalized cost function value=30.265327274001493, variation=0.0013443830391182132.
# Normalized cost function value=30.264004008333547, variation=0.0013232656679456056.
# Normalized cost function value=30.262701278736806, variation=0.001302729596741159.
# Normalized cost function value=30.26141853163404, variation=0.0012827471027669901.
# Normalized cost function value=30.260155239441563, variation=0.0012632921924762286.
# Normalized cost function value=30.25891089896923, variation=0.0012443404723327944.
# Normalized cost function value=30.257685029937267, variation=0.0012258690319626453.
# Normalized cost function value=30.25647717360068, variation=0.0012078563365882644.
# Normalized cost function value=30.25528689147205, variation=0.0011902821286291498.
# Normalized cost function value=30.254113764133713, variation=0.0011731273383368546.
# Normalized cost function value=30.25295739013283, variation=0.0011563740008817547.
# Normalized cost function value=30.251817384951877, variation=0.001140005180953807.
# Normalized cost function value=30.250693380048986, variation=0.001124004902891329.
# Normalized cost function value=30.24958502196238, variation=0.001108358086607808.
# Normalized cost function value=30.248491971473676, variation=0.0010930504887021186.
# Normalized cost function value=30.247413902826466, variation=0.001078068647210273.
# Normalized cost function value=30.246350502994044, variation=0.001063399832421652.
# Normalized cost function value=30.245301470995052, variation=0.0010490319989919783.
# Normalized cost function value=30.244266517251642, variation=0.0010349537434102274.
# Normalized cost function value=30.24324536298757, variation=0.0010211542640732318.
# Normalized cost function value=30.2422377396638, variation=0.0010076233237690246.
# Normalized cost function value=30.24124338844844, variation=0.0009943512153611778.
# Normalized cost function value=30.240262059718315, variation=0.0009813287301234652.
# Normalized cost function value=30.239293512591292, variation=0.0009685471270231005.
# Normalized cost function value=30.23833751448545, variation=0.0009559981058409051.
# Normalized cost function value=30.237393840704545, variation=0.0009436737809060958.
# Normalized cost function value=30.23646227404779, variation=0.0009315666567566439.
# Normalized cost function value=30.23554260444178, variation=0.0009196696060094212.
# Normalized cost function value=30.234634628593852, variation=0.0009079758479266786.
# Normalized cost function value=30.233738149664873, variation=0.0008964789289791497.
# Normalized cost function value=30.23285297696056, variation=0.0008851727043115432.
# Normalized cost function value=30.231978925640238, variation=0.0008740513203235878.
# Normalized cost function value=30.231115816441328, variation=0.0008631091989101947.
# Normalized cost function value=30.230263475419434, variation=0.0008523410218934657.
# Normalized cost function value=30.229421733702402, variation=0.0008417417170321073.
# Normalized cost function value=30.228590427257885, variation=0.0008313064445175655.
# Normalized cost function value=30.22776939667332, variation=0.0008210305845643973.
# Normalized cost function value=30.226958486947602, variation=0.0008109097257182896.
# Normalized cost function value=30.226157547294285, variation=0.0008009396533168456.
# Normalized cost function value=30.225366430954637, variation=0.0007911163396485676.
# Normalized cost function value=30.224584995021072, variation=0.0007814359335647225.
# Normalized cost function value=30.223813100269172, variation=0.0007718947518995378.
# Normalized cost function value=30.22305061099918, variation=0.000762489269991562.
# Normalized cost function value=30.222297394885146, variation=0.0007532161140346716.
# Normalized cost function value=30.22155332283189, variation=0.000744072053254996.
# Normalized cost function value=30.220818268839572, variation=0.0007350539923187682.
# Normalized cost function value=30.2200921098751, variation=0.0007261589644720345.
# Normalized cost function value=30.219374725749468, variation=0.000717384125632492.
# Normalized cost function value=30.218665999002287, variation=0.0007087267471810321.
# Normalized cost function value=30.21796581479128, variation=0.0007001842110057055.
# Normalized cost function value=30.21727406078741, variation=0.0006917540038706704.
# Normalized cost function value=30.21659062707581, variation=0.0006834337116004008.
# Normalized cost function value=30.21591540606078, variation=0.0006752210150295923.
# Normalized cost function value=30.215248292376067, variation=0.000667113684713172.
# Normalized cost function value=30.214589182799383, variation=0.000659109576684358.
# Normalized cost function value=30.21393797617083, variation=0.0006512066285537799.
# Normalized cost function value=30.213294573315796, variation=0.0006434028550330595.
# Normalized cost function value=30.212658876971112, variation=0.000635696344684078.
# Normalized cost function value=30.212030791715172, variation=0.0006280852559399364.
# Normalized cost function value=30.211410223900973, variation=0.0006205678141988358.
# Normalized cost function value=30.210797081592737, variation=0.0006131423082358367.
# Normalized cost function value=30.21019127450536, variation=0.0006058070873784516.
# Normalized cost function value=30.209592713946765, variation=0.0005985605585934195.
# Normalized cost function value=30.20900131276314, variation=0.0005914011836267719.
# Normalized cost function value=30.208416985286547, variation=0.0005843274765915396.
# Normalized cost function value=30.207839647284835, variation=0.0005773380017117802.
# Normalized cost function value=30.207269215914614, variation=0.0005704313702210584.
# Normalized cost function value=30.206705609675407, variation=0.0005636062392078145.
# Normalized cost function value=30.206148748366818, variation=0.0005568613085884522.
# Normalized cost function value=30.205598553047192, variation=0.0005501953196258569.
# Normalized cost function value=30.20505494599417, variation=0.0005436070530215886.
# Normalized cost function value=30.204517850667507, variation=0.0005370953266634615.
# Normalized cost function value=30.20398719167293, variation=0.0005306589945774931.
# Normalized cost function value=30.203462894728222, variation=0.0005242969447074586.
# Normalized cost function value=30.202944886630306, variation=0.000518008097916578.
# Normalized cost function value=30.202433095224514, variation=0.0005117914057919393.
# Normalized cost function value=30.2019274493745, variation=0.0005056458500121153.
# Normalized cost function value=30.201427878933956, variation=0.0004995704405459378.
# Normalized cost function value=30.20093431471943, variation=0.0004935642145262875.
# Normalized cost function value=30.200446688484398, variation=0.00048762623503151303.
# Normalized cost function value=30.199964932894524, variation=0.0004817555898739556.
# Normalized cost function value=30.199488981503777, variation=0.00047595139074729786.
# Normalized cost function value=30.199018768732046, variation=0.0004702127717308713.
# Normalized cost function value=30.19855422984308, variation=0.0004645388889663593.
# Normalized cost function value=30.198095300924045, variation=0.0004589289190342072.
# Normalized cost function value=30.197641918865628, variation=0.00045338205841716217.
# Normalized cost function value=30.197194021342877, variation=0.000447897522750651.
# Normalized cost function value=30.196751546797106, variation=0.0004424745457711765.
# Normalized cost function value=30.196314434418543, variation=0.00043711237856314256.
# Normalized cost function value=30.19588262412951, variation=0.0004318102890330522.
# Normalized cost function value=30.19545605656848, variation=0.00042656756102843474.
# Normalized cost function value=30.195034673074794, variation=0.00042138349368769923.
# Normalized cost function value=30.19461841567402, variation=0.0004162574007722242.
# Normalized cost function value=30.194207227063618, variation=0.0004111886104034568.
# Normalized cost function value=30.193801050599575, variation=0.0004061764640432841.
# Normalized cost function value=30.19339983028374, variation=0.00040122031583322837.
# Normalized cost function value=30.193003510750543, variation=0.0003963195331984082.
# Normalized cost function value=30.19261203725624, variation=0.00039147349430379563.
# Normalized cost function value=30.192225355666057, variation=0.00038668159018229176.
# Normalized cost function value=30.191843412444317, variation=0.0003819432217397889.
# Normalized cost function value=30.191466154643237, variation=0.0003772578010803329.
# Normalized cost function value=30.19109352989274, variation=0.0003726247504971525.
# Normalized cost function value=30.190725486390868, variation=0.00036804350187225054.
# Normalized cost function value=30.190361972894145, variation=0.0003635134967225895.
# Normalized cost function value=30.190002938708705, variation=0.00035903418543981047.
# Normalized cost function value=30.189648333681127, variation=0.0003546050275780033.
# Normalized cost function value=30.189298108190414, variation=0.0003502254907132851.
# Normalized cost function value=30.188952213139682, variation=0.00034589505073157056.
# Normalized cost function value=30.18861059994817, variation=0.0003416131915123799.
# Normalized cost function value=30.1882732205439, variation=0.0003373794042715872.
# Normalized cost function value=30.187940027356273, variation=0.0003331931876253691.
# Normalized cost function value=30.187610973308992, variation=0.00032905404728111876.
# Normalized cost function value=30.187286011813114, variation=0.0003249614958775737.
# Normalized cost function value=30.186965096760698, variation=0.00032091505241638174.
# Normalized cost function value=30.186648182518304, variation=0.00031691424239355115.
# Normalized cost function value=30.18633522392051, variation=0.0003129585977958982.
# Normalized cost function value=30.18602617626463, variation=0.0003090476558789135.
# Normalized cost function value=30.185720995304177, variation=0.0003051809604528444.
# Normalized cost function value=30.185419637243555, variation=0.0003013580606214816.
# Normalized cost function value=30.18512205873279, variation=0.0002975785107643958.
# Normalized cost function value=30.184828216861792, variation=0.00029384187099879.
# Normalized cost function value=30.184538069155614, variation=0.00029014770617763475.
# Normalized cost function value=30.18425157356916, variation=0.0002864955864545493.
# Normalized cost function value=30.183968688482476, variation=0.0002828850866833932.
# Normalized cost function value=30.18368937269615, variation=0.0002793157863258955.
# Normalized cost function value=30.183413585426173, variation=0.0002757872699774566.
# Normalized cost function value=30.183141286300227, variation=0.00027229912594606276.
# Normalized cost function value=30.18287243535256, variation=0.00026885094766626594.
# Normalized cost function value=30.182606993020382, variation=0.00026544233217862256.
# Normalized cost function value=30.182344920139023, variation=0.00026207288135893236.
# Normalized cost function value=30.182086177938466, variation=0.00025874220055754904.
# Normalized cost function value=30.18183072803911, variation=0.0002554498993561083.
# Normalized cost function value=30.181578532447787, variation=0.00025219559132239056.
# Normalized cost function value=30.181329553554065, variation=0.0002489788937225512.
# Normalized cost function value=30.181083754126696, variation=0.0002457994273683539.
# Normalized cost function value=30.18084109730979, variation=0.00024265681690494034.
# Normalized cost function value=30.180601546619098, variation=0.0002395506906935907.
# Normalized cost function value=30.180365065938794, variation=0.00023648068030368563.
# Normalized cost function value=30.180131619517994, variation=0.00023344642080047606.
# Normalized cost function value=30.179901171967153, variation=0.00023044755084100643.
# Normalized cost function value=30.179673688254965, variation=0.00022748371218739294.
# Normalized cost function value=30.179449133705187, variation=0.0002245545497778778.
# Normalized cost function value=30.179227473993052, variation=0.00022165971213539137.
# Normalized cost function value=30.179008675142637, variation=0.0002187988504154248.
# Normalized cost function value=30.178792703523182, variation=0.0002159716194540806.
# Normalized cost function value=30.17857952584664, variation=0.0002131776765423865.
# Normalized cost function value=30.17836910916428, variation=0.00021041668236065902.
# Normalized cost function value=30.178161420863745, variation=0.00020768830053441434.
# Normalized cost function value=30.17795642866619, variation=0.00020499219755620857.
# Normalized cost function value=30.177754100623584, variation=0.00020232804260444937.
# Normalized cost function value=30.177554405115394, variation=0.00019969550818998982.
# Normalized cost function value=30.177357310846432, variation=0.00019709426896241666.
# Normalized cost function value=30.17716278684326, variation=0.00019452400317021556.
# Normalized cost function value=30.176970802452306, variation=0.0001919843909554686.
# Normalized cost function value=30.176781327336382, variation=0.00018947511592415367.
# Normalized cost function value=30.176594331472604, variation=0.00018699586377834976.
# Normalized cost function value=30.17640978514934, variation=0.00018454632326481146.
# Normalized cost function value=30.176227658963757, variation=0.00018212618558166582.
# Normalized cost function value=30.176047923819173, variation=0.0001797351445844697.
# Normalized cost function value=30.175870550922493, variation=0.0001773728966796284.
# Normalized cost function value=30.175695511781544, variation=0.00017503914094874062.
# Normalized cost function value=30.175522778202946, variation=0.00017273357859792782.
# Normalized cost function value=30.175352322288795, variation=0.00017045591415154604.
# Normalized cost function value=30.175184116435304, variation=0.00016820585349108796.
# Normalized cost function value=30.17501813332924, variation=0.0001659831060649708.
# Normalized cost function value=30.174854345946134, variation=0.00016378738310507401.
# Normalized cost function value=30.174692727547697, variation=0.00016161839843675807.
# Normalized cost function value=30.174533251679346, variation=0.00015947586835096672.
# Normalized cost function value=30.17437589216784, variation=0.00015735951150475103.
# Normalized cost function value=30.174220623119094, variation=0.0001552690487471864.
# Normalized cost function value=30.174067418915424, variation=0.00015320420367004317.
# Normalized cost function value=30.173916254213594, variation=0.0001511647018297424.
# Normalized cost function value=30.17376710394233, variation=0.00014915027126605196.
# Normalized cost function value=30.17361994329995, variation=0.00014716064237774162.
# Normalized cost function value=30.17347474775223, variation=0.00014519554772007837.
# Normalized cost function value=30.173331493030094, variation=0.00014325472213627677.
# Normalized cost function value=30.173190155127127, variation=0.00014133790296710913.
# Normalized cost function value=30.17305071029758, variation=0.00013944482954642012.
# Normalized cost function value=30.1729131350542, variation=0.0001375752433823152.
# Normalized cost function value=30.172777406165633, variation=0.00013572888856572263.
# Normalized cost function value=30.172643500654644, variation=0.00013390551098879655.
# Normalized cost function value=30.172511395795528, variation=0.0001321048591158558.
# Normalized cost function value=30.17238106911239, variation=0.00013032668313783802.
# Normalized cost function value=30.17225249837638, variation=0.00012857073600969215.
# Normalized cost function value=30.17212566160416, variation=0.00012683677222113943.
# Normalized cost function value=30.172000537055293, variation=0.00012512454886604019.
# Normalized cost function value=30.171877103230276, variation=0.0001234338250171163.
# Normalized cost function value=30.17175533886866, variation=0.00012176436161581705.
# Normalized cost function value=30.171635222946275, variation=0.0001201159223853665.
# Normalized cost function value=30.17151673467398, variation=0.00011848827229599124.
# Normalized cost function value=30.17139985349484, variation=0.0001168811791387725.
# Normalized cost function value=30.1712845590826, variation=0.00011529441223956383.
# Normalized cost function value=30.17117083133917, variation=0.00011372774342888192.
# Normalized cost function value=30.17105865039306, variation=0.00011218094611109564.
# Normalized cost function value=30.17094799659677, variation=0.00011065379629116023.
# Normalized cost function value=30.170838850525243, variation=0.00010914607152656686.
# Normalized cost function value=30.170731192973665, variation=0.00010765755157748913.
# Normalized cost function value=30.17062500495519, variation=0.00010618801847428472.
# Normalized cost function value=30.170520267699594, variation=0.00010473725559734248.
# Normalized cost function value=30.170416962650673, variation=0.00010330504892053227.
# Normalized cost function value=30.170315071464444, variation=0.00010189118622960791.
# Normalized cost function value=30.170214576007474, variation=0.00010049545696944051.
# Normalized cost function value=30.170115458354324, variation=9.911765314996046e-05.
# Normalized cost function value=30.17001770078631, variation=9.77575680138898e-05.
# Normalized cost function value=30.16992128578895, variation=9.64149973619044e-05.
# Normalized cost function value=30.169826196050426, variation=9.508973852234703e-05.
# Normalized cost function value=30.169732414459688, variation=9.378159073847314e-05.
# Normalized cost function value=30.169639924104246, variation=9.249035544200979e-05.
# Normalized cost function value=30.169548708268497, variation=9.121583574867032e-05.
# Normalized cost function value=30.169458750431872, variation=8.99578366251319e-05.
# Normalized cost function value=30.169370034266993, variation=8.871616487837741e-05.
# Normalized cost function value=30.169282543637507, variation=8.749062948609776e-05.
# Normalized cost function value=30.1691962625967, variation=8.628104080798948e-05.
# Normalized cost function value=30.169111175385275, variation=8.508721142419517e-05.
# Normalized cost function value=30.16902726642984, variation=8.390895543541887e-05.
# Normalized cost function value=30.16894452034078, variation=8.274608905978198e-05.
# Normalized cost function value=30.168862921910787, variation=8.159842999333478e-05.
# Normalized cost function value=30.168782456112922, variation=8.046579786480379e-05.
# Normalized cost function value=30.16870310809854, variation=7.934801438125305e-05.
# Normalized cost function value=30.16862486319601, variation=7.824490253227623e-05.
# Normalized cost function value=30.168547706909017, variation=7.715628699145327e-05.
# Normalized cost function value=30.168471624913934, variation=7.608199508268854e-05.
# Normalized cost function value=30.168396603059286, variation=7.502185464858258e-05.
# Normalized cost function value=30.168322627363175, variation=7.397569611100607e-05.
# Normalized cost function value=30.168249684011823, variation=7.294335135199503e-05.
# Normalized cost function value=30.1681777593579, variation=7.192465392336089e-05.
# Normalized cost function value=30.168106839919062, variation=7.09194388370804e-05.
# Normalized cost function value=30.168036912375715, variation=6.992754334689266e-05.
# Normalized cost function value=30.16796796356988, variation=6.89488058362997e-05.
# Normalized cost function value=30.167899980503257, variation=6.798306662147979e-05.
# Normalized cost function value=30.167832950335608, variation=6.70301676493068e-05.
# Normalized cost function value=30.167766860383242, variation=6.608995236589976e-05.
# Normalized cost function value=30.167701698117273, variation=6.516226596886554e-05.
# Normalized cost function value=30.167637451162143, variation=6.424695513018719e-05.
# Normalized cost function value=30.167574107293763, variation=6.334386837991701e-05.
# Normalized cost function value=30.167511654438353, variation=6.245285540984469e-05.
# Normalized cost function value=30.16745008067041, variation=6.157376794391212e-05.
# Normalized cost function value=30.16738937421142, variation=6.070645898859084e-05.
# Normalized cost function value=30.16732952342817, variation=5.9850783252102246e-05.
# Normalized cost function value=30.167270516831476, variation=5.9006596693222946e-05.
# Normalized cost function value=30.16721234307415, variation=5.817375732419805e-05.
# Normalized cost function value=30.167154990950028, variation=5.735212412361079e-05.
# Normalized cost function value=30.16709844939206, variation=5.654155796719351e-05.
# Normalized cost function value=30.167042707471094, variation=5.5741920967022907e-05.
# Normalized cost function value=30.16698775439419, variation=5.4953076904951104e-05.
# Normalized cost function value=30.16693357950315, variation=5.417489103720641e-05.
# Normalized cost function value=30.166880172273366, variation=5.340722978530721e-05.
# Normalized cost function value=30.166827522311827, variation=5.2649961538975276e-05.
# Normalized cost function value=30.16677561935617, variation=5.190295565782321e-05.
# Normalized cost function value=30.166724453273165, variation=5.116608300426151e-05.
# Normalized cost function value=30.166674014057023, variation=5.0439216142450505e-05.
# Normalized cost function value=30.166624291828217, variation=4.972222880539334e-05.
# Normalized cost function value=30.166575276832056, variation=4.901499616138949e-05.
# Normalized cost function value=30.166526959437356, variation=4.8317394700347904e-05.
# Normalized cost function value=30.166479330134962, variation=4.7629302393659145e-05.
# Normalized cost function value=30.166432379536406, variation=4.6950598555639544e-05.
# Normalized cost function value=30.166386098372634, variation=4.628116377247693e-05.
# Normalized cost function value=30.16634047749257, variation=4.562088006210274e-05.
# Normalized cost function value=30.16629550786197, variation=4.496963060063308e-05.
# Normalized cost function value=30.166251180561755, variation=4.432730021619591e-05.
# Normalized cost function value=30.166207486787215, variation=4.3693774539832475e-05.
# Normalized cost function value=30.166164417846325, variation=4.306894089012303e-05.
# Normalized cost function value=30.166121965158396, variation=4.2452687928573596e-05.
# Normalized cost function value=30.166080120253312, variation=4.1844905084076345e-05.
# Normalized cost function value=30.16603887476967, variation=4.1245483643592706e-05.
# Normalized cost function value=30.16599822045419, variation=4.0654315480281866e-05.
# Normalized cost function value=30.16595814915961, variation=4.0071294577614935e-05.
# Normalized cost function value=30.165918652844244, variation=3.949631536670495e-05.
# Normalized cost function value=30.165879723570534, variation=3.892927371040855e-05.
# Normalized cost function value=30.165841353503595, variation=3.837006693885314e-05.
# Normalized cost function value=30.165803534910403, variation=3.7818593192184835e-05.
# Normalized cost function value=30.165766260158335, variation=3.727475206716235e-05.
# Normalized cost function value=30.16572952171407, variation=3.6738444265438375e-05.
# Normalized cost function value=30.16569331214256, variation=3.62095715082944e-05.
# Normalized cost function value=30.165657624105727, variation=3.5688036835068715e-05.
# Normalized cost function value=30.16562245036127, variation=3.5173744457495104e-05.
# Normalized cost function value=30.165587783761897, variation=3.4666599372457085e-05.
# Normalized cost function value=30.165553617253657, variation=3.4166508239508175e-05.
# Normalized cost function value=30.165519943875417, variation=3.36733782404508e-05.
# Normalized cost function value=30.165486756757282, variation=3.3187118134492266e-05.
# Normalized cost function value=30.165454049119756, variation=3.2707637526385724e-05.
# Normalized cost function value=30.16542181427268, variation=3.2234847076040296e-05.
# Normalized cost function value=30.165390045614014, variation=3.1768658665498606e-05.
# Normalized cost function value=30.165358736629006, variation=3.130898500813828e-05.
# Normalized cost function value=30.165327880888956, variation=3.085574005012859e-05.
# Normalized cost function value=30.16529747205022, variation=3.040883873595135e-05.
# Normalized cost function value=30.16526750385324, variation=2.996819697997921e-05.
# Normalized cost function value=30.165237970121595, variation=2.9533731645159378e-05.
# Normalized cost function value=30.165208864760682, variation=2.9105360912495826e-05.
# Normalized cost function value=30.16518018175721, variation=2.8683003471030588e-05.
# Normalized cost function value=30.165151915177812, variation=2.8266579398916747e-05.
# Normalized cost function value=30.165124059168228, variation=2.7856009584326102e-05.
# Normalized cost function value=30.165096607952428, variation=2.745121580005616e-05.
# Normalized cost function value=30.165069555831465, variation=2.7052120962878234e-05.
# Normalized cost function value=30.165042897182694, variation=2.6658648771160642e-05.
# Normalized cost function value=30.165016626458634, variation=2.6270724060140083e-05.
# Normalized cost function value=30.164990738186336, variation=2.5888272297436288e-05.
# Normalized cost function value=30.164965226966373, variation=2.551121996319239e-05.
# Normalized cost function value=30.164940087471656, variation=2.5139494717052457e-05.
# Normalized cost function value=30.164915314446922, variation=2.477302473380405e-05.
# Normalized cost function value=30.1648909027076, variation=2.4411739321550385e-05.
# Normalized cost function value=30.164866847139173, variation=2.4055568427883145e-05.
# Normalized cost function value=30.16484314269599, variation=2.3704443183447665e-05.
# Normalized cost function value=30.164819784400613, variation=2.3358295376141314e-05.
# Normalized cost function value=30.164796767342885, variation=2.3017057728225154e-05.
# Normalized cost function value=30.164774086679348, variation=2.2680663537499868e-05.
# Normalized cost function value=30.16475173763194, variation=2.234904740916477e-05.
# Normalized cost function value=30.16472971548752, variation=2.2022144417377376e-05.
# Normalized cost function value=30.164708015596982, variation=2.1699890538684485e-05.
# Normalized cost function value=30.164686633374497, variation=2.1382222485044622e-05.
# Normalized cost function value=30.16466556429647, variation=2.1069078027124988e-05.
# Normalized cost function value=30.16464480390109, variation=2.0760395379681995e-05.
# Normalized cost function value=30.16462434778742, variation=2.045611367051947e-05.
# Normalized cost function value=30.164604191614377, variation=2.0156173043517356e-05.
# Normalized cost function value=30.164584331100386, variation=1.986051399072153e-05.
# Normalized cost function value=30.164564762022444, variation=1.9569077942094282e-05.
# Normalized cost function value=30.16454548021519, variation=1.9281807254856176e-05.
# Normalized cost function value=30.164526481570586, variation=1.899864460241929e-05.
# Normalized cost function value=30.16450776203678, variation=1.871953380572222e-05.
# Normalized cost function value=30.164489317617583, variation=1.8444419197294337e-05.
# Normalized cost function value=30.164471144371625, variation=1.8173245958763573e-05.
# Normalized cost function value=30.164453238412086, variation=1.790595953821139e-05.
# Normalized cost function value=30.164435595905186, variation=1.7642506900727994e-05.
# Normalized cost function value=30.164418213070377, variation=1.7382834808898906e-05.
# Normalized cost function value=30.164401086178998, variation=1.712689137889356e-05.
# Normalized cost function value=30.16438421155407, variation=1.6874624929386073e-05.
# Normalized cost function value=30.164367585569252, variation=1.662598481644295e-05.
# Normalized cost function value=30.164351204648465, variation=1.638092078692921e-05.
# Normalized cost function value=30.164335065264986, variation=1.6139383479440994e-05.
# Normalized cost function value=30.164319163941133, variation=1.5901323852318683e-05.
# Normalized cost function value=30.16430349724731, variation=1.5666693823135347e-05.
# Normalized cost function value=30.164288061801635, variation=1.5435445675393566e-05.
# Normalized cost function value=30.164272854269022, variation=1.5207532612748764e-05.
# Normalized cost function value=30.164257871361023, variation=1.4982907998728479e-05.
# Normalized cost function value=30.164243109834572, variation=1.4761526450968177e-05.
# Normalized cost function value=30.16422856649217, variation=1.4543342402362214e-05.
# Normalized cost function value=30.164214238180502, variation=1.4328311667810567e-05.
# Normalized cost function value=30.16420012179049, variation=1.4116390012475222e-05.
# Normalized cost function value=30.16418621425635, variation=1.3907534139434574e-05.
# Normalized cost function value=30.16417251255513, variation=1.3701701220725226e-05.
# Normalized cost function value=30.164159013706204, variation=1.3498848925763696e-05.
# Normalized cost function value=30.164145714770584, variation=1.329893562029838e-05.
# Normalized cost function value=30.164132612850395, variation=1.3101920188773875e-05.
# Normalized cost function value=30.164119705088403, variation=1.2907761991698408e-05.
# Normalized cost function value=30.16410698866763, variation=1.2716420773273285e-05.
# Normalized cost function value=30.16409446081032, variation=1.2527857311539492e-05.
# Normalized cost function value=30.16408211877794, variation=1.2342032377432588e-05.
# Normalized cost function value=30.164069959870496, variation=1.215890744532544e-05.
# Normalized cost function value=30.16405798142564, variation=1.1978444856453052e-05.
# Normalized cost function value=30.164046180819028, variation=1.1800606610989917e-05.
# Normalized cost function value=30.16403455546277, variation=1.1625356258093689e-05.
# Normalized cost function value=30.16402310280579, variation=1.1452656980992515e-05.
# Normalized cost function value=30.164011820332824, variation=1.12824729647798e-05.
# Normalized cost function value=30.16400070556437, variation=1.1114768454945079e-05.
# Normalized cost function value=30.163989756055607, variation=1.0949508762791993e-05.
# Normalized cost function value=30.163978969396528, variation=1.0786659078831917e-05.
# Normalized cost function value=30.163968343211067, variation=1.0626185460438364e-05.
# Normalized cost function value=30.16395787515703, variation=1.046805403603912e-05.
# Normalized cost function value=30.163947562925053, variation=1.0312231978559794e-05.
# Normalized cost function value=30.16393740423887, variation=1.0158686183814325e-05.
# Normalized cost function value=30.16392739685434, variation=1.000738452816563e-05.
# Normalized cost function value=30.16391753855908, variation=9.858295261011563e-06.
# Normalized cost function value=30.16390782717234, variation=9.711386738331385e-06.
# Normalized cost function value=30.163898260544183, variation=9.566628158097501e-06.
# Normalized cost function value=30.163888836555504, variation=9.423988679202466e-06.
# Normalized cost function value=30.163879553117102, variation=9.28343840200796e-06.
# Normalized cost function value=30.16387040816958, variation=9.14494752279893e-06.
# Normalized cost function value=30.163861399683068, variation=9.008486511419278e-06.
# Normalized cost function value=30.163852525656356, variation=8.874026711680472e-06.
# Normalized cost function value=30.16384378411714, variation=8.741539215151306e-06.
# Normalized cost function value=30.163835173121004, variation=8.610996136582116e-06.
# Normalized cost function value=30.163826690751335, variation=8.482369668882939e-06.
# Normalized cost function value=30.163818335119018, variation=8.355632317602613e-06.
# Normalized cost function value=30.163810104362025, variation=8.230756993299337e-06.
# Normalized cost function value=30.16380199664484, variation=8.107717185623642e-06.
# Normalized cost function value=30.163794010158213, variation=7.986486625810585e-06.
# Normalized cost function value=30.163786143118934, variation=7.867039279574328e-06.
# Normalized cost function value=30.163778393769352, variation=7.74934958158724e-06.
# Normalized cost function value=30.163770760376952, variation=7.633392399952754e-06.
# Normalized cost function value=30.16376324123414, variation=7.519142812384416e-06.
# Normalized cost function value=30.163755834657923, variation=7.4065762163399995e-06.
# Normalized cost function value=30.163748538989335, variation=7.295668588369608e-06.
# Normalized cost function value=30.16374135259342, variation=7.186395915681487e-06.
# Normalized cost function value=30.16373427385863, variation=7.078734789445207e-06.
# Normalized cost function value=30.16372730119669, variation=6.972661939386171e-06.
# Normalized cost function value=30.163720433042254, variation=6.868154436290297e-06.
# Normalized cost function value=30.163713667852367, variation=6.765189887403267e-06.
# Normalized cost function value=30.163707004106453, variation=6.663745914181618e-06.
# Normalized cost function value=30.16370044030586, variation=6.563800592829239e-06.
# Normalized cost function value=30.16369397497355, variation=6.465332308636107e-06.
# Normalized cost function value=30.163687606653827, variation=6.368319724003868e-06.
# Normalized cost function value=30.16368133391207, variation=6.272741757129552e-06.
# Normalized cost function value=30.16367515533432, variation=6.178577748983116e-06.
# Normalized cost function value=30.163669069527074, variation=6.085807246591912e-06.
# Normalized cost function value=30.16366307511709, variation=5.994409985277116e-06.
# Normalized cost function value=30.163657170751, variation=5.904366087605695e-06.
# Normalized cost function value=30.163651355094935, variation=5.81565606694312e-06.
# Normalized cost function value=30.163645626834416, variation=5.7282605183672786e-06.
# Normalized cost function value=30.16363998467413, variation=5.642160285646014e-06.
# ...
# Normalized cost function value=30.1632853932208, variation=1.834891278917894e-07.
# Normalized cost function value=30.163285212551557, variation=1.806692431216561e-07.
# Normalized cost function value=30.163285034658855, variation=1.778927014584042e-07.
# Normalized cost function value=30.163284859500205, variation=1.7515865025075072e-07.
# Normalized cost function value=30.163284687033645, variation=1.7246656014435757e-07.
# Normalized cost function value=30.163284517217964, variation=1.698156815166385e-07.
# Normalized cost function value=30.16328435001236, variation=1.6720560225280678e-07.
# Normalized cost function value=30.163284185376938, variation=1.6463542351630167e-07.
# Normalized cost function value=30.163284023272286, variation=1.621046514799218e-07.
# Normalized cost function value=30.163283863659473, variation=1.5961281363274793e-07.
# Normalized cost function value=30.16328370650035, variation=1.5715912127234333e-07.
# Normalized cost function value=30.163283551757313, variation=1.547430379389425e-07.
# Normalized cost function value=30.16328339939319, variation=1.523641230960493e-07.
# Normalized cost function value=30.163283249371652, variation=1.500215383032355e-07.
# Normalized cost function value=30.163283101656624, variation=1.4771502776511625e-07.
# Normalized cost function value=30.16328295621276, variation=1.4544386317538738e-07.
# Normalized cost function value=30.163282813005235, variation=1.432075258378518e-07.
# Normalized cost function value=30.163282671999674, variation=1.410055610051586e-07.
# Normalized cost function value=30.16328253316239, variation=1.388372830035678e-07.
# Normalized cost function value=30.163282396460044, variation=1.3670234721985253e-07.
# Normalized cost function value=30.16328226185987, variation=1.3460017456168316e-07.
# Normalized cost function value=30.163282129329566, variation=1.3253030317628145e-07.
# Normalized cost function value=30.163281998837462, variation=1.3049210423332624e-07.
# Normalized cost function value=30.163281870352268, variation=1.2848519403974024e-07.
# Normalized cost function value=30.163281743843136, variation=1.2650913205902725e-07.
# Normalized cost function value=30.16328161927972, variation=1.2456341735855858e-07.
# Normalized cost function value=30.163281496632123, variation=1.2264759519098334e-07.
# Normalized cost function value=30.163281375871083, variation=1.2076104027869405e-07.
# Normalized cost function value=30.163281256967494, variation=1.189035891968615e-07.
# Normalized cost function value=30.163281139892874, variation=1.170746202205919e-07.
# Normalized cost function value=30.16328102461915, variation=1.1527372478781217e-07.
# Normalized cost function value=30.16328091111877, variation=1.1350038064961154e-07.
# Normalized cost function value=30.16328079936433, variation=1.117544385920155e-07.
# Normalized cost function value=30.16328068932907, variation=1.1003525912656187e-07.
# Normalized cost function value=30.163280580986736, variation=1.0834233421519457e-07.
# Normalized cost function value=30.163280474311136, variation=1.0667559990906739e-07.
# Normalized cost function value=30.163280369276816, variation=1.0503432079644881e-07.
# Normalized cost function value=30.16328026585852, variation=1.0341829437265915e-07.
# Normalized cost function value=30.163280164031338, variation=1.0182718312989891e-07.
# Normalized cost function value=30.163280063770962, variation=1.0026037600141535e-07.
# Normalized cost function value=30.163279965053306, variation=9.871765627167406e-08.
# Normalized cost function value=30.163279867854662, variation=9.71986438003114e-08.
# Normalized cost function value=30.16327977215167, variation=9.570299042138686e-08.
# Normalized cost function value=30.16327967792133, variation=9.423034086353255e-08.
# Normalized cost function value=30.163279585141105, variation=9.278022616854287e-08.
# Normalized cost function value=30.163279493788632, variation=9.135247225344756e-08.
# Normalized cost function value=30.163279403841983, variation=8.994664923989149e-08.
# Normalized cost function value=30.163279315279663, variation=8.856232014409215e-08.
# Normalized cost function value=30.163279228080267, variation=8.71993961482076e-08.
# Normalized cost function value=30.163279142222926, variation=8.585734079247231e-08.
# Normalized cost function value=30.163279057687017, variation=8.453590893964247e-08.
# Normalized cost function value=30.163278974452226, variation=8.3234791503628e-08.
# Normalized cost function value=30.163278892498564, variation=8.195366163477047e-08.
# Normalized cost function value=30.163278811806343, variation=8.069222090512085e-08.
# Normalized cost function value=30.16327873235621, variation=7.945013180687965e-08.
# Normalized cost function value=30.16327865412897, variation=7.82272415733587e-08.
# Normalized cost function value=30.1632785771059, variation=7.702307058821134e-08.
# Normalized cost function value=30.16327850126855, variation=7.5837348845198e-08.
# Normalized cost function value=30.16327842659856, variation=7.466999107919037e-08.
# Normalized cost function value=30.163278353078127, variation=7.352043240871353e-08.
# Normalized cost function value=30.163278280689507, variation=7.23886195430623e-08.
# Normalized cost function value=30.16327820941527, variation=7.127423629071927e-08.
# Normalized cost function value=30.163278139238294, variation=7.017697711830806e-08.
# Normalized cost function value=30.16327807014184, variation=6.909645478003767e-08.
# Normalized cost function value=30.163278002109156, variation=6.803268348676283e-08.
# Normalized cost function value=30.16327793512393, variation=6.698522625470105e-08.
# Normalized cost function value=30.16327786917006, variation=6.595386992103158e-08.
# Normalized cost function value=30.163277804231626, variation=6.493843329735682e-08.
# Normalized cost function value=30.16327774029317, variation=6.393845453089853e-08.
# Normalized cost function value=30.16327767733914, variation=6.29540330976397e-08.
# Normalized cost function value=30.163277615354588, variation=6.198455082540022e-08.
# Normalized cost function value=30.163277554324402, variation=6.103018534986404e-08.
# Normalized cost function value=30.163277494234038, variation=6.009036468412887e-08.
# Normalized cost function value=30.163277435069038, variation=5.916500001035274e-08.
# Normalized cost function value=30.163277376815103, variation=5.8253935009133784e-08.
# Normalized cost function value=30.16327731945833, variation=5.735677177653997e-08.
# Normalized cost function value=30.16327726298476, variation=5.6473570708703846e-08.
# Normalized cost function value=30.16327720738095, variation=5.560380955671462e-08.
# Normalized cost function value=30.163277152633487, variation=5.474746345157655e-08.
# Normalized cost function value=30.16327709872917, variation=5.390431567775522e-08.
# Normalized cost function value=30.163277045655057, variation=5.307411399257944e-08.
# Normalized cost function value=30.16327699339836, variation=5.2256698523933665e-08.
# Normalized cost function value=30.163276941946545, variation=5.145181347643302e-08.
# Normalized cost function value=30.163276891287172, variation=5.065937358494921e-08.
# Normalized cost function value=30.163276841408067, variation=4.987910529052897e-08.
# Normalized cost function value=30.163276792297307, variation=4.9110759903214785e-08.
# Normalized cost function value=30.16327674394291, variation=4.8354397819139194e-08.
# Normalized cost function value=30.16327669633341, variation=4.760950034210509e-08.
# Normalized cost function value=30.163276649457238, variation=4.687617050080917e-08.
# Normalized cost function value=30.163276603303114, variation=4.615412407815711e-08.
# Normalized cost function value=30.163276557860055, variation=4.5443059093486227e-08.
# Normalized cost function value=30.163276513116948, variation=4.474310699720263e-08.
# Normalized cost function value=30.16327646906309, variation=4.405385922723326e-08.
# Normalized cost function value=30.163276425687958, variation=4.337513104246682e-08.
# Normalized cost function value=30.163276382980964, variation=4.270699349717688e-08.
# Normalized cost function value=30.163276340931933, variation=4.204903092386303e-08.
# Normalized cost function value=30.163276299530708, variation=4.140122555895687e-08.
# Normalized cost function value=30.163276258767315, variation=4.07633926613471e-08.
# Normalized cost function value=30.163276218631918, variation=4.013539722791393e-08.
# Normalized cost function value=30.16327617911488, variation=3.9517036753977663e-08.
# Normalized cost function value=30.16327614020671, variation=3.8908169130991155e-08.
# Normalized cost function value=30.16327610189803, variation=3.830868067211668e-08.
# Normalized cost function value=30.16327606417951, variation=3.7718521639362734e-08.
# Normalized cost function value=30.1632760270422, variation=3.713730833965201e-08.
# Normalized cost function value=30.163275990477075, variation=3.6565126038112794e-08.
# Normalized cost function value=30.163275954475367, variation=3.600170828121918e-08.
# Normalized cost function value=30.16327591902845, variation=3.5446916513137694e-08.
# Normalized cost function value=30.16327588412764, variation=3.4900811130000875e-08.
# Normalized cost function value=30.16327584976469, variation=3.436294804259887e-08.
# Normalized cost function value=30.163275815931165, variation=3.38335262028977e-08.
# Normalized cost function value=30.163275782619063, variation=3.331210152168751e-08.
# Normalized cost function value=30.163275749820286, variation=3.279877702766498e-08.
# Normalized cost function value=30.16327571752687, variation=3.2293417717710327e-08.
# Normalized cost function value=30.163275685731236, variation=3.179563279331887e-08.
# Normalized cost function value=30.16327565442548, variation=3.130575620957643e-08.
# Normalized cost function value=30.16327562360217, variation=3.082330835013636e-08.
# Normalized cost function value=30.163275593253974, variation=3.034819684444301e-08.
# Normalized cost function value=30.163275563373382, variation=2.9880592222752966e-08.
# Normalized cost function value=30.163275533953307, variation=2.942007526485213e-08.
# Normalized cost function value=30.163275504986686, variation=2.896662110174475e-08.
# Normalized cost function value=30.163275476466428, variation=2.8520258155140255e-08.
# Normalized cost function value=30.163275448385793, variation=2.8080634706384444e-08.
# Normalized cost function value=30.163275420737918, variation=2.7647875100456076e-08.
# Normalized cost function value=30.16327539351616, variation=2.7221759069107065e-08.
# Normalized cost function value=30.163275366713997, variation=2.6802162267358653e-08.
# Normalized cost function value=30.163275340324866, variation=2.6389130880488665e-08.
# Normalized cost function value=30.16327531434256, variation=2.598230608441554e-08.
# Normalized cost function value=30.163275288760648, variation=2.5581911700101045e-08.
# Normalized cost function value=30.163275263573105, variation=2.5187542718185796e-08.
# Normalized cost function value=30.16327523877379, variation=2.4799316378221192e-08.
# Normalized cost function value=30.163275214356734, variation=2.4417055044523295e-08.
# Normalized cost function value=30.16327519031598, variation=2.4040755164378425e-08.
# Normalized cost function value=30.16327516664587, variation=2.3670107651696526e-08.
# Normalized cost function value=30.163275143340595, variation=2.3305275931306824e-08.
# Normalized cost function value=30.16327512039466, variation=2.2945936706264547e-08.
# Normalized cost function value=30.163275097802273, variation=2.2592384851805036e-08.
# Normalized cost function value=30.163275075558285, variation=2.2243987984893465e-08.
# Normalized cost function value=30.163275053657102, variation=2.1901183089312326e-08.
# Normalized cost function value=30.163275032093658, variation=2.1563444363437156e-08.
# Normalized cost function value=30.163275010862595, variation=2.1231063129789618e-08.
# Normalized cost function value=30.163274989958754, variation=2.0903840436403698e-08.
# Normalized cost function value=30.16327496937721, variation=2.0581545356890274e-08.
# Normalized cost function value=30.163274949112957, variation=2.02642524982366e-08.
# Normalized cost function value=30.163274929161133, variation=1.9951823304609206e-08.
# Normalized cost function value=30.16327490951692, variation=1.9644211590730265e-08.
# Normalized cost function value=30.16327489017549, variation=1.9341431567454492e-08.
# Normalized cost function value=30.163274871132383, variation=1.9043106647131935e-08.
# Normalized cost function value=30.16327485238276, variation=1.8749624075553584e-08.
# Normalized cost function value=30.163274833922216, variation=1.8460543316223266e-08.
# Normalized cost function value=30.163274815746252, variation=1.8175963845123988e-08.
# Normalized cost function value=30.16327479785063, variation=1.789562276144352e-08.
# Normalized cost function value=30.16327478023086, variation=1.7619768755139376e-08.
# Normalized cost function value=30.163274762882764, variation=1.734809629283518e-08.
# Normalized cost function value=30.16327474580215, variation=1.708061603267197e-08.
# Normalized cost function value=30.163274728984884, variation=1.6817264025803524e-08.
# Normalized cost function value=30.163274712426958, variation=1.6557926585392124e-08.
# Normalized cost function value=30.163274696124272, variation=1.630268542385238e-08.
# Normalized cost function value=30.163274680073044, variation=1.605122790238056e-08.
# Normalized cost function value=30.163274664269267, variation=1.5803777841938427e-08.
# Normalized cost function value=30.163274648709148, variation=1.5560118526991573e-08.
# Normalized cost function value=30.163274633389022, variation=1.5320125612561242e-08.
# Normalized cost function value=30.163274618305064, variation=1.508395897076298e-08.
# Normalized cost function value=30.163274603453775, variation=1.4851288199224655e-08.
# Normalized cost function value=30.16327458883143, variation=1.4622344224335393e-08.
# Normalized cost function value=30.16327457443459, variation=1.4396842829000889e-08.
# Normalized cost function value=30.163274560259698, variation=1.4174890594631506e-08.
# Normalized cost function value=30.163274546303494, variation=1.3956203304132941e-08.
# Normalized cost function value=30.163274532562408, variation=1.3741086490881571e-08.
# Normalized cost function value=30.163274519033354, variation=1.35290534331034e-08.
# Normalized cost function value=30.163274505712813, variation=1.332054111458092e-08.
# Normalized cost function value=30.16327449259775, variation=1.3115062813540135e-08.
# Normalized cost function value=30.163274479684873, variation=1.2912877878079598e-08.
# Normalized cost function value=30.16327446697117, variation=1.2713702091105006e-08.
# Normalized cost function value=30.163274454453543, variation=1.2517627823172006e-08.
# Normalized cost function value=30.163274442128962, variation=1.2324580467293345e-08.
# Normalized cost function value=30.163274429994487, variation=1.213447475834073e-08.
# Normalized cost function value=30.16327441804706, variation=1.1947427935865562e-08.
# Normalized cost function value=30.16327440628393, variation=1.1763130913777786e-08.
# Normalized cost function value=30.163274394702274, variation=1.1581654746350978e-08.
# Normalized cost function value=30.16327438329914, variation=1.1403134436704931e-08.
# Normalized cost function value=30.163274372071946, variation=1.1227193397189694e-08.
# Normalized cost function value=30.163274361017834, variation=1.1054112292185891e-08.
# Normalized cost function value=30.16327435013431, variation=1.0883525192184607e-08.
# Normalized cost function value=30.163274339418567, variation=1.0715741183275895e-08.
# Normalized cost function value=30.163274328868088, variation=1.0550479601079132e-08.
# Normalized cost function value=30.163274318480376, variation=1.0387712023884887e-08.
# Normalized cost function value=30.16327430825287, variation=1.0227505953253058e-08.
# Normalized cost function value=30.163274298183094, variation=1.0069776124055352e-08.
# Normalized cost function value=30.16327428826863, variation=9.91446214015923e-09.
# Converged in 988 iterations.

# %%
errors[-1], len(errors)
# Out:
# (30.16327428826863, 989)

# %% [markdown]
# ## NTF (PARAFAC): Nonnegative PARAFAC Decomposition

# %% [markdown]
# ======================================
# Nonnegative Tensor Factorization (NTF)
# ======================================
#
# Factorization of a tensor T in nonnegative matrices, corresponding to the PARAFAC decomposition of this tensor
#
# Precisely, each matrix corresponds the concatenation of all column vectors coming from PARAFAC decomposition on a tensor mode
#
# Hence, this results in as much factors as tensor modes
#
# All of this matrices are of size I_n*rank, with I_n the size of the n-th tensor mode
#
# The factorization problem is solved by fixing alternatively all factors except one, and resolving the problem on this one. Factorwise, the problem is reduced to a Nonnegative Least Squares problem.
#
# The optimization problem, for M_n, the n-th factor, is:
#
# min_{M_n} d(T - M_n (khatri-rao(M_l))^T)_{\beta} + 2 * sparsity_coefficients[n] * (\sum\limits_{j = 0}^{r}||V[k,:]||_1)
#
# With:
#    * l the index of all the modes except the n-th one
#    * d(A)_{\beta} the elementwise beta-divergence,
#    *  ||a||_1 = \sum_{i} abs(a_{i}) (Elementwise L1 norm)
#
# More precisely, the chosen optimization algorithm is either the HALS [1], which updates each factor columnwise, fixing every other columns, and optimizes factors according to the euclidean norm, or the MU [5,6], which optimizes the factors according to the $\beta$-divergence loss.
#
# Parameters
# ----------
# `tensor`: nonnegative tensor
# * The tensor T, which is factorized
# `rank`: integer
# * The rank of the decomposition
# `init`: "random" | "nndsvd" | "custom" |
# * If set to random:
#     * Initialize with random factors of the correct size.
#     * The randomization is the uniform distribution in [0,1), which is the default from numpy random.
# * If set to nnsvd:
#     * Corresponds to a Nonnegative Double Singular Value Decomposition (NNDSVD) initialization, which is a data based initialization, designed for NMF resolution. See [2] for details. This nndsvd if performed via the nimfa toolbox [3].
# * If set to custom:
#     * factors_0 (see below) will be used for the initialization
#     * Default: random
#
#
# * `factors_0`: None or list of array of nonnegative floats
#     * A custom initialization of the factors, used only in "custom" init mode.
#     * Default: None
# * `n_iter_max`: integer
#     * The maximal number of iteration before stopping the algorithm
#     * Default: 100
# * `tol`: float
#     * Threshold on the improvement in cost function value.
#     * Between two succesive iterations, if the difference between both cost function values is below this threshold, the algorithm stops.
#     * Default: 1e-8
# * `update_rule`: string "hals" | "mu"
#     * The chosen update rule.
#         * HALS performs optimization with the euclidean norm,
#         * MU performs the optimization using the $\beta$-divergence loss, which generalizes the Euclidean norm, and the Kullback-Leibler and Itakura-Saito divergences.
#     * The chosen beta-divergence is specified with the parameter `beta`.
#
# * `beta`: float
#     * The beta parameter for the beta-divergence.
#     * Only useful if update_rule is set to "mu".
#         * 2 - Euclidean norm
#         * 1 - Kullback-Leibler divergence
#         * 0 - Itakura-Saito divergence
#
# * `sparsity_coefficients`: array of float (as much as the number of modes)
#     * The sparsity coefficients on U and V respectively.
#     * If set to None, the algorithm is computed without sparsity
#     * Default: [],
#
# * `fixed_modes`: array of integers (between 0 and the number of modes)
#     * Has to be set not to update a factor, 0 and 1 for U and V respectively
#     * Default: []
#
# * `normalize`: array of boolean (as much as the number of modes)
#     * A boolean whereas the factors need to be normalized.
#     * The normalization is a l_2 normalization on each of the rank components (columnwise for U, linewise for V)
#     * Default: []
#
# * `verbose`: boolean
#     * Indicates whether the algorithm prints the successive normalized cost function values or not
#     * Default: False
#
# * `return_costs`: boolean
#     * Indicates whether the algorithm should return all normalized cost function values and computation time of each iteration or not
#     * Default: False
#
# Returns
# -------
# * np.array(factors): numpy array
#     * An array containing all the factors computed with PARAFAC decomposition
#
# * cost_fct_vals: list
#     * A list of the normalized cost function values, for every iteration of the algorithm.
#
# * toc: list
#     * A list with accumulated time at each iterations

# %%
rank = 2
U_lines = 500
V_lines = 250
W_lines = 50

T = tl.random.random_cp((U_lines, V_lines, W_lines), rank, full=True)
T = tl.abs(T)
T = T + 1e-2 * np.random.rand(U_lines, V_lines, W_lines)

factors, errors, toc = ntf.ntf(T, rank, init = "random", n_iter_max = 1000, tol = 1e-8, update_rule = "hals",
           sparsity_coefficients = [None, None, None], fixed_modes = [], normalize = [False, False, False],
           verbose = True, return_costs = True)
# Out:
# Normalized cost function value=0.0674647169179721
# Normalized cost function value=0.045758935705470676, variation=0.02170578121250142.
# Normalized cost function value=0.011600878576329026, variation=0.03415805712914165.
# Normalized cost function value=0.004241137924237255, variation=0.007359740652091771.
# Normalized cost function value=0.0012889655898227297, variation=0.0029521723344145255.
# Normalized cost function value=0.00038773888620125826, variation=0.0009012267036214714.
# Normalized cost function value=0.0002324465179333007, variation=0.00015529236826795757.
# Normalized cost function value=0.00019418838422411528, variation=3.8258133709185405e-05.
# Normalized cost function value=0.0001726799004333517, variation=2.150848379076358e-05.
# Normalized cost function value=0.00015687706450228669, variation=1.580283593106502e-05.
# Normalized cost function value=0.0001447436842743454, variation=1.2133380227941282e-05.
# Normalized cost function value=0.0001353245435449222, variation=9.41914072942319e-06.
# Normalized cost function value=0.00012792615195198563, variation=7.398391592936584e-06.
# Normalized cost function value=0.00012207646177759017, variation=5.849690174395463e-06.
# Normalized cost function value=0.00011743313624293588, variation=4.6433255346542895e-06.
# Normalized cost function value=0.00011374846950845799, variation=3.6846667344778904e-06.
# Normalized cost function value=0.00011081073321951867, variation=2.9377362889393123e-06.
# Normalized cost function value=0.00010845521534447263, variation=2.3555178750460425e-06.
# Normalized cost function value=0.00010656777216668468, variation=1.887443177787956e-06.
# Normalized cost function value=0.0001050655185410648, variation=1.5022536256198822e-06.
# Normalized cost function value=0.00010385885507731232, variation=1.2066634637524718e-06.
# Normalized cost function value=0.00010287009634309635, variation=9.887587342159699e-07.
# Normalized cost function value=0.00010205601032834808, variation=8.140860147482713e-07.
# Normalized cost function value=0.00010138084287636513, variation=6.751674519829467e-07.
# Normalized cost function value=0.00010082108480907245, variation=5.597580672926877e-07.
# Normalized cost function value=0.00010035705547804872, variation=4.640293310237219e-07.
# Normalized cost function value=9.997242964447367e-05, variation=3.8462583357505543e-07.
# Normalized cost function value=9.965365296164675e-05, variation=3.187766828269186e-07.
# Normalized cost function value=9.938947689330754e-05, variation=2.641760683392121e-07.
# Normalized cost function value=9.917056836800567e-05, variation=2.1890852530186903e-07.
# Normalized cost function value=9.898918507311811e-05, variation=1.813832948875595e-07.
# Normalized cost function value=9.883890542532371e-05, variation=1.5027964779439963e-07.
# Normalized cost function value=9.871440410296239e-05, variation=1.2450132236132368e-07.
# Normalized cost function value=9.861126552190008e-05, variation=1.0313858106231113e-07.
# Normalized cost function value=9.852582891789058e-05, variation=8.543660400949383e-08.
# Normalized cost function value=9.845505967582478e-05, variation=7.076924206580201e-08.
# Normalized cost function value=9.839644251570798e-05, variation=5.8617160116799225e-08.
# Normalized cost function value=9.834789283907679e-05, variation=4.854967663119438e-08.
# Normalized cost function value=9.830768312801224e-05, variation=4.020971106454669e-08.
# Normalized cost function value=9.827438191123236e-05, variation=3.330121677987629e-08.
# Normalized cost function value=9.824680313199466e-05, variation=2.7578779237703442e-08.
# Normalized cost function value=9.822396412937932e-05, variation=2.2839002615342163e-08.
# Normalized cost function value=9.820505082761027e-05, variation=1.8913301769049812e-08.
# Normalized cost function value=9.818938883879473e-05, variation=1.5661988815536326e-08.
# Normalized cost function value=9.81764195374544e-05, variation=1.2969301340336192e-08.
# Normalized cost function value=9.816568019891119e-05, variation=1.0739338543208935e-08.
# Normalized cost function value=9.815678757295607e-05, variation=8.892625955115902e-09.
# Converged in 46 iterations.
# C:\Users\bviei\anaconda3\envs\msc-thesis\lib\site-packages\nn_fac\ntf.py:361: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.array(factors), cost_fct_vals, toc

# %%
errors[-1], len(errors)
# Out:
# (9.815678757295607e-05, 47)

# %% [markdown]
# ## MU
# ### Beta = 2

# %%
rank = 2
U_lines = 500
V_lines = 250
W_lines = 50

T = tl.random.random_cp((U_lines, V_lines, W_lines), rank, full=True)
T = tl.abs(T)
T = T + 1e-2 * np.random.rand(U_lines, V_lines, W_lines)

factors, errors, toc = ntf.ntf(T, rank, init = "random", n_iter_max = 1000, tol = 1e-8, update_rule = "mu",beta = 2,
           sparsity_coefficients = [None, None, None], fixed_modes = [], normalize = [False, False, False],
           verbose = True, return_costs = True)
# Out:
# Normalized cost function value=0.058894143770483104
# Normalized cost function value=0.04911629440347402, variation=0.009777849367009081.
# Normalized cost function value=0.04393790698157085, variation=0.005178387421903172.
# Normalized cost function value=0.04097277791855683, variation=0.0029651290630140215.
# Normalized cost function value=0.039130572256584305, variation=0.001842205661972525.
# Normalized cost function value=0.03788727174401904, variation=0.0012433005125652638.
# Normalized cost function value=0.03696050957203528, variation=0.0009267621719837582.
# Normalized cost function value=0.036171554440720816, variation=0.0007889551313144672.
# Normalized cost function value=0.03537786195157734, variation=0.0007936924891434743.
# Normalized cost function value=0.034432417398963765, variation=0.0009454445526135766.
# Normalized cost function value=0.03315473435140071, variation=0.0012776830475630524.
# Normalized cost function value=0.03131560269807044, variation=0.0018391316533302726.
# Normalized cost function value=0.028657742295021, variation=0.002657860403049439.
# Normalized cost function value=0.024994076685188927, variation=0.0036636656098320737.
# Normalized cost function value=0.02039958681938329, variation=0.004594489865805636.
# Normalized cost function value=0.01536982164114237, variation=0.0050297651782409206.
# Normalized cost function value=0.010678285921228948, variation=0.004691535719913422.
# Normalized cost function value=0.006932314171017714, variation=0.003745971750211234.
# Normalized cost function value=0.004291852378258518, variation=0.002640461792759196.
# Normalized cost function value=0.0025854677382361802, variation=0.0017063846400223377.
# Normalized cost function value=0.0015452799900483847, variation=0.0010401877481877955.
# Normalized cost function value=0.0009354183200225858, variation=0.0006098616700257989.
# Normalized cost function value=0.000585288700719198, variation=0.0003501296193033878.
# Normalized cost function value=0.0003848010898284652, variation=0.00020048761089073286.
# Normalized cost function value=0.0002684121291412138, variation=0.00011638896068725136.
# Normalized cost function value=0.00019905613141499914, variation=6.935599772621469e-05.
# Normalized cost function value=0.00015629149030332257, variation=4.2764641111676564e-05.
# Normalized cost function value=0.00012889786031251662, variation=2.7393629990805956e-05.
# Normalized cost function value=0.00011065626418122199, variation=1.8241596131294627e-05.
# Normalized cost function value=9.805118061095447e-05, variation=1.260508357026752e-05.
# Normalized cost function value=8.904199422626965e-05, variation=9.009186384684821e-06.
# Normalized cost function value=8.240725522445973e-05, variation=6.634739001809919e-06.
# Normalized cost function value=7.73914903977119e-05, variation=5.015764826747825e-06.
# Normalized cost function value=7.351181774763901e-05, variation=3.879672650072897e-06.
# Normalized cost function value=7.044972811967979e-05, variation=3.0620896279592212e-06.
# Normalized cost function value=6.798895445344704e-05, variation=2.4607736662327496e-06.
# Normalized cost function value=6.597878414934071e-05, variation=2.0101703041063235e-06.
# Normalized cost function value=6.431175225808245e-05, variation=1.6670318912582663e-06.
# Normalized cost function value=6.290967781492778e-05, variation=1.4020744431546685e-06.
# Normalized cost function value=6.171467578936666e-05, variation=1.19500202556112e-06.
# Normalized cost function value=6.0683220396814685e-05, variation=1.0314553925519734e-06.
# Normalized cost function value=5.9782131421515216e-05, variation=9.010889752994694e-07.
# Normalized cost function value=5.898580407925249e-05, variation=7.963273422627223e-07.
# Normalized cost function value=5.827426232206301e-05, variation=7.115417571894843e-07.
# Normalized cost function value=5.763176918490814e-05, variation=6.424931371548683e-07.
# Normalized cost function value=5.704582118474899e-05, variation=5.859480001591493e-07.
# Normalized cost function value=5.650641196412674e-05, variation=5.394092206222485e-07.
# Normalized cost function value=5.600548745763123e-05, variation=5.009245064955137e-07.
# Normalized cost function value=5.553653900577543e-05, variation=4.6894845185580013e-07.
# Normalized cost function value=5.5094296864832045e-05, variation=4.422421409433844e-07.
# Normalized cost function value=5.467449737814922e-05, variation=4.1979948668282696e-07.
# Normalized cost function value=5.427370448980404e-05, variation=4.0079288834517956e-07.
# Normalized cost function value=5.3889171439068744e-05, variation=3.845330507352946e-07.
# Normalized cost function value=5.3518732114523666e-05, variation=3.7043932454507736e-07.
# Normalized cost function value=5.31607141587291e-05, variation=3.58017955794565e-07.
# Normalized cost function value=5.281386782660336e-05, variation=3.4684633212573923e-07.
# Normalized cost function value=5.247730603656732e-05, variation=3.365617900360387e-07.
# Normalized cost function value=5.215045216580894e-05, variation=3.268538707583841e-07.
# Normalized cost function value=5.183299303327007e-05, variation=3.1745913253887e-07.
# Normalized cost function value=5.152483525407374e-05, variation=3.081577791963288e-07.
# Normalized cost function value=5.122606377877622e-05, variation=2.987714752975207e-07.
# Normalized cost function value=5.093690197182105e-05, variation=2.8916180695516715e-07.
# Normalized cost function value=5.065767304327577e-05, variation=2.792289285452848e-07.
# Normalized cost function value=5.0388763024051175e-05, variation=2.689100192245926e-07.
# Normalized cost function value=5.013058575998054e-05, variation=2.5817726407063326e-07.
# Normalized cost function value=4.9883550586357874e-05, variation=2.470351736226674e-07.
# Normalized cost function value=4.964803342701698e-05, variation=2.3551715934089158e-07.
# Normalized cost function value=4.942435204218079e-05, variation=2.2368138483618954e-07.
# Normalized cost function value=4.92127460364828e-05, variation=2.1160600569799018e-07.
# Normalized cost function value=4.9013362050136446e-05, variation=1.9938398634635715e-07.
# Normalized cost function value=4.882624431631203e-05, variation=1.871177338244156e-07.
# Normalized cost function value=4.8651330504441474e-05, variation=1.7491381187055593e-07.
# Normalized cost function value=4.8488452511187064e-05, variation=1.6287799325441043e-07.
# Normalized cost function value=4.833734163402674e-05, variation=1.5111087716032352e-07.
# Normalized cost function value=4.819763738694464e-05, variation=1.397042470820982e-07.
# Normalized cost function value=4.806889910595656e-05, variation=1.2873828098808435e-07.
# Normalized cost function value=4.795061944820121e-05, variation=1.1827965775534883e-07.
# Normalized cost function value=4.784223890839275e-05, variation=1.0838053980845856e-07.
# Normalized cost function value=4.774316055073048e-05, variation=9.907835766227111e-08.
# Normalized cost function value=4.7652764269036834e-05, variation=9.039628169364499e-08.
# Normalized cost function value=4.757042002742938e-05, variation=8.234424160745213e-08.
# Normalized cost function value=4.749549968312093e-05, variation=7.492034430845384e-08.
# Normalized cost function value=4.742738713885365e-05, variation=6.811254426728126e-08.
# Normalized cost function value=4.736548670490273e-05, variation=6.190043395091685e-08.
# Normalized cost function value=4.7309229662792646e-05, variation=5.625704211008423e-08.
# Normalized cost function value=4.7258079111376034e-05, variation=5.1150551416612644e-08.
# Normalized cost function value=4.7211533240081837e-05, variation=4.654587129419694e-08.
# Normalized cost function value=4.7169127215403287e-05, variation=4.24060246785501e-08.
# Normalized cost function value=4.713043388801169e-05, variation=3.869332739159454e-08.
# Normalized cost function value=4.709506353289022e-05, variation=3.537035512147114e-08.
# Normalized cost function value=4.7062662827536094e-05, variation=3.2400705354126915e-08.
# Normalized cost function value=4.70329132572832e-05, variation=2.9749570252895173e-08.
# Normalized cost function value=4.700552911544971e-05, variation=2.73841418334871e-08.
# Normalized cost function value=4.698025524203588e-05, variation=2.5273873413829786e-08.
# Normalized cost function value=4.6956864620177343e-05, variation=2.3390621858538436e-08.
# Normalized cost function value=4.693515592601841e-05, variation=2.170869415893189e-08.
# Normalized cost function value=4.691495110609592e-05, variation=2.0204819922493465e-08.
# Normalized cost function value=4.689609303729362e-05, variation=1.8858068802296774e-08.
# Normalized cost function value=4.687844330818617e-05, variation=1.7649729107453672e-08.
# Normalized cost function value=4.6861880147123285e-05, variation=1.6563161062882524e-08.
# Normalized cost function value=4.6846296511587986e-05, variation=1.5583635535298924e-08.
# Normalized cost function value=4.6831598344893434e-05, variation=1.4698166694552151e-08.
# Normalized cost function value=4.6817702999900625e-05, variation=1.3895344992809048e-08.
# Normalized cost function value=4.680453782478641e-05, variation=1.3165175114215324e-08.
# Normalized cost function value=4.679203890269031e-05, variation=1.249892209610054e-08.
# Normalized cost function value=4.6780149934998556e-05, variation=1.1888967691753326e-08.
# Normalized cost function value=4.67688212568735e-05, variation=1.1328678125057908e-08.
# Normalized cost function value=4.675800897314828e-05, variation=1.0812283725214944e-08.
# Normalized cost function value=4.6747674202730995e-05, variation=1.0334770417287664e-08.
# Normalized cost function value=4.673778242004191e-05, variation=9.89178268908221e-09.
# Converged in 109 iterations.

# %%
errors[-1], len(errors)
# Out:
# (4.673778242004191e-05, 110)

# %% [markdown]
# ### Beta = 1

# %%
rank = 2
U_lines = 500
V_lines = 250
W_lines = 50

T = tl.random.random_cp((U_lines, V_lines, W_lines), rank, full=True)
T = tl.abs(T)
T = T + 1e-2 * np.random.rand(U_lines, V_lines, W_lines)

factors, errors, toc = ntf.ntf(T, rank, init = "random", n_iter_max = 1000, tol = 1e-8, update_rule = "mu",beta = 1,
           sparsity_coefficients = [None, None, None], fixed_modes = [], normalize = [False, False, False],
           verbose = True, return_costs = True)
# Out:
# Normalized cost function value=0.18348920398067517
# Normalized cost function value=0.14670128811147579, variation=0.036787915869199384.
# Normalized cost function value=0.1310437351979512, variation=0.01565755291352458.
# Normalized cost function value=0.12308169919814402, variation=0.007962035999807188.
# Normalized cost function value=0.11852603097222336, variation=0.004555668225920656.
# Normalized cost function value=0.11565636554075087, variation=0.00286966543147249.
# Normalized cost function value=0.11366669356477892, variation=0.0019896719759719544.
# Normalized cost function value=0.1121093110992372, variation=0.0015573824655417123.
# Normalized cost function value=0.11066681151610018, variation=0.0014424995831370246.
# Normalized cost function value=0.1090284759989548, variation=0.0016383355171453867.
# Normalized cost function value=0.10679290974126321, variation=0.0022355662576915847.
# Normalized cost function value=0.10337165857067937, variation=0.003421251170583839.
# Normalized cost function value=0.09791901168522515, variation=0.005452646885454215.
# Normalized cost function value=0.08940973797776344, variation=0.008509273707461712.
# Normalized cost function value=0.07709897855353158, variation=0.012310759424231862.
# Normalized cost function value=0.06142336872434013, variation=0.01567560982919145.
# Normalized cost function value=0.044575264265577404, variation=0.016848104458762725.
# Normalized cost function value=0.02956213403802179, variation=0.015013130227555613.
# Normalized cost function value=0.018328002316155972, variation=0.011234131721865818.
# Normalized cost function value=0.011004514542616809, variation=0.007323487773539163.
# Normalized cost function value=0.0066471290545874065, variation=0.0043573854880294026.
# Normalized cost function value=0.004173253023353476, variation=0.0024738760312339302.
# Normalized cost function value=0.002783457818918385, variation=0.0013897952044350913.
# Normalized cost function value=0.001990238540328935, variation=0.0007932192785894501.
# Normalized cost function value=0.0015225448088443468, variation=0.0004676937314845881.
# Normalized cost function value=0.001235232364190271, variation=0.0002873124446540758.
# Normalized cost function value=0.0010508839109088445, variation=0.00018434845328142648.
# Normalized cost function value=0.0009275068522808211, variation=0.00012337705862802337.
# Normalized cost function value=0.000841661416886462, variation=8.58454353943591e-05.
# Normalized cost function value=0.0007798082142281334, variation=6.185320265832865e-05.
# Normalized cost function value=0.0007338431284700618, variation=4.596508575807157e-05.
# Normalized cost function value=0.0006987451108744561, variation=3.5098017595605754e-05.
# Normalized cost function value=0.0006713014370696844, variation=2.7443673804771677e-05.
# Normalized cost function value=0.0006493947324732531, variation=2.1906704596431252e-05.
# Normalized cost function value=0.0006315912850826271, variation=1.7803447390626003e-05.
# Normalized cost function value=0.0006168959659526868, variation=1.4695319129940363e-05.
# Normalized cost function value=0.0006046021400810613, variation=1.2293825871625454e-05.
# Normalized cost function value=0.0005941973366188052, variation=1.0404803462256136e-05.
# Normalized cost function value=0.0005853025475757919, variation=8.894789043013287e-06.
# Normalized cost function value=0.0005776323170242114, variation=7.670230551580525e-06.
# Normalized cost function value=0.0005709679774806233, variation=6.6643395435881e-06.
# Normalized cost function value=0.0005651393728863788, variation=5.8286045942445e-06.
# Normalized cost function value=0.0005600121636253127, variation=5.12720926106611e-06.
# Normalized cost function value=0.0005554788669708703, variation=4.533296654442363e-06.
# Normalized cost function value=0.0005514524374032744, variation=4.0264295675958685e-06.
# Normalized cost function value=0.000547861599747111, variation=3.590837656163438e-06.
# Normalized cost function value=0.000544647409011625, variation=3.214190735485972e-06.
# Normalized cost function value=0.0005417606802264344, variation=2.8867287851906285e-06.
# Normalized cost function value=0.0005391600432142259, variation=2.6006370122084533e-06.
# Normalized cost function value=0.0005368104518457918, variation=2.3495913684341624e-06.
# Normalized cost function value=0.0005346820278105156, variation=2.1284240352761885e-06.
# Normalized cost function value=0.0005327491535115474, variation=1.932874298968138e-06.
# Normalized cost function value=0.0005309897526378011, variation=1.759400873746356e-06.
# Normalized cost function value=0.0005293847137201134, variation=1.6050389176876581e-06.
# Normalized cost function value=0.0005279174238229313, variation=1.4672898971821108e-06.
# Normalized cost function value=0.000526573387976774, variation=1.3440358461573338e-06.
# Normalized cost function value=0.0005253399160483504, variation=1.2334719284235384e-06.
# Normalized cost function value=0.0005242058631757729, variation=1.1340528725775926e-06.
# Normalized cost function value=0.0005231614131485634, variation=1.0444500272094662e-06.
# Normalized cost function value=0.0005221978965214321, variation=9.6351662713125e-07.
# Normalized cost function value=0.0005213076370522452, variation=8.902594691869402e-07.
# Normalized cost function value=0.0005204838214133681, variation=8.238156388771329e-07.
# Normalized cost function value=0.0005197203881605135, variation=7.634332528545784e-07.
# Normalized cost function value=0.0005190119327379762, variation=7.08455422537336e-07.
# Normalized cost function value=0.0005183536259156446, variation=6.583068223315995e-07.
# Normalized cost function value=0.0005177411435348452, variation=6.12482380799354e-07.
# Normalized cost function value=0.0005171706058205578, variation=5.705377142873518e-07.
# Normalized cost function value=0.0005166385248199113, variation=5.320810006465395e-07.
# Normalized cost function value=0.0005161417587694514, variation=4.967660504599401e-07.
# Normalized cost function value=0.0005156774723899527, variation=4.642863794987158e-07.
# Normalized cost function value=0.0005152431022671143, variation=4.343701228383054e-07.
# Normalized cost function value=0.0005148363266076372, variation=4.067756594771819e-07.
# Normalized cost function value=0.0005144550387682919, variation=3.8128783934527656e-07.
# Normalized cost function value=0.0005140973240453918, variation=3.57714722900096e-07.
# Normalized cost function value=0.000513761439287221, variation=3.3588475817076906e-07.
# Normalized cost function value=0.0005134457949549353, variation=3.1564433228574093e-07.
# Normalized cost function value=0.0005131489393106104, variation=2.968556443249228e-07.
# Normalized cost function value=0.0005128695444560922, variation=2.793948545181703e-07.
# Normalized cost function value=0.0005126063939846692, variation=2.631504714229946e-07.
# Normalized cost function value=0.000512358372040085, variation=2.4802194458417234e-07.
# Normalized cost function value=0.0005121244536054293, variation=2.3391843465567566e-07.
# Normalized cost function value=0.0005119036958682363, variation=2.2075773719308113e-07.
# Normalized cost function value=0.0005116952305287735, variation=2.0846533946273192e-07.
# Normalized cost function value=0.0005114982569360903, variation=1.9697359268319465e-07.
# Normalized cost function value=0.0005113120359516717, variation=1.8622098441859088e-07.
# Normalized cost function value=0.0005111358844535812, variation=1.7615149809050053e-07.
# Normalized cost function value=0.0005109691704054258, variation=1.6671404815546756e-07.
# Normalized cost function value=0.0005108113084241763, variation=1.5786198124948577e-07.
# Normalized cost function value=0.0005106617557893781, variation=1.4955263479823552e-07.
# Normalized cost function value=0.00051052000884358, variation=1.4174694579801705e-07.
# Normalized cost function value=0.0005103855997402188, variation=1.344091033612634e-07.
# Normalized cost function value=0.0005102580935005614, variation=1.2750623965733857e-07.
# Normalized cost function value=0.0005101370853461928, variation=1.2100815436862696e-07.
# Normalized cost function value=0.0005100221982775473, variation=1.1488706864548701e-07.
# Normalized cost function value=0.0005099130808726362, variation=1.0911740491107835e-07.
# Normalized cost function value=0.0005098094052831536, variation=1.0367558948268154e-07.
# Normalized cost function value=0.0005097108654079095, variation=9.853987524403602e-08.
# Normalized cost function value=0.000509617175225802, variation=9.369018210748405e-08.
# Normalized cost function value=0.00050952806727264, variation=8.910795316202647e-08.
# Normalized cost function value=0.000509443291247862, variation=8.477602477798777e-08.
# Normalized cost function value=0.0005093626127387718, variation=8.06785090902342e-08.
# Normalized cost function value=0.0005092858120512189, variation=7.68006875529392e-08.
# Normalized cost function value=0.0005092126831369055, variation=7.312891431331733e-08.
# Normalized cost function value=0.0005091430326084634, variation=6.965052844209747e-08.
# Normalized cost function value=0.0005090766788344174, variation=6.635377404603723e-08.
# Normalized cost function value=0.0005090134511068887, variation=6.322772752869084e-08.
# Normalized cost function value=0.0005089531888756757, variation=6.026223121305841e-08.
# Normalized cost function value=0.0005088957410429113, variation=5.74478327643917e-08.
# Normalized cost function value=0.0005088409653130809, variation=5.477572983039747e-08.
# Normalized cost function value=0.0005087887275936874, variation=5.223771939349194e-08.
# Normalized cost function value=0.0005087389014422458, variation=4.982615144154094e-08.
# Normalized cost function value=0.0005086913675557517, variation=4.753388649413135e-08.
# Normalized cost function value=0.0005086460132990472, variation=4.535425670454136e-08.
# Normalized cost function value=0.0005086027322688807, variation=4.328103016650389e-08.
# Normalized cost function value=0.0005085614238907115, variation=4.130837816913261e-08.
# Normalized cost function value=0.0005085219930455716, variation=3.943084513991033e-08.
# Normalized cost function value=0.0005084843497245491, variation=3.764332102247029e-08.
# Normalized cost function value=0.0005084484087086339, variation=3.594101591526417e-08.
# Normalized cost function value=0.0005084140892718833, variation=3.4319436750590224e-08.
# Normalized cost function value=0.0005083813149060452, variation=3.2774365838123855e-08.
# Normalized cost function value=0.000508350013064899, variation=3.1301841146207446e-08.
# Normalized cost function value=0.0005083201149267517, variation=2.989813814721024e-08.
# Normalized cost function value=0.000508291555173659, variation=2.8559753092734057e-08.
# Normalized cost function value=0.0005082642717860329, variation=2.7283387626073942e-08.
# Normalized cost function value=0.0005082382058514321, variation=2.606593460085377e-08.
# Normalized cost function value=0.0005082133013864324, variation=2.4904464999693336e-08.
# Normalized cost function value=0.0005081895051705404, variation=2.3796215891974844e-08.
# Normalized cost function value=0.0005081667665912412, variation=2.2738579299194997e-08.
# Normalized cost function value=0.0005081450374993063, variation=2.172909193494301e-08.
# Normalized cost function value=0.0005081242720735782, variation=2.076542572810626e-08.
# Normalized cost function value=0.0005081044266945191, variation=1.9845379059047277e-08.
# Normalized cost function value=0.0005080854598258558, variation=1.8966868663324032e-08.
# Normalized cost function value=0.0005080673319037156, variation=1.812792214017818e-08.
# Normalized cost function value=0.0005080500052326934, variation=1.732667102220635e-08.
# Normalized cost function value=0.0005080334438883526, variation=1.65613443408371e-08.
# Normalized cost function value=0.0005080176136256645, variation=1.5830262688047193e-08.
# Normalized cost function value=0.000508002481792987, variation=1.513183267749796e-08.
# Normalized cost function value=0.0005079880172511519, variation=1.4464541835124134e-08.
# Normalized cost function value=0.0005079741902973367, variation=1.3826953815200202e-08.
# Normalized cost function value=0.0005079609725933485, variation=1.3217703988179647e-08.
# Normalized cost function value=0.0005079483370980307, variation=1.2635495317799353e-08.
# Normalized cost function value=0.00050793625800352, variation=1.2079094510752432e-08.
# Normalized cost function value=0.0005079247106750675, variation=1.1547328452481999e-08.
# Normalized cost function value=0.000507913671594205, variation=1.103908086252589e-08.
# Normalized cost function value=0.0005079031183050279, variation=1.055328917711016e-08.
# Normalized cost function value=0.0005078930293633863, variation=1.008894164153569e-08.
# Normalized cost function value=0.0005078833842888091, variation=9.645074577229774e-09.
# Converged in 146 iterations.

# %%
errors[-1], len(errors)
# Out:
# (0.0005078833842888091, 147)

# %% [markdown]
# ### Beta = 0

# %%
rank = 2
U_lines = 500
V_lines = 250
W_lines = 50

T = tl.random.random_cp((U_lines, V_lines, W_lines), rank, full=True)
T = tl.abs(T)
T = T + 1e-2 * np.random.rand(U_lines, V_lines, W_lines)

factors, errors, toc = ntf.ntf(T, rank, init = "random", n_iter_max = 1000, tol = 1e-8, update_rule = "mu",beta = 0,
           sparsity_coefficients = [None, None, None], fixed_modes = [], normalize = [False, False, False],
           verbose = True, return_costs = True)
# Out:
# Normalized cost function value=2.7130988473675828
# Normalized cost function value=1.2127958777532506, variation=1.5003029696143322.
# Normalized cost function value=0.8186929515777894, variation=0.39410292617546117.
# Normalized cost function value=0.6949488109074421, variation=0.12374414067034734.
# Normalized cost function value=0.6412202749671609, variation=0.05372853594028115.
# Normalized cost function value=0.6082149043133838, variation=0.03300537065377718.
# Normalized cost function value=0.5824591057934608, variation=0.025755798519922934.
# Normalized cost function value=0.5593104428406117, variation=0.02314866295284912.
# Normalized cost function value=0.5365117190170025, variation=0.022798723823609257.
# Normalized cost function value=0.5125903944445124, variation=0.023921324572490077.
# Normalized cost function value=0.48646367724080447, variation=0.026126717203707905.
# Normalized cost function value=0.4573835906982056, variation=0.02908008654259886.
# Normalized cost function value=0.4249952360302532, variation=0.032388354667952424.
# Normalized cost function value=0.3894167868454556, variation=0.03557844918479758.
# Normalized cost function value=0.3512723125970333, variation=0.03814447424842232.
# Normalized cost function value=0.31162823686060975, variation=0.039644075736423534.
# Normalized cost function value=0.2718318783705854, variation=0.03979635849002433.
# Normalized cost function value=0.2333048936780251, variation=0.03852698469256033.
# Normalized cost function value=0.19735579929988137, variation=0.035949094378143726.
# Normalized cost function value=0.16503506453090613, variation=0.032320734768975234.
# Normalized cost function value=0.13702769920154187, variation=0.028007365329364264.
# Normalized cost function value=0.11359897639294463, variation=0.023428722808597244.
# Normalized cost function value=0.09462080564438699, variation=0.018978170748557635.
# Normalized cost function value=0.07967183003219643, variation=0.014948975612190565.
# Normalized cost function value=0.06816815618926489, variation=0.011503673842931536.
# Normalized cost function value=0.05948044319671623, variation=0.008687712992548662.
# Normalized cost function value=0.05301475219254605, variation=0.006465691004170181.
# Normalized cost function value=0.04825558648449315, variation=0.004759165708052897.
# Normalized cost function value=0.04478028625075113, variation=0.0034753002337420194.
# Normalized cost function value=0.0422559594349371, variation=0.002524326815814028.
# Normalized cost function value=0.040427914317957704, variation=0.0018280451169793988.
# Normalized cost function value=0.03910538750229767, variation=0.001322526815660037.
# Normalized cost function value=0.03814772432847337, variation=0.0009576631738242997.
# Normalized cost function value=0.037452414919089, variation=0.0006953094093843648.
# Normalized cost function value=0.03694538310150741, variation=0.0005070318175815908.
# Normalized cost function value=0.036573423342493375, variation=0.0003719597590140372.
# Normalized cost function value=0.03629847528354825, variation=0.00027494805894512364.
# Normalized cost function value=0.03609337658466914, variation=0.00020509869887910814.
# Normalized cost function value=0.03593875918774082, variation=0.00015461739692832627.
# Normalized cost function value=0.03582080635554106, variation=0.00011795283219975805.
# Normalized cost function value=0.03572964516665151, variation=9.116118888954916e-05.
# Normalized cost function value=0.03565820136963258, variation=7.144379701892745e-05.
# Normalized cost function value=0.03560138700866963, variation=5.6814360962949284e-05.
# Normalized cost function value=0.03555552561545519, variation=4.586139321444138e-05.
# Normalized cost function value=0.03551794599861156, variation=3.757961684363459e-05.
# Normalized cost function value=0.03548669519345732, variation=3.125080515423845e-05.
# Normalized cost function value=0.03546033541346854, variation=2.635977998877853e-05.
# Normalized cost function value=0.035437800142479055, variation=2.2535270989484935e-05.
# Normalized cost function value=0.035418291858167784, variation=1.9508284311270385e-05.
# Normalized cost function value=0.03540120908602165, variation=1.708277214613335e-05.
# Normalized cost function value=0.035386094153146225, variation=1.5114932875426312e-05.
# Normalized cost function value=0.03537259558761801, variation=1.3498565528215212e-05.
# Normalized cost function value=0.03536044091321668, variation=1.2154674401326782e-05.
# Normalized cost function value=0.03534941685123227, variation=1.1024061984415967e-05.
# Normalized cost function value=0.0353393548234398, variation=1.0062027792467898e-05.
# Normalized cost function value=0.0353301202677756, variation=9.234555664199007e-06.
# Normalized cost function value=0.03532160471092959, variation=8.51555684600741e-06.
# Normalized cost function value=0.03531371984590045, variation=7.884865029145205e-06.
# Normalized cost function value=0.03530639307650747, variation=7.326769392974886e-06.
# Normalized cost function value=0.03529956414199844, variation=6.828934509033047e-06.
# Normalized cost function value=0.0352931825420735, variation=6.381599924942805e-06.
# Normalized cost function value=0.03528720555897869, variation=5.976983094804766e-06.
# Normalized cost function value=0.035281596727935204, variation=5.608831043488194e-06.
# Normalized cost function value=0.03527632464644624, variation=5.2720814889620216e-06.
# Normalized cost function value=0.03527136204141429, variation=4.9626050319523385e-06.
# Normalized cost function value=0.035266685033648465, variation=4.677007765824248e-06.
# Normalized cost function value=0.03526227255443797, variation=4.412479210492981e-06.
# Normalized cost function value=0.03525810587997885, variation=4.16667445912039e-06.
# Normalized cost function value=0.03525416825766407, variation=3.937622314778566e-06.
# Normalized cost function value=0.035250444604375264, variation=3.723653288809081e-06.
# Normalized cost function value=0.03524692126150889, variation=3.523342866372514e-06.
# Normalized cost function value=0.03524358579493096, variation=3.3354665779292136e-06.
# Normalized cost function value=0.03524042683068571, variation=3.1589642452492517e-06.
# Normalized cost function value=0.035237433919291, variation=2.992911394709974e-06.
# Normalized cost function value=0.03523459742299132, variation=2.836496299681024e-06.
# Normalized cost function value=0.035231908421530324, variation=2.6890014609981527e-06.
# Normalized cost function value=0.03522935863292684, variation=2.549788603485592e-06.
# Normalized cost function value=0.03522694034645856, variation=2.4182864682767424e-06.
# Normalized cost function value=0.035224646365619026, variation=2.293980839535026e-06.
# Normalized cost function value=0.035222469959260254, variation=2.176406358772587e-06.
# Normalized cost function value=0.035220404819480064, variation=2.0651397801899063e-06.
# Normalized cost function value=0.03521844502509481, variation=1.9597943852547872e-06.
# Normalized cost function value=0.03521658500975473, variation=1.8600153400757935e-06.
# Normalized cost function value=0.035214819533940546, variation=1.765475814187456e-06.
# Normalized cost function value=0.03521314366021792, variation=1.6758737226285625e-06.
# Normalized cost function value=0.03521155273124094, variation=1.5909289769744372e-06.
# Normalized cost function value=0.03521004235008785, variation=1.5103811530914335e-06.
# Normalized cost function value=0.03520860836258654, variation=1.4339875013119618e-06.
# Normalized cost function value=0.03520724684134421, variation=1.361521242332353e-06.
# Normalized cost function value=0.03520595407124973, variation=1.2927700944742604e-06.
# Normalized cost function value=0.035204726536250515, variation=1.2275349992180162e-06.
# Normalized cost function value=0.035203560907243074, variation=1.1656290074407716e-06.
# Normalized cost function value=0.03520245403094005, variation=1.1068763030239182e-06.
# Normalized cost function value=0.03520140291959799, variation=1.051111342062483e-06.
# Normalized cost function value=0.03520040474151123, variation=9.9817808675573e-07.
# Normalized cost function value=0.03519945681218638, variation=9.479293248543241e-07.
# Normalized cost function value=0.03519855658612972, variation=9.00226056657627e-07.
# Normalized cost function value=0.03519770164918567, variation=8.54936944051643e-07.
# Normalized cost function value=0.03519688971137457, variation=8.119378110960085e-07.
# Normalized cost function value=0.03519611860018584, variation=7.711111887354072e-07.
# Normalized cost function value=0.03519538625428526, variation=7.323459005753596e-07.
# Normalized cost function value=0.035194690717604116, variation=6.95536681145914e-07.
# Normalized cost function value=0.035194030133779315, variation=6.605838248005536e-07.
# Normalized cost function value=0.035193402740915855, variation=6.273928634600856e-07.
# Normalized cost function value=0.035192806866651535, variation=5.95874264319729e-07.
# Normalized cost function value=0.03519224092349872, variation=5.659431528137748e-07.
# Normalized cost function value=0.03519170340444639, variation=5.375190523307372e-07.
# Normalized cost function value=0.03519119287880482, variation=5.105256415741111e-07.
# Normalized cost function value=0.03519070798827636, variation=4.848905284585148e-07.
# Normalized cost function value=0.03519024744323882, variation=4.6054503753667486e-07.
# Normalized cost function value=0.035189810019227184, variation=4.374240116372663e-07.
# Normalized cost function value=0.03518939455360419, variation=4.154656229951592e-07.
# Normalized cost function value=0.0351889999424052, variation=3.946111989880374e-07.
# Normalized cost function value=0.03518862513734994, variation=3.7480505526293895e-07.
# Normalized cost function value=0.03518826914301003, variation=3.5599433990951557e-07.
# Normalized cost function value=0.03518793101412474, variation=3.3812888528689244e-07.
# Normalized cost function value=0.03518760985305496, variation=3.2116106978008485e-07.
# Normalized cost function value=0.03518730480736957, variation=3.050456853920247e-07.
# Normalized cost function value=0.03518701506755609, variation=2.897398134818485e-07.
# Normalized cost function value=0.03518673986484862, variation=2.752027074698349e-07.
# Normalized cost function value=0.03518647846916789, variation=2.6139568072569563e-07.
# Normalized cost function value=0.035186230187165705, variation=2.4828200218679486e-07.
# Normalized cost function value=0.035185994360370475, variation=2.3582679523070915e-07.
# Normalized cost function value=0.035185770363426024, variation=2.23996944451188e-07.
# Normalized cost function value=0.035185557602421334, variation=2.1276100468925474e-07.
# Normalized cost function value=0.03518535551330442, variation=2.020891169129957e-07.
# Normalized cost function value=0.03518516356037675, variation=1.919529276708798e-07.
# Normalized cost function value=0.035184981234864736, variation=1.8232551201452507e-07.
# Normalized cost function value=0.035184808053562826, variation=1.7318130191013026e-07.
# Normalized cost function value=0.03518464355754587, variation=1.6449601695361915e-07.
# Normalized cost function value=0.03518448731094659, variation=1.562465992838158e-07.
# Normalized cost function value=0.035184338899794464, variation=1.4841115212466116e-07.
# Normalized cost function value=0.03518419793091396, variation=1.4096888050624257e-07.
# Normalized cost function value=0.03518406403087807, variation=1.3390003588548138e-07.
# Normalized cost function value=0.03518393684501438, variation=1.2718586369503404e-07.
# Normalized cost function value=0.03518381603646208, variation=1.2080855229384957e-07.
# Normalized cost function value=0.03518370128527594, variation=1.1475118614351354e-07.
# Normalized cost function value=0.03518359228757565, variation=1.0899770028910405e-07.
# Normalized cost function value=0.03518348875473815, variation=1.0353283749764408e-07.
# Normalized cost function value=0.03518339041263058, variation=9.834210757536654e-08.
# Normalized cost function value=0.03518329700088173, variation=9.341174884991421e-08.
# Normalized cost function value=0.035183208272190514, variation=8.872869121379079e-08.
# Normalized cost function value=0.035183123991669105, variation=8.428052140907472e-08.
# Normalized cost function value=0.03518304393621929, variation=8.005544981787294e-08.
# Normalized cost function value=0.03518296789393964, variation=7.604227964669308e-08.
# Normalized cost function value=0.0351828956635635, variation=7.22303761385712e-08.
# Normalized cost function value=0.035182827053924476, variation=6.860963902566297e-08.
# Normalized cost function value=0.035182761883449036, variation=6.517047543980192e-08.
# Normalized cost function value=0.03518269997967469, variation=6.190377434267536e-08.
# Normalized cost function value=0.03518264117879263, variation=5.880088206622336e-08.
# Normalized cost function value=0.035182585325212866, variation=5.585357976123362e-08.
# Normalized cost function value=0.035182532271151506, variation=5.305406135941437e-08.
# Normalized cost function value=0.03518248187623917, variation=5.039491233344018e-08.
# Normalized cost function value=0.03518243400714791, variation=4.78690912603108e-08.
# Normalized cost function value=0.03518238853723877, variation=4.5469909143447396e-08.
# Normalized cost function value=0.035182345346225025, variation=4.319101374467005e-08.
# Normalized cost function value=0.035182304319853745, variation=4.102637127939568e-08.
# Normalized cost function value=0.03518226534960287, variation=3.897025087351569e-08.
# Normalized cost function value=0.035182228332393636, variation=3.701720923537932e-08.
# Normalized cost function value=0.03518219317031692, variation=3.5162076715555823e-08.
# Normalized cost function value=0.0351821597703745, variation=3.3399942422907e-08.
# Normalized cost function value=0.035182128044231924, variation=3.172614257418438e-08.
# Normalized cost function value=0.03518209790798495, variation=3.013624697706385e-08.
# Normalized cost function value=0.035182069281936845, variation=2.8626048101387802e-08.
# Normalized cost function value=0.03518204209038754, variation=2.719154930386214e-08.
# Normalized cost function value=0.03518201626143309, variation=2.5828954454409914e-08.
# Normalized cost function value=0.0351819917267748, variation=2.4534658284169897e-08.
# Normalized cost function value=0.03518196842153907, variation=2.3305235734294438e-08.
# Normalized cost function value=0.03518194628410477, variation=2.2137434295410596e-08.
# Normalized cost function value=0.035181925255940646, variation=2.1028164126635218e-08.
# Normalized cost function value=0.03518190528145001, variation=1.9974490637897357e-08.
# Normalized cost function value=0.03518188630782365, variation=1.8973626357554618e-08.
# Normalized cost function value=0.03518186828490022, variation=1.8022923431448845e-08.
# Normalized cost function value=0.03518185116503262, variation=1.7119867599946215e-08.
# Normalized cost function value=0.03518183490296307, variation=1.626206955207543e-08.
# Normalized cost function value=0.035181819455702174, variation=1.5447260894030368e-08.
# Normalized cost function value=0.03518180478241604, variation=1.467328613474761e-08.
# Normalized cost function value=0.035181790844317454, variation=1.3938098585020153e-08.
# Normalized cost function value=0.03518177760456359, variation=1.3239753862692716e-08.
# Normalized cost function value=0.03518176502815863, variation=1.2576404959108167e-08.
# Normalized cost function value=0.03518175308186091, variation=1.19462977218876e-08.
# Normalized cost function value=0.03518174173409491, variation=1.1347765997704595e-08.
# Normalized cost function value=0.03518173095486781, variation=1.0779227101187505e-08.
# Normalized cost function value=0.03518172071569026, variation=1.0239177554438594e-08.
# Normalized cost function value=0.03518171098950071, variation=9.72618954819815e-09.
# Converged in 184 iterations.

# %%
errors[-1], len(errors)
# Out:
# (0.03518171098950071, 185)

# %% [markdown]
# ## NTD: Nonnegative Tucker Decomposition

# %%
rank = 2
U_lines = 500
V_lines = 250
W_lines = 50

T = tl.random.random_tucker((U_lines, V_lines, W_lines), (4,3,2), full=True)#, nonegative=True)
T = tl.abs(T)
T = T + 1e-2 * np.random.rand(U_lines, V_lines, W_lines)

core, factors, cost_fct_vals, toc = ntd.ntd(T, [4,3,2], init = "random", n_iter_max = 1000, tol = 1e-8,
           sparsity_coefficients = [None, None, None, None], fixed_modes = [], normalize = [False, False, False, False],
           verbose = True, return_costs = True)
# Out:
# Normalized cost function value=0.0037735871221246725
# Normalized cost function value=0.0008425395936174949, variation=0.0029310475285071777.
# Normalized cost function value=0.0007655581555580159, variation=7.698143805947905e-05.
# Normalized cost function value=0.0007102223016109263, variation=5.533585394708958e-05.
# Normalized cost function value=0.0005553171732514389, variation=0.00015490512835948742.
# Normalized cost function value=0.00032934111206123906, variation=0.0002259760611901998.
# Normalized cost function value=0.00026120808691001556, variation=6.81330251512235e-05.
# Normalized cost function value=0.00022402067724570587, variation=3.7187409664309686e-05.
# Normalized cost function value=0.00017723707166087326, variation=4.678360558483261e-05.
# Normalized cost function value=0.00014107661504635831, variation=3.616045661451495e-05.
# Normalized cost function value=0.00011540533474378174, variation=2.567128030257658e-05.
# Normalized cost function value=0.0001036379767920434, variation=1.176735795173833e-05.
# Normalized cost function value=8.762682873466437e-05, variation=1.601114805737904e-05.
# Normalized cost function value=8.024488601147434e-05, variation=7.381942723190028e-06.
# Normalized cost function value=7.075719349710003e-05, variation=9.487692514374308e-06.
# Normalized cost function value=6.438176649643661e-05, variation=6.375427000663417e-06.
# Normalized cost function value=6.220889319481447e-05, variation=2.1728733016221444e-06.
# Normalized cost function value=6.0041931603043416e-05, variation=2.1669615917710523e-06.
# Normalized cost function value=5.798270994123036e-05, variation=2.0592216618130587e-06.
# Normalized cost function value=5.5619255580335945e-05, variation=2.3634543608944125e-06.
# Normalized cost function value=5.430119887706768e-05, variation=1.3180567032682641e-06.
# Normalized cost function value=5.326053833569752e-05, variation=1.0406605413701601e-06.
# Normalized cost function value=5.2330969913105006e-05, variation=9.295684225925143e-07.
# Normalized cost function value=5.118823302304869e-05, variation=1.1427368900563157e-06.
# Normalized cost function value=5.025313349545484e-05, variation=9.350995275938525e-07.
# Normalized cost function value=4.944579618217706e-05, variation=8.073373132777811e-07.
# Normalized cost function value=4.906144267412396e-05, variation=3.8435350805310006e-07.
# Normalized cost function value=4.838373950423672e-05, variation=6.777031698872402e-07.
# Normalized cost function value=4.7767028736894515e-05, variation=6.167107673422015e-07.
# Normalized cost function value=4.729690924652147e-05, variation=4.7011949037304785e-07.
# Normalized cost function value=4.674728208426644e-05, variation=5.496271622550288e-07.
# Normalized cost function value=4.640999689366936e-05, variation=3.372851905970769e-07.
# Normalized cost function value=4.595865469331333e-05, variation=4.5134220035603e-07.
# Normalized cost function value=4.55219849957744e-05, variation=4.366696975389341e-07.
# Normalized cost function value=4.511738304545914e-05, variation=4.0460195031525464e-07.
# Normalized cost function value=4.473826000509965e-05, variation=3.791230403594944e-07.
# Normalized cost function value=4.4425769344847204e-05, variation=3.12490660252445e-07.
# Normalized cost function value=4.418102771755908e-05, variation=2.447416272881249e-07.
# Normalized cost function value=4.3935129063305194e-05, variation=2.458986542538846e-07.
# Normalized cost function value=4.364048856460851e-05, variation=2.946404986966836e-07.
# Normalized cost function value=4.3364856690214496e-05, variation=2.756318743940149e-07.
# Normalized cost function value=4.3068648794786574e-05, variation=2.9620789542792207e-07.
# Normalized cost function value=4.285852747077965e-05, variation=2.101213240069251e-07.
# Normalized cost function value=4.2660779862600185e-05, variation=1.9774760817946313e-07.
# Normalized cost function value=4.241862361483757e-05, variation=2.4215624776261445e-07.
# Normalized cost function value=4.2171507590075576e-05, variation=2.471160247619953e-07.
# Normalized cost function value=4.193181770146586e-05, variation=2.3968988860971566e-07.
# Normalized cost function value=4.1699161310089847e-05, variation=2.326563913760134e-07.
# Normalized cost function value=4.154344430653635e-05, variation=1.5571700355349538e-07.
# Normalized cost function value=4.136592796496865e-05, variation=1.7751634156770295e-07.
# Normalized cost function value=4.123688201972806e-05, variation=1.290459452405913e-07.
# Normalized cost function value=4.102449756206593e-05, variation=2.123844576621279e-07.
# Normalized cost function value=4.0824718357223e-05, variation=1.9977920484293133e-07.
# Normalized cost function value=4.063082861556143e-05, variation=1.9388974166156906e-07.
# Normalized cost function value=4.046075410976269e-05, variation=1.7007450579874066e-07.
# Normalized cost function value=4.032602380555801e-05, variation=1.3473030420467914e-07.
# Normalized cost function value=4.0221804383099307e-05, variation=1.0421942245870237e-07.
# Normalized cost function value=4.0066512871440215e-05, variation=1.5529151165909183e-07.
# Normalized cost function value=3.99659281273033e-05, variation=1.0058474413691617e-07.
# Normalized cost function value=3.9787281232117574e-05, variation=1.786468951857245e-07.
# Normalized cost function value=3.965718380802831e-05, variation=1.3009742408926351e-07.
# Normalized cost function value=3.951081184731286e-05, variation=1.4637196071545138e-07.
# Normalized cost function value=3.938615494828279e-05, variation=1.2465689903006573e-07.
# Normalized cost function value=3.9246015905061634e-05, variation=1.4013904322115946e-07.
# Normalized cost function value=3.914587914437188e-05, variation=1.0013676068975719e-07.
# Normalized cost function value=3.898638454814677e-05, variation=1.5949459622510346e-07.
# Normalized cost function value=3.884056691859401e-05, variation=1.4581762955275998e-07.
# Normalized cost function value=3.8750163735825306e-05, variation=9.040318276870687e-08.
# Normalized cost function value=3.8600096620620775e-05, variation=1.5006711520453123e-07.
# Normalized cost function value=3.8463420338528e-05, variation=1.3667628209277217e-07.
# Normalized cost function value=3.833024454077713e-05, variation=1.3317579775087526e-07.
# Normalized cost function value=3.8246097905673395e-05, variation=8.414663510373236e-08.
# Normalized cost function value=3.810631543380397e-05, variation=1.3978247186942295e-07.
# Normalized cost function value=3.8010546855354135e-05, variation=9.576857844983733e-08.
# Normalized cost function value=3.788501435128589e-05, variation=1.2553250406824806e-07.
# Normalized cost function value=3.776189650525893e-05, variation=1.2311784602695542e-07.
# Normalized cost function value=3.7710608883223703e-05, variation=5.1287622035228134e-08.
# Normalized cost function value=3.766565125516179e-05, variation=4.495762806191263e-08.
# Normalized cost function value=3.761939118130598e-05, variation=4.626007385580841e-08.
# Normalized cost function value=3.753320635068665e-05, variation=8.618483061933476e-08.
# Normalized cost function value=3.7416311662434354e-05, variation=1.1689468825229374e-07.
# Normalized cost function value=3.733487874064221e-05, variation=8.143292179214613e-08.
# Normalized cost function value=3.7215407621920154e-05, variation=1.19471118722054e-07.
# Normalized cost function value=3.71047209739643e-05, variation=1.1068664795585128e-07.
# Normalized cost function value=3.703679328222628e-05, variation=6.792769173802191e-08.
# Normalized cost function value=3.692272697653404e-05, variation=1.140663056922389e-07.
# Normalized cost function value=3.685604167843753e-05, variation=6.668529809651132e-08.
# Normalized cost function value=3.674530268180117e-05, variation=1.1073899663636321e-07.
# Normalized cost function value=3.66658904960216e-05, variation=7.941218577956432e-08.
# Normalized cost function value=3.656945937087905e-05, variation=9.643112514255117e-08.
# Normalized cost function value=3.6471956414333083e-05, variation=9.750295654596826e-08.
# Normalized cost function value=3.639701982335727e-05, variation=7.49365909758157e-08.
# Normalized cost function value=3.632128869325066e-05, variation=7.573113010660675e-08.
# Normalized cost function value=3.625771193737956e-05, variation=6.357675587109903e-08.
# Normalized cost function value=3.617078353954447e-05, variation=8.692839783508931e-08.
# Normalized cost function value=3.61033371879476e-05, variation=6.744635159687583e-08.
# Normalized cost function value=3.602531479647433e-05, variation=7.802239147326648e-08.
# Normalized cost function value=3.593031096914646e-05, variation=9.500382732787073e-08.
# Normalized cost function value=3.586926226948263e-05, variation=6.1048699663827e-08.
# Normalized cost function value=3.580933162558165e-05, variation=5.993064390097998e-08.
# Normalized cost function value=3.57253680324495e-05, variation=8.396359313215146e-08.
# Normalized cost function value=3.566081438297674e-05, variation=6.455364947276221e-08.
# Normalized cost function value=3.558265286794947e-05, variation=7.816151502726578e-08.
# Normalized cost function value=3.5531039139968816e-05, variation=5.161372798065747e-08.
# Normalized cost function value=3.545202870926777e-05, variation=7.901043070104548e-08.
# Normalized cost function value=3.5368190147448626e-05, variation=8.383856181914392e-08.
# Normalized cost function value=3.5291222936615225e-05, variation=7.696721083340135e-08.
# Normalized cost function value=3.5224474803487895e-05, variation=6.674813312732995e-08.
# Normalized cost function value=3.514448475564319e-05, variation=7.9990047844702e-08.
# Normalized cost function value=3.506793514271427e-05, variation=7.654961292892325e-08.
# Normalized cost function value=3.498930557313219e-05, variation=7.862956958208314e-08.
# Normalized cost function value=3.4938942150904625e-05, variation=5.036342222756139e-08.
# Normalized cost function value=3.486838717689798e-05, variation=7.055497400664852e-08.
# Normalized cost function value=3.4812286278859645e-05, variation=5.610089803833148e-08.
# Normalized cost function value=3.474518170973179e-05, variation=6.710456912785678e-08.
# Normalized cost function value=3.4670210777718784e-05, variation=7.497093201300464e-08.
# Normalized cost function value=3.459639665537192e-05, variation=7.381412234686615e-08.
# Normalized cost function value=3.4551443393989915e-05, variation=4.4953261382002713e-08.
# Normalized cost function value=3.451574681260139e-05, variation=3.569658138852694e-08.
# Normalized cost function value=3.4467009322329726e-05, variation=4.873749027166157e-08.
# Normalized cost function value=3.4403658853299164e-05, variation=6.335046903056254e-08.
# Normalized cost function value=3.4352614951627766e-05, variation=5.104390167139805e-08.
# Normalized cost function value=3.430248172955827e-05, variation=5.013322206949924e-08.
# Normalized cost function value=3.4237615273838854e-05, variation=6.486645571941301e-08.
# Normalized cost function value=3.4174069205164e-05, variation=6.354606867485247e-08.
# Normalized cost function value=3.4114646063796956e-05, variation=5.942314136704542e-08.
# Normalized cost function value=3.4053745810722724e-05, variation=6.090025307423194e-08.
# Normalized cost function value=3.40090917831014e-05, variation=4.46540276213215e-08.
# Normalized cost function value=3.395118240555236e-05, variation=5.790937754904203e-08.
# Normalized cost function value=3.389527485333631e-05, variation=5.59075522160485e-08.
# Normalized cost function value=3.3840670021144674e-05, variation=5.460483219163785e-08.
# Normalized cost function value=3.378710754330258e-05, variation=5.3562477842095536e-08.
# Normalized cost function value=3.3737697192705016e-05, variation=4.941035059756265e-08.
# Normalized cost function value=3.3708923729004654e-05, variation=2.877346370036202e-08.
# Normalized cost function value=3.3663235134538873e-05, variation=4.5688594465780204e-08.
# Normalized cost function value=3.361604817085047e-05, variation=4.718696368840187e-08.
# Normalized cost function value=3.3582102858554e-05, variation=3.394531229646984e-08.
# Normalized cost function value=3.3533892069838814e-05, variation=4.821078871518759e-08.
# Normalized cost function value=3.350328142784326e-05, variation=3.061064199555099e-08.
# Normalized cost function value=3.3456977671792996e-05, variation=4.63037560502667e-08.
# Normalized cost function value=3.3416003085733464e-05, variation=4.097458605953206e-08.
# Normalized cost function value=3.337103838348653e-05, variation=4.496470224693431e-08.
# Normalized cost function value=3.3332929209285104e-05, variation=3.810917420142627e-08.
# Normalized cost function value=3.3303560140645045e-05, variation=2.936906864005887e-08.
# Normalized cost function value=3.3263966565657336e-05, variation=3.959357498770923e-08.
# Normalized cost function value=3.322120554308853e-05, variation=4.2761022568805595e-08.
# Normalized cost function value=3.318407316450349e-05, variation=3.713237858504265e-08.
# Normalized cost function value=3.315593133113268e-05, variation=2.814183337080669e-08.
# Normalized cost function value=3.3116107227391394e-05, variation=3.982410374128671e-08.
# Normalized cost function value=3.309029357034241e-05, variation=2.5813657048984466e-08.
# Normalized cost function value=3.307250747689255e-05, variation=1.7786093449858687e-08.
# Normalized cost function value=3.3046655266401186e-05, variation=2.5852210491364772e-08.
# Normalized cost function value=3.3009135933327246e-05, variation=3.751933307394068e-08.
# Normalized cost function value=3.297017037492033e-05, variation=3.8965558406912687e-08.
# Normalized cost function value=3.293406858218661e-05, variation=3.610179273372461e-08.
# Normalized cost function value=3.289695803475593e-05, variation=3.711054743067927e-08.
# Normalized cost function value=3.2877193113649526e-05, variation=1.9764921106402925e-08.
# Normalized cost function value=3.285760337596626e-05, variation=1.958973768326265e-08.
# Normalized cost function value=3.282187633045438e-05, variation=3.572704551188413e-08.
# Normalized cost function value=3.279598027403209e-05, variation=2.5896056422285867e-08.
# Normalized cost function value=3.276969804267327e-05, variation=2.6282231358824002e-08.
# Normalized cost function value=3.273363853163396e-05, variation=3.605951103930968e-08.
# Normalized cost function value=3.269807604351376e-05, variation=3.5562488120197795e-08.
# Normalized cost function value=3.2671966696532094e-05, variation=2.6109346981667428e-08.
# Normalized cost function value=3.2637751856535356e-05, variation=3.421483999673815e-08.
# Normalized cost function value=3.2615177315207424e-05, variation=2.257454132793249e-08.
# Normalized cost function value=3.259015435357173e-05, variation=2.5022961635692658e-08.
# Normalized cost function value=3.257476606132579e-05, variation=1.538829224594383e-08.
# Normalized cost function value=3.255693211465141e-05, variation=1.7833946674374772e-08.
# Normalized cost function value=3.253810763004421e-05, variation=1.8824484607199822e-08.
# Normalized cost function value=3.250562927394529e-05, variation=3.2478356098922386e-08.
# Normalized cost function value=3.2484278372419885e-05, variation=2.1350901525405222e-08.
# Normalized cost function value=3.245188491728595e-05, variation=3.2393455133934094e-08.
# Normalized cost function value=3.242028461810259e-05, variation=3.1600299183361634e-08.
# Normalized cost function value=3.2387982720037406e-05, variation=3.230189806518384e-08.
# Normalized cost function value=3.235592565754014e-05, variation=3.2057062497267176e-08.
# Normalized cost function value=3.2325790909884704e-05, variation=3.0134747655434816e-08.
# Normalized cost function value=3.229524014331521e-05, variation=3.05507665694955e-08.
# Normalized cost function value=3.22637407842141e-05, variation=3.1499359101107294e-08.
# Normalized cost function value=3.22324090493961e-05, variation=3.1331734818001045e-08.
# Normalized cost function value=3.220239865838246e-05, variation=3.001039101364298e-08.
# Normalized cost function value=3.217285303340263e-05, variation=2.9545624979824636e-08.
# Normalized cost function value=3.214191642546355e-05, variation=3.093660793908543e-08.
# Normalized cost function value=3.2111207651442046e-05, variation=3.070877402150049e-08.
# Normalized cost function value=3.209226515373818e-05, variation=1.8942497703863456e-08.
# Normalized cost function value=3.206306761820844e-05, variation=2.9197535529745127e-08.
# Normalized cost function value=3.203304564696944e-05, variation=3.002197123899448e-08.
# Normalized cost function value=3.200465074662501e-05, variation=2.8394900344433393e-08.
# Normalized cost function value=3.1986102432190505e-05, variation=1.854831443450465e-08.
# Normalized cost function value=3.195754323200655e-05, variation=2.855920018395464e-08.
# Normalized cost function value=3.194058165573325e-05, variation=1.6961576273298953e-08.
# Normalized cost function value=3.191237885482539e-05, variation=2.8202800907862612e-08.
# Normalized cost function value=3.189525212250397e-05, variation=1.7126732321417874e-08.
# Normalized cost function value=3.18668467406203e-05, variation=2.840538188367427e-08.
# Normalized cost function value=3.183856518183168e-05, variation=2.8281558788613534e-08.
# Normalized cost function value=3.1811220014882754e-05, variation=2.7345166948928765e-08.
# Normalized cost function value=3.1783223778028636e-05, variation=2.7996236854118263e-08.
# Normalized cost function value=3.1771030277192935e-05, variation=1.2193500835701548e-08.
# Normalized cost function value=3.174473180737852e-05, variation=2.6298469814411507e-08.
# Normalized cost function value=3.1726700865531255e-05, variation=1.8030941847268405e-08.
# Normalized cost function value=3.169935030281634e-05, variation=2.73505627149161e-08.
# Normalized cost function value=3.167296965525819e-05, variation=2.638064755814735e-08.
# Normalized cost function value=3.164580784652797e-05, variation=2.7161808730224437e-08.
# Normalized cost function value=3.161998656314445e-05, variation=2.582128338351878e-08.
# Normalized cost function value=3.15946880253418e-05, variation=2.5298537802647238e-08.
# Normalized cost function value=3.156960598483148e-05, variation=2.508204051031792e-08.
# Normalized cost function value=3.154284410923074e-05, variation=2.6761875600743912e-08.
# Normalized cost function value=3.151622830243257e-05, variation=2.661580679816914e-08.
# Normalized cost function value=3.150158633558401e-05, variation=1.4641966848559951e-08.
# Normalized cost function value=3.147614893434543e-05, variation=2.5437401238581484e-08.
# Normalized cost function value=3.145151547385392e-05, variation=2.46334604915116e-08.
# Normalized cost function value=3.1425687059194116e-05, variation=2.5828414659801163e-08.
# Normalized cost function value=3.140006262777423e-05, variation=2.5624431419888228e-08.
# Normalized cost function value=3.137552300303062e-05, variation=2.4539624743610323e-08.
# Normalized cost function value=3.1350146840672966e-05, variation=2.5376162357651543e-08.
# Normalized cost function value=3.132581670847632e-05, variation=2.4330132196643314e-08.
# Normalized cost function value=3.13016952599268e-05, variation=2.4121448549525534e-08.
# Normalized cost function value=3.1276720417567334e-05, variation=2.4974842359462763e-08.
# Normalized cost function value=3.126701241861766e-05, variation=9.707998949675225e-09.
# Converged in 218 iterations.

# %% [markdown]
# ## MU
# ### Beta = 2

# %%
rank = 2
U_lines = 500
V_lines = 250
W_lines = 50

T = tl.random.random_tucker((U_lines, V_lines, W_lines), (4,3,2), full=True)#, nonegative=True)
T = tl.abs(T)
T = T + 1e-2 * np.random.rand(U_lines, V_lines, W_lines)

core, factors, cost_fct_vals, toc = ntd.ntd_mu(T, [4,3,2], init = "random", n_iter_max = 100, tol = 1e-8, beta = 2,
           sparsity_coefficients = [None, None, None, None], fixed_modes = [], normalize = [False, False, False, False],
           verbose = True, return_costs = True)
# Out:
# Initial Obj=59345.9401938378
# Iter=1|Obj=56595.91592321377| Var=0.046338877800938115 (target is 1e-08).
# Iter=2|Obj=54912.40461371337| Var=0.029746162457808683 (target is 1e-08).
# Iter=3|Obj=53392.97305015571| Var=0.027670097025366953 (target is 1e-08).
# Iter=4|Obj=52016.38221001458| Var=0.02578224739139379 (target is 1e-08).
# Iter=5|Obj=50764.551396783834| Var=0.02406608764478302 (target is 1e-08).
# Iter=6|Obj=49622.204373421475| Var=0.022502848777951227 (target is 1e-08).
# Iter=7|Obj=48576.387599970556| Var=0.02107558071344119 (target is 1e-08).
# Iter=8|Obj=47616.0543176407| Var=0.019769549152939426 (target is 1e-08).
# Iter=9|Obj=46731.73321211281| Var=0.018571910633936473 (target is 1e-08).
# Iter=10|Obj=45915.262774039176| Var=0.01747143497476803 (target is 1e-08).
# Iter=11|Obj=45159.57683279875| Var=0.016458273253478865 (target is 1e-08).
# Iter=12|Obj=44458.53025994916| Var=0.015523763108879067 (target is 1e-08).
# Iter=13|Obj=43806.75643554455| Var=0.014660264758949266 (target is 1e-08).
# Iter=14|Obj=43199.550003265045| Var=0.01386102240125729 (target is 1e-08).
# Iter=15|Obj=42632.76989123298| Var=0.013120046666903428 (target is 1e-08).
# Iter=16|Obj=42102.758673394914| Var=0.012432014602622797 (target is 1e-08).
# Iter=17|Obj=41606.27518365175| Var=0.011792184298291522 (target is 1e-08).
# Iter=18|Obj=41140.43793806005| Var=0.0111963217936591 (target is 1e-08).
# Iter=19|Obj=40702.67741784273| Var=0.010640638314944589 (target is 1e-08).
# Iter=20|Obj=40290.69565319535| Var=0.010121736229243304 (target is 1e-08).
# Iter=21|Obj=39902.43185122489| Var=0.009636562379375765 (target is 1e-08).
# Iter=22|Obj=39536.03305042585| Var=0.009182367685386736 (target is 1e-08).
# Iter=23|Obj=39189.82897355535| Var=0.008756672082627561 (target is 1e-08).
# Iter=24|Obj=38862.31040174412| Var=0.008357234016821822 (target is 1e-08).
# Iter=25|Obj=38552.110513602835| Var=0.007982023840954287 (target is 1e-08).
# Iter=26|Obj=38257.988730419056| Var=0.007629200561665741 (target is 1e-08).
# Iter=27|Obj=37978.81668726242| Var=0.007297091468236668 (target is 1e-08).
# Iter=28|Obj=37713.566013774725| Var=0.006984174248289748 (target is 1e-08).
# Iter=29|Obj=37461.2976606087| Var=0.006689061253817321 (target is 1e-08).
# Iter=30|Obj=37221.152550242434| Var=0.006410485630848467 (target is 1e-08).
# Iter=31|Obj=36992.34336607874| Var=0.0061472890678180275 (target is 1e-08).
# Iter=32|Obj=36774.14732279248| Var=0.005898410952963393 (target is 1e-08).
# Iter=33|Obj=36565.899784973226| Var=0.0056628787607587265 (target is 1e-08).
# Iter=34|Obj=36366.98862114682| Var=0.005439799512554323 (target is 1e-08).
# Iter=35|Obj=36176.849196984986| Var=0.005228352177921867 (target is 1e-08).
# Iter=36|Obj=35994.9599255169| Var=0.005027780901473393 (target is 1e-08).
# Iter=37|Obj=35820.838303930446| Var=0.00483738895519703 (target is 1e-08).
# Iter=38|Obj=35654.037376464556| Var=0.00465653332986315 (target is 1e-08).
# Iter=39|Obj=35494.14257128339| Var=0.0044846198901085784 (target is 1e-08).
# Iter=40|Obj=35340.768866326696| Var=0.004321099027780966 (target is 1e-08).
# Iter=41|Obj=35193.55824517842| Var=0.004165461756225116 (target is 1e-08).
# Iter=42|Obj=35052.177409139804| Var=0.004017236195717346 (target is 1e-08).
# Iter=43|Obj=34916.31571610114| Var=0.003875984406128152 (target is 1e-08).
# Iter=44|Obj=34785.683320574186| Var=0.0037412995285386113 (target is 1e-08).
# Iter=45|Obj=34660.009492486075| Var=0.003612803202108737 (target is 1e-08).
# Iter=46|Obj=34539.04109512704| Var=0.0034901432264541356 (target is 1e-08).
# Iter=47|Obj=34422.54120504748| Var=0.003372991443471145 (target is 1e-08).
# Iter=48|Obj=34310.28785878225| Var=0.0032610418154940908 (target is 1e-08).
# Iter=49|Obj=34202.07291308393| Var=0.0031540086793710106 (target is 1e-08).
# Iter=50|Obj=34097.70100691286| Var=0.003051625158402179 (target is 1e-08).
# Iter=51|Obj=33996.98861479403| Var=0.002953641716150133 (target is 1e-08).
# Iter=52|Obj=33899.76318234236| Var=0.002859824837819917 (target is 1e-08).
# Iter=53|Obj=33805.86233579375| Var=0.0027699558266389953 (target is 1e-08).
# Iter=54|Obj=33715.1331582904| Var=0.0026838297039173654 (target is 1e-08).
# Iter=55|Obj=33627.43152646573| Var=0.0026012542027617556 (target is 1e-08).
# Iter=56|Obj=33542.621501574875| Var=0.0025220488464634703 (target is 1e-08).
# Iter=57|Obj=33460.574770033076| Var=0.0024460441035578234 (target is 1e-08).
# Iter=58|Obj=33381.17012876879| Var=0.002373080612333041 (target is 1e-08).
# Iter=59|Obj=33304.2930112758| Var=0.002303008468440076 (target is 1e-08).
# Iter=60|Obj=33229.835050677335| Var=0.0022356865696939623 (target is 1e-08).
# Iter=61|Obj=33157.69367648683| Var=0.0021709820130158854 (target is 1e-08).
# Iter=62|Obj=33087.77174208629| Var=0.002108769538760878 (target is 1e-08).
# Iter=63|Obj=33019.9771802391| Var=0.0020489310182517126 (target is 1e-08).
# Iter=64|Obj=32954.22268421796| Var=0.0019913549807202475 (target is 1e-08).
# Iter=65|Obj=32890.42541236199| Var=0.0019359361762922602 (target is 1e-08).
# Iter=66|Obj=32828.506714090996| Var=0.0018825751717921526 (target is 1e-08).
# Iter=67|Obj=32768.39187558691| Var=0.0018311779767394606 (target is 1e-08).
# Iter=68|Obj=32710.009883524774| Var=0.0017816556968616797 (target is 1e-08).
# Iter=69|Obj=32653.293205383085| Var=0.0017339242129136695 (target is 1e-08).
# Iter=70|Obj=32598.17758499962| Var=0.0016879038826742032 (target is 1e-08).
# Iter=71|Obj=32544.601852158594| Var=0.0016435192642695114 (target is 1e-08).
# Iter=72|Obj=32492.507745105602| Var=0.0016006988590501483 (target is 1e-08).
# Iter=73|Obj=32441.839744983205| Var=0.0015593748725051806 (target is 1e-08).
# Iter=74|Obj=32392.54492126885| Var=0.0015194829917738136 (target is 1e-08).
# Iter=75|Obj=32344.572787378445| Var=0.0014809621783963992 (target is 1e-08).
# Iter=76|Obj=32297.87516566644| Var=0.0014437544752555456 (target is 1e-08).
# Iter=77|Obj=32252.40606112436| Var=0.0014078048264430539 (target is 1e-08).
# Iter=78|Obj=32208.121543133908| Var=0.001373060909208548 (target is 1e-08).
# Iter=79|Obj=32164.979634686006| Var=0.0013394729770292687 (target is 1e-08).
# Iter=80|Obj=32122.940208526674| Var=0.0013069937129385754 (target is 1e-08).
# Iter=81|Obj=32081.964889733383| Var=0.0012755780923943767 (target is 1e-08).
# Iter=82|Obj=32042.01696426534| Var=0.0012451832549952306 (target is 1e-08).
# Iter=83|Obj=32003.0612930694| Var=0.0012157683843494096 (target is 1e-08).
# Iter=84|Obj=31965.0642313544| Var=0.001187294595571329 (target is 1e-08).
# Iter=85|Obj=31927.993552678818| Var=0.001159724829810326 (target is 1e-08).
# Iter=86|Obj=31891.818377522824| Var=0.0011330237553545872 (target is 1e-08).
# Iter=87|Obj=31856.509106042497| Var=0.0011071576748102158 (target is 1e-08).
# Iter=88|Obj=31822.03735472552| Var=0.0010820944379759266 (target is 1e-08).
# Iter=89|Obj=31788.375896690086| Var=0.0010578033599861235 (target is 1e-08).
# Iter=90|Obj=31755.498605387897| Var=0.0010342551443659222 (target is 1e-08).
# Iter=91|Obj=31723.380401488514| Var=0.0010114218107075636 (target is 1e-08).
# Iter=92|Obj=31691.997202741113| Var=0.0009892766265832095 (target is 1e-08).
# Iter=93|Obj=31661.32587662198| Var=0.0009677940434905674 (target is 1e-08).
# Iter=94|Obj=31631.344195591922| Var=0.0009469496365026174 (target is 1e-08).
# Iter=95|Obj=31602.030794798902| Var=0.0009267200474238878 (target is 1e-08).
# Iter=96|Obj=31573.365132074025| Var=0.0009070829311892022 (target is 1e-08).
# Iter=97|Obj=31545.32745007853| Var=0.0008880169053317735 (target is 1e-08).
# Iter=98|Obj=31517.898740470464| Var=0.0008695015022897741 (target is 1e-08).
# Iter=99|Obj=31491.060709968388| Var=0.0008515171243828873 (target is 1e-08).

# %% [markdown]
# ### Beta = 1

# %%
rank = 2
U_lines = 500
V_lines = 250
W_lines = 50

T = tl.random.random_tucker((U_lines, V_lines, W_lines), (4,3,2), full=True)#, nonegative=True)
T = tl.abs(T)
T = T + 1e-2 * np.random.rand(U_lines, V_lines, W_lines)

core, factors, cost_fct_vals, toc = ntd.ntd_mu(T, [4,3,2], init = "random", n_iter_max = 100, tol = 1e-8, beta = 1,
           sparsity_coefficients = [None, None, None, None], fixed_modes = [], normalize = [False, False, False, False],
           verbose = True, return_costs = True)

# %% [markdown]
# # PARAFAC2: Nonnegative Tensor Factorization admitting variability over a factor

# %%
rank = 3
W_lines = 5
H_lines = 5
Q_lines = 5

H_0 = np.random.rand(rank, H_lines)
Q_0 = np.random.rand(Q_lines, rank)

W_1 = np.random.rand(W_lines, rank)

tensor_slices = []
W_list = []
D_list = []

for i in range(Q_lines):
    diag_Q = np.diag(Q_0[i,:])
    W_k = np.roll(W_1, i, axis=0)
    tensor_slices.append(W_k@diag_Q@H_0)
    W_list.append(W_k)
    D_list.append(diag_Q)

W_list, H, D_list, errors, toc = parafac2.parafac_2(tensor_slices, rank, init_with_P = True, init = "random",
                                                    tol_mu = 1e6, step_mu = 1.02, n_iter_max=1000, tol=1e-8,
                                                    sparsity_coefficient = None, fixed_modes = [], normalize = [False, False, False, False, False],
                                                    verbose=False, return_costs=True)

# %%
errors[-1], len(errors)
# Out:
# (0.12336820547604586, 1000)
